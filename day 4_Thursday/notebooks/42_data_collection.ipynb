# %% [markdown]
# #  	Lecture: Web Data Acquisition A

# %% [markdown]
# This lecture adapts content from the  Lab for Data Mining with Pandas on Wikipedia data by [Brian Keegan](https://www.brianckeegan.com),[Department of Information Science, CU Boulder](www.colorado.edu/cmci/academics/information-science), as well as the [PyCon 2015 Pandas tutorial](https://github.com/brandon-rhodes/pycon-pandas-tutorial) by Brandon Rhodes.
#
#
# This notebook is copyrighted and made available under the [Apache License v2.0](https://creativecommons.org/licenses/by-sa/4.0/) license.

# %% [markdown]
# # Web Data Acq.. what?
#
# ### 1. "Webscraping"
# ![alt text](21_webscrape1.png "API")
#
#
# more like "Screenscraping"
#
#
# ![alt text](21_webscrape2.png "API")

# %% [markdown]
# ### 2. API-"Scraping"
#
# ![alt text](21_webscrape3_api.png "API")
#
# What is a Web API?
#
# * answers if spoken to correctly
# * predefined set of vocabulary, rules and answer formats
# * mostly accessible over http and often without credentials
#
# **Also**:
# Install a browser add-on like [Chrome: JSON Viewer](https://chrome.google.com/webstore/detail/json-viewer/gbmdgpbipfallnflgajpaliibnhdgobh) or [Firefox: JSON view](https://jsonview.com) (similarly available for other browsers), to see human-readable JSON.

# %% [markdown]
# ## Import modules and set up environment

# %%
# Two fundamental packages for doing data manipulation
import numpy as np                   # http://www.numpy.org/
import pandas as pd                  # http://pandas.pydata.org/

# Package to save/load Python structures in the "Pickle" format
import pickle

# Last but not least: Package query and download from web resources! Alternatives: URLlib2, URLlib3
import requests

# %% [markdown]
# # Querying Abgeordnetenwatch.de
# https://en.wikipedia.org/wiki/Parliamentwatch
#
# https://www.abgeordnetenwatch.de/api/
#
# https://www.abgeordnetenwatch.de/api/v2/parliaments
#
# https://www.abgeordnetenwatch.de/api/v2/politicians
#
#
# Task: Find out how many votes the politicans in the current NRW parliament have participated in.

# %% [markdown]
# There are several ways to send a request to an API, among others you can do it with the package `requests`. This package allows you to make **HTTP requests** very **easily** and **quickly**. It provides all functions and methods to write your **parameters** into requests, send you **requests** and work with your **responses**.

# %% [markdown]
# ## Getting candidates of a parliament

# %%
parliaments = requests.get(url="https://www.abgeordnetenwatch.de/api/v2/parliaments").json()

# %%
parliaments
# Out:
# {'meta': {'abgeordnetenwatch_api': {'version': '2.7',
#    'changelog': 'https://www.abgeordnetenwatch.de/api/version-changelog/aktuell',
#    'licence': 'CC0 1.0',
#    'licence_link': 'https://creativecommons.org/publicdomain/zero/1.0/deed.de',
#    'documentation': 'https://www.abgeordnetenwatch.de/api/entitaeten/parliament'},
#   'status': 'ok',
#   'status_message': '',
#   'result': {'count': 18, 'total': 18, 'range_start': 0, 'range_end': 100}},
#  'data': [{'id': 18,
#    'entity_type': 'parliament',
#    'label': 'Schleswig-Holstein',
#    'api_url': 'https://www.abgeordnetenwatch.de/api/v2/parliaments/18',
#    'abgeordnetenwatch_url': 'https://www.abgeordnetenwatch.de/schleswig-holstein',
#    'label_external_long': 'Landtag Schleswig-Holstein',
#    'current_project': {'id': 138,
#     'entity_type': 'parliament_period',
#     'label': 'Schleswig-Holstein 2022 - 2027',
#     'api_url': 'https://www.abgeordnetenwatch.de/api/v2/parliament-periods/138',
#     'abgeordnetenwatch_url': 'https://www.abgeordnetenwatch.de/schleswig-holstein'}},
#   {'id': 17,
#    'entity_type': 'parliament',
#    'label': 'Sachsen',
#    'api_url': 'https://www.abgeordnetenwatch.de/api/v2/parliaments/17',
#    'abgeordnetenwatch_url': 'https://www.abgeordnetenwatch.de/sachsen',
#    'label_external_long': 'Landtag Sachsen',
#    'current_project': {'id': 119,
#     'entity_type': 'parliament_period',
#     'label': 'Sachsen 2019 - 2024',
#     'api_url': 'https://www.abgeordnetenwatch.de/api/v2/parliament-periods/119',
#     'abgeordnetenwatch_url': 'https://www.abgeordnetenwatch.de/sachsen'}},
#   {'id': 16,
#    'entity_type': 'parliament',
#    'label': 'Brandenburg',
#    'api_url': 'https://www.abgeordnetenwatch.de/api/v2/parliaments/16',
#    'abgeordnetenwatch_url': 'https://www.abgeordnetenwatch.de/brandenburg',
#    'label_external_long': 'Landtag Brandenburg',
#    'current_project': {'id': 120,
#     'entity_type': 'parliament_period',
#     'label': 'Brandenburg 2019 - 2024',
#     'api_url': 'https://www.abgeordnetenwatch.de/api/v2/parliament-periods/120',
#     'abgeordnetenwatch_url': 'https://www.abgeordnetenwatch.de/brandenburg'}},
#   {'id': 15,
#    'entity_type': 'parliament',
#    'label': 'Thüringen',
#    'api_url': 'https://www.abgeordnetenwatch.de/api/v2/parliaments/15',
#    'abgeordnetenwatch_url': 'https://www.abgeordnetenwatch.de/thueringen',
#    'label_external_long': 'Landtag Thüringen',
#    'current_project': {'id': 121,
#     'entity_type': 'parliament_period',
#     'label': 'Thüringen 2019 - 2024',
#     'api_url': 'https://www.abgeordnetenwatch.de/api/v2/parliament-periods/121',
#     'abgeordnetenwatch_url': 'https://www.abgeordnetenwatch.de/thueringen'}},
#   {'id': 14,
#    'entity_type': 'parliament',
#    'label': 'Saarland',
#    'api_url': 'https://www.abgeordnetenwatch.de/api/v2/parliaments/14',
#    'abgeordnetenwatch_url': 'https://www.abgeordnetenwatch.de/saarland',
#    'label_external_long': 'Landtag Saarland',
#    'current_project': {'id': 137,
#     'entity_type': 'parliament_period',
#     'label': 'Saarland 2022 - 2027',
#     'api_url': 'https://www.abgeordnetenwatch.de/api/v2/parliament-periods/137',
#     'abgeordnetenwatch_url': 'https://www.abgeordnetenwatch.de/saarland'}},
#   {'id': 13,
#    'entity_type': 'parliament',
#    'label': 'Bayern',
#    'api_url': 'https://www.abgeordnetenwatch.de/api/v2/parliaments/13',
#    'abgeordnetenwatch_url': 'https://www.abgeordnetenwatch.de/bayern',
#    'label_external_long': 'Landtag Bayern',
#    'current_project': {'id': 147,
#     'entity_type': 'parliament_period',
#     'label': 'Bayern Wahl 2023',
#     'api_url': 'https://www.abgeordnetenwatch.de/api/v2/parliament-periods/147',
#     'abgeordnetenwatch_url': 'https://www.abgeordnetenwatch.de/bayern'}},
#   {'id': 12,
#    'entity_type': 'parliament',
#    'label': 'Niedersachsen',
#    'api_url': 'https://www.abgeordnetenwatch.de/api/v2/parliaments/12',
#    'abgeordnetenwatch_url': 'https://www.abgeordnetenwatch.de/niedersachsen',
#    'label_external_long': 'Landtag Niedersachsen',
#    'current_project': {'id': 143,
#     'entity_type': 'parliament_period',
#     'label': 'Niedersachsen 2022 - 2027',
#     'api_url': 'https://www.abgeordnetenwatch.de/api/v2/parliament-periods/143',
#     'abgeordnetenwatch_url': 'https://www.abgeordnetenwatch.de/niedersachsen'}},
#   {'id': 11,
#    'entity_type': 'parliament',
#    'label': 'Hessen',
#    'api_url': 'https://www.abgeordnetenwatch.de/api/v2/parliaments/11',
#    'abgeordnetenwatch_url': 'https://www.abgeordnetenwatch.de/hessen',
#    'label_external_long': 'Landtag Hessen',
#    'current_project': {'id': 148,
#     'entity_type': 'parliament_period',
#     'label': 'Hessen Wahl 2023',
#     'api_url': 'https://www.abgeordnetenwatch.de/api/v2/parliament-periods/148',
#     'abgeordnetenwatch_url': 'https://www.abgeordnetenwatch.de/hessen'}},
#   {'id': 10,
#    'entity_type': 'parliament',
#    'label': 'Bremen',
#    'api_url': 'https://www.abgeordnetenwatch.de/api/v2/parliaments/10',
#    'abgeordnetenwatch_url': 'https://www.abgeordnetenwatch.de/bremen',
#    'label_external_long': 'Bürgerschaft Bremen',
#    'current_project': {'id': 146,
#     'entity_type': 'parliament_period',
#     'label': 'Bremen 2023 - 2027',
#     'api_url': 'https://www.abgeordnetenwatch.de/api/v2/parliament-periods/146',
#     'abgeordnetenwatch_url': 'https://www.abgeordnetenwatch.de/bremen'}},
#   {'id': 9,
#    'entity_type': 'parliament',
#    'label': 'Mecklenburg-Vorpommern',
#    'api_url': 'https://www.abgeordnetenwatch.de/api/v2/parliaments/9',
#    'abgeordnetenwatch_url': 'https://www.abgeordnetenwatch.de/mecklenburg-vorpommern',
#    'label_external_long': 'Landtag Mecklenburg-Vorpommern',
#    'current_project': {'id': 134,
#     'entity_type': 'parliament_period',
#     'label': 'Mecklenburg-Vorpommern 2021 - 2026',
#     'api_url': 'https://www.abgeordnetenwatch.de/api/v2/parliament-periods/134',
#     'abgeordnetenwatch_url': 'https://www.abgeordnetenwatch.de/mecklenburg-vorpommern'}},
#   {'id': 8,
#    'entity_type': 'parliament',
#    'label': 'Sachsen-Anhalt',
#    'api_url': 'https://www.abgeordnetenwatch.de/api/v2/parliaments/8',
#    'abgeordnetenwatch_url': 'https://www.abgeordnetenwatch.de/sachsen-anhalt',
#    'label_external_long': 'Landtag Sachsen-Anhalt',
#    'current_project': {'id': 131,
#     'entity_type': 'parliament_period',
#     'label': 'Sachsen-Anhalt 2021 - 2026',
#     'api_url': 'https://www.abgeordnetenwatch.de/api/v2/parliament-periods/131',
#     'abgeordnetenwatch_url': 'https://www.abgeordnetenwatch.de/sachsen-anhalt'}},
#   {'id': 7,
#    'entity_type': 'parliament',
#    'label': 'Rheinland-Pfalz',
#    'api_url': 'https://www.abgeordnetenwatch.de/api/v2/parliaments/7',
#    'abgeordnetenwatch_url': 'https://www.abgeordnetenwatch.de/rheinland-pfalz',
#    'label_external_long': 'Landtag Rheinland-Pfalz',
#    'current_project': {'id': 127,
#     'entity_type': 'parliament_period',
#     'label': 'Rheinland-Pfalz 2021 - 2026',
#     'api_url': 'https://www.abgeordnetenwatch.de/api/v2/parliament-periods/127',
#     'abgeordnetenwatch_url': 'https://www.abgeordnetenwatch.de/rheinland-pfalz'}},
#   {'id': 6,
#    'entity_type': 'parliament',
#    'label': 'Baden-Württemberg',
#    'api_url': 'https://www.abgeordnetenwatch.de/api/v2/parliaments/6',
#    'abgeordnetenwatch_url': 'https://www.abgeordnetenwatch.de/baden-wuerttemberg',
#    'label_external_long': 'Landtag Baden-Württemberg',
#    'current_project': {'id': 126,
#     'entity_type': 'parliament_period',
#     'label': 'Baden-Württemberg 2021 - 2026',
#     'api_url': 'https://www.abgeordnetenwatch.de/api/v2/parliament-periods/126',
#     'abgeordnetenwatch_url': 'https://www.abgeordnetenwatch.de/baden-wuerttemberg'}},
#   {'id': 5,
#    'entity_type': 'parliament',
#    'label': 'Bundestag',
#    'api_url': 'https://www.abgeordnetenwatch.de/api/v2/parliaments/5',
#    'abgeordnetenwatch_url': 'https://www.abgeordnetenwatch.de/bundestag',
#    'label_external_long': 'Bundestag',
#    'current_project': {'id': 132,
#     'entity_type': 'parliament_period',
#     'label': 'Bundestag 2021 - 2025',
#     'api_url': 'https://www.abgeordnetenwatch.de/api/v2/parliament-periods/132',
#     'abgeordnetenwatch_url': 'https://www.abgeordnetenwatch.de/bundestag'}},
#   {'id': 4,
#    'entity_type': 'parliament',
#    'label': 'Nordrhein-Westfalen',
#    'api_url': 'https://www.abgeordnetenwatch.de/api/v2/parliaments/4',
#    'abgeordnetenwatch_url': 'https://www.abgeordnetenwatch.de/nordrhein-westfalen',
#    'label_external_long': 'Landtag Nordrhein-Westfalen',
#    'current_project': {'id': 139,
#     'entity_type': 'parliament_period',
#     'label': 'Nordrhein-Westfalen 2022 - 2027',
#     'api_url': 'https://www.abgeordnetenwatch.de/api/v2/parliament-periods/139',
#     'abgeordnetenwatch_url': 'https://www.abgeordnetenwatch.de/nordrhein-westfalen'}},
#   {'id': 3,
#    'entity_type': 'parliament',
#    'label': 'Hamburg',
#    'api_url': 'https://www.abgeordnetenwatch.de/api/v2/parliaments/3',
#    'abgeordnetenwatch_url': 'https://www.abgeordnetenwatch.de/hamburg',
#    'label_external_long': 'Bürgerschaft Hamburg',
#    'current_project': {'id': 122,
#     'entity_type': 'parliament_period',
#     'label': 'Hamburg 2020 - 2025',
#     'api_url': 'https://www.abgeordnetenwatch.de/api/v2/parliament-periods/122',
#     'abgeordnetenwatch_url': 'https://www.abgeordnetenwatch.de/hamburg'}},
#   {'id': 2,
#    'entity_type': 'parliament',
#    'label': 'Berlin',
#    'api_url': 'https://www.abgeordnetenwatch.de/api/v2/parliaments/2',
#    'abgeordnetenwatch_url': 'https://www.abgeordnetenwatch.de/berlin',
#    'label_external_long': 'Abgeordnetenhaus Berlin',
#    'current_project': {'id': 133,
#     'entity_type': 'parliament_period',
#     'label': 'Berlin 2021 - 2026',
#     'api_url': 'https://www.abgeordnetenwatch.de/api/v2/parliament-periods/133',
#     'abgeordnetenwatch_url': 'https://www.abgeordnetenwatch.de/berlin'}},
#   {'id': 1,
#    'entity_type': 'parliament',
#    'label': 'EU-Parlament',
#    'api_url': 'https://www.abgeordnetenwatch.de/api/v2/parliaments/1',
#    'abgeordnetenwatch_url': 'https://www.abgeordnetenwatch.de/eu',
#    'label_external_long': 'EU-Parlament',
#    'current_project': {'id': 117,
#     'entity_type': 'parliament_period',
#     'label': 'EU-Parlament 2019 - 2024',
#     'api_url': 'https://www.abgeordnetenwatch.de/api/v2/parliament-periods/117',
#     'abgeordnetenwatch_url': 'https://www.abgeordnetenwatch.de/eu'}}]}

# %%
 # For better handling
import json
print(json.dumps(parliaments, indent=4))
# Out:
# {
#     "meta": {
#         "abgeordnetenwatch_api": {
#             "version": "2.7",
#             "changelog": "https://www.abgeordnetenwatch.de/api/version-changelog/aktuell",
#             "licence": "CC0 1.0",
#             "licence_link": "https://creativecommons.org/publicdomain/zero/1.0/deed.de",
#             "documentation": "https://www.abgeordnetenwatch.de/api/entitaeten/parliament"
#         },
#         "status": "ok",
#         "status_message": "",
#         "result": {
#             "count": 18,
#             "total": 18,
#             "range_start": 0,
#             "range_end": 100
#         }
#     },
#     "data": [
#         {
#             "id": 18,
#             "entity_type": "parliament",
#             "label": "Schleswig-Holstein",
#             "api_url": "https://www.abgeordnetenwatch.de/api/v2/parliaments/18",
#             "abgeordnetenwatch_url": "https://www.abgeordnetenwatch.de/schleswig-holstein",
#             "label_external_long": "Landtag Schleswig-Holstein",
#             "current_project": {
#                 "id": 138,
#                 "entity_type": "parliament_period",
#                 "label": "Schleswig-Holstein 2022 - 2027",
#                 "api_url": "https://www.abgeordnetenwatch.de/api/v2/parliament-periods/138",
#                 "abgeordnetenwatch_url": "https://www.abgeordnetenwatch.de/schleswig-holstein"
#             }
#         },
#         {
#             "id": 17,
#             "entity_type": "parliament",
#             "label": "Sachsen",
#             "api_url": "https://www.abgeordnetenwatch.de/api/v2/parliaments/17",
#             "abgeordnetenwatch_url": "https://www.abgeordnetenwatch.de/sachsen",
#             "label_external_long": "Landtag Sachsen",
#             "current_project": {
#                 "id": 119,
#                 "entity_type": "parliament_period",
#                 "label": "Sachsen 2019 - 2024",
#                 "api_url": "https://www.abgeordnetenwatch.de/api/v2/parliament-periods/119",
#                 "abgeordnetenwatch_url": "https://www.abgeordnetenwatch.de/sachsen"
#             }
#         },
#         {
#             "id": 16,
#             "entity_type": "parliament",
#             "label": "Brandenburg",
#             "api_url": "https://www.abgeordnetenwatch.de/api/v2/parliaments/16",
#             "abgeordnetenwatch_url": "https://www.abgeordnetenwatch.de/brandenburg",
#             "label_external_long": "Landtag Brandenburg",
#             "current_project": {
#                 "id": 120,
#                 "entity_type": "parliament_period",
#                 "label": "Brandenburg 2019 - 2024",
#                 "api_url": "https://www.abgeordnetenwatch.de/api/v2/parliament-periods/120",
#                 "abgeordnetenwatch_url": "https://www.abgeordnetenwatch.de/brandenburg"
#             }
#         },
#         {
#             "id": 15,
#             "entity_type": "parliament",
#             "label": "Th\u00fcringen",
#             "api_url": "https://www.abgeordnetenwatch.de/api/v2/parliaments/15",
#             "abgeordnetenwatch_url": "https://www.abgeordnetenwatch.de/thueringen",
#             "label_external_long": "Landtag Th\u00fcringen",
#             "current_project": {
#                 "id": 121,
#                 "entity_type": "parliament_period",
#                 "label": "Th\u00fcringen 2019 - 2024",
#                 "api_url": "https://www.abgeordnetenwatch.de/api/v2/parliament-periods/121",
#                 "abgeordnetenwatch_url": "https://www.abgeordnetenwatch.de/thueringen"
#             }
#         },
#         {
#             "id": 14,
#             "entity_type": "parliament",
#             "label": "Saarland",
#             "api_url": "https://www.abgeordnetenwatch.de/api/v2/parliaments/14",
#             "abgeordnetenwatch_url": "https://www.abgeordnetenwatch.de/saarland",
#             "label_external_long": "Landtag Saarland",
#             "current_project": {
#                 "id": 137,
#                 "entity_type": "parliament_period",
#                 "label": "Saarland 2022 - 2027",
#                 "api_url": "https://www.abgeordnetenwatch.de/api/v2/parliament-periods/137",
#                 "abgeordnetenwatch_url": "https://www.abgeordnetenwatch.de/saarland"
#             }
#         },
#         {
#             "id": 13,
#             "entity_type": "parliament",
#             "label": "Bayern",
#             "api_url": "https://www.abgeordnetenwatch.de/api/v2/parliaments/13",
#             "abgeordnetenwatch_url": "https://www.abgeordnetenwatch.de/bayern",
#             "label_external_long": "Landtag Bayern",
#             "current_project": {
#                 "id": 147,
#                 "entity_type": "parliament_period",
#                 "label": "Bayern Wahl 2023",
#                 "api_url": "https://www.abgeordnetenwatch.de/api/v2/parliament-periods/147",
#                 "abgeordnetenwatch_url": "https://www.abgeordnetenwatch.de/bayern"
#             }
#         },
#         {
#             "id": 12,
#             "entity_type": "parliament",
#             "label": "Niedersachsen",
#             "api_url": "https://www.abgeordnetenwatch.de/api/v2/parliaments/12",
#             "abgeordnetenwatch_url": "https://www.abgeordnetenwatch.de/niedersachsen",
#             "label_external_long": "Landtag Niedersachsen",
#             "current_project": {
#                 "id": 143,
#                 "entity_type": "parliament_period",
#                 "label": "Niedersachsen 2022 - 2027",
#                 "api_url": "https://www.abgeordnetenwatch.de/api/v2/parliament-periods/143",
#                 "abgeordnetenwatch_url": "https://www.abgeordnetenwatch.de/niedersachsen"
#             }
#         },
#         {
#             "id": 11,
#             "entity_type": "parliament",
#             "label": "Hessen",
#             "api_url": "https://www.abgeordnetenwatch.de/api/v2/parliaments/11",
#             "abgeordnetenwatch_url": "https://www.abgeordnetenwatch.de/hessen",
#             "label_external_long": "Landtag Hessen",
#             "current_project": {
#                 "id": 148,
#                 "entity_type": "parliament_period",
#                 "label": "Hessen Wahl 2023",
#                 "api_url": "https://www.abgeordnetenwatch.de/api/v2/parliament-periods/148",
#                 "abgeordnetenwatch_url": "https://www.abgeordnetenwatch.de/hessen"
#             }
#         },
#         {
#             "id": 10,
#             "entity_type": "parliament",
#             "label": "Bremen",
#             "api_url": "https://www.abgeordnetenwatch.de/api/v2/parliaments/10",
#             "abgeordnetenwatch_url": "https://www.abgeordnetenwatch.de/bremen",
#             "label_external_long": "B\u00fcrgerschaft Bremen",
#             "current_project": {
#                 "id": 146,
#                 "entity_type": "parliament_period",
#                 "label": "Bremen 2023 - 2027",
#                 "api_url": "https://www.abgeordnetenwatch.de/api/v2/parliament-periods/146",
#                 "abgeordnetenwatch_url": "https://www.abgeordnetenwatch.de/bremen"
#             }
#         },
#         {
#             "id": 9,
#             "entity_type": "parliament",
#             "label": "Mecklenburg-Vorpommern",
#             "api_url": "https://www.abgeordnetenwatch.de/api/v2/parliaments/9",
#             "abgeordnetenwatch_url": "https://www.abgeordnetenwatch.de/mecklenburg-vorpommern",
#             "label_external_long": "Landtag Mecklenburg-Vorpommern",
#             "current_project": {
#                 "id": 134,
#                 "entity_type": "parliament_period",
#                 "label": "Mecklenburg-Vorpommern 2021 - 2026",
#                 "api_url": "https://www.abgeordnetenwatch.de/api/v2/parliament-periods/134",
#                 "abgeordnetenwatch_url": "https://www.abgeordnetenwatch.de/mecklenburg-vorpommern"
#             }
#         },
#         {
#             "id": 8,
#             "entity_type": "parliament",
#             "label": "Sachsen-Anhalt",
#             "api_url": "https://www.abgeordnetenwatch.de/api/v2/parliaments/8",
#             "abgeordnetenwatch_url": "https://www.abgeordnetenwatch.de/sachsen-anhalt",
#             "label_external_long": "Landtag Sachsen-Anhalt",
#             "current_project": {
#                 "id": 131,
#                 "entity_type": "parliament_period",
#                 "label": "Sachsen-Anhalt 2021 - 2026",
#                 "api_url": "https://www.abgeordnetenwatch.de/api/v2/parliament-periods/131",
#                 "abgeordnetenwatch_url": "https://www.abgeordnetenwatch.de/sachsen-anhalt"
#             }
#         },
#         {
#             "id": 7,
#             "entity_type": "parliament",
#             "label": "Rheinland-Pfalz",
#             "api_url": "https://www.abgeordnetenwatch.de/api/v2/parliaments/7",
#             "abgeordnetenwatch_url": "https://www.abgeordnetenwatch.de/rheinland-pfalz",
#             "label_external_long": "Landtag Rheinland-Pfalz",
#             "current_project": {
#                 "id": 127,
#                 "entity_type": "parliament_period",
#                 "label": "Rheinland-Pfalz 2021 - 2026",
#                 "api_url": "https://www.abgeordnetenwatch.de/api/v2/parliament-periods/127",
#                 "abgeordnetenwatch_url": "https://www.abgeordnetenwatch.de/rheinland-pfalz"
#             }
#         },
#         {
#             "id": 6,
#             "entity_type": "parliament",
#             "label": "Baden-W\u00fcrttemberg",
#             "api_url": "https://www.abgeordnetenwatch.de/api/v2/parliaments/6",
#             "abgeordnetenwatch_url": "https://www.abgeordnetenwatch.de/baden-wuerttemberg",
#             "label_external_long": "Landtag Baden-W\u00fcrttemberg",
#             "current_project": {
#                 "id": 126,
#                 "entity_type": "parliament_period",
#                 "label": "Baden-W\u00fcrttemberg 2021 - 2026",
#                 "api_url": "https://www.abgeordnetenwatch.de/api/v2/parliament-periods/126",
#                 "abgeordnetenwatch_url": "https://www.abgeordnetenwatch.de/baden-wuerttemberg"
#             }
#         },
#         {
#             "id": 5,
#             "entity_type": "parliament",
#             "label": "Bundestag",
#             "api_url": "https://www.abgeordnetenwatch.de/api/v2/parliaments/5",
#             "abgeordnetenwatch_url": "https://www.abgeordnetenwatch.de/bundestag",
#             "label_external_long": "Bundestag",
#             "current_project": {
#                 "id": 132,
#                 "entity_type": "parliament_period",
#                 "label": "Bundestag 2021 - 2025",
#                 "api_url": "https://www.abgeordnetenwatch.de/api/v2/parliament-periods/132",
#                 "abgeordnetenwatch_url": "https://www.abgeordnetenwatch.de/bundestag"
#             }
#         },
#         {
#             "id": 4,
#             "entity_type": "parliament",
#             "label": "Nordrhein-Westfalen",
#             "api_url": "https://www.abgeordnetenwatch.de/api/v2/parliaments/4",
#             "abgeordnetenwatch_url": "https://www.abgeordnetenwatch.de/nordrhein-westfalen",
#             "label_external_long": "Landtag Nordrhein-Westfalen",
#             "current_project": {
#                 "id": 139,
#                 "entity_type": "parliament_period",
#                 "label": "Nordrhein-Westfalen 2022 - 2027",
#                 "api_url": "https://www.abgeordnetenwatch.de/api/v2/parliament-periods/139",
#                 "abgeordnetenwatch_url": "https://www.abgeordnetenwatch.de/nordrhein-westfalen"
#             }
#         },
#         {
#             "id": 3,
#             "entity_type": "parliament",
#             "label": "Hamburg",
#             "api_url": "https://www.abgeordnetenwatch.de/api/v2/parliaments/3",
#             "abgeordnetenwatch_url": "https://www.abgeordnetenwatch.de/hamburg",
#             "label_external_long": "B\u00fcrgerschaft Hamburg",
#             "current_project": {
#                 "id": 122,
#                 "entity_type": "parliament_period",
#                 "label": "Hamburg 2020 - 2025",
#                 "api_url": "https://www.abgeordnetenwatch.de/api/v2/parliament-periods/122",
#                 "abgeordnetenwatch_url": "https://www.abgeordnetenwatch.de/hamburg"
#             }
#         },
#         {
#             "id": 2,
#             "entity_type": "parliament",
#             "label": "Berlin",
#             "api_url": "https://www.abgeordnetenwatch.de/api/v2/parliaments/2",
#             "abgeordnetenwatch_url": "https://www.abgeordnetenwatch.de/berlin",
#             "label_external_long": "Abgeordnetenhaus Berlin",
#             "current_project": {
#                 "id": 133,
#                 "entity_type": "parliament_period",
#                 "label": "Berlin 2021 - 2026",
#                 "api_url": "https://www.abgeordnetenwatch.de/api/v2/parliament-periods/133",
#                 "abgeordnetenwatch_url": "https://www.abgeordnetenwatch.de/berlin"
#             }
#         },
#         {
#             "id": 1,
#             "entity_type": "parliament",
#             "label": "EU-Parlament",
#             "api_url": "https://www.abgeordnetenwatch.de/api/v2/parliaments/1",
#             "abgeordnetenwatch_url": "https://www.abgeordnetenwatch.de/eu",
#             "label_external_long": "EU-Parlament",
#             "current_project": {
#                 "id": 117,
#                 "entity_type": "parliament_period",
#                 "label": "EU-Parlament 2019 - 2024",
#                 "api_url": "https://www.abgeordnetenwatch.de/api/v2/parliament-periods/117",
#                 "abgeordnetenwatch_url": "https://www.abgeordnetenwatch.de/eu"
#             }
#         }
#     ]
# }

# %% [markdown]
# Let's inspect the stuff inside our results.

# %%
parliaments.keys()
# Out:
# dict_keys(['meta', 'data'])

# %%
parliaments['meta']
# Out:
# {'abgeordnetenwatch_api': {'version': '2.7',
#   'changelog': 'https://www.abgeordnetenwatch.de/api/version-changelog/aktuell',
#   'licence': 'CC0 1.0',
#   'licence_link': 'https://creativecommons.org/publicdomain/zero/1.0/deed.de',
#   'documentation': 'https://www.abgeordnetenwatch.de/api/entitaeten/parliament'},
#  'status': 'ok',
#  'status_message': '',
#  'result': {'count': 18, 'total': 18, 'range_start': 0, 'range_end': 100}}

# %% [markdown]
# Save your results!

# %%
with open('21_parliaments.p', 'wb') as f:
    pickle.dump(parliaments, f)

# %%
with open('21_parliaments.p', 'rb') as f:
    parliaments = pickle.load(f)

# %% [markdown]
# We can check for specific conditions, e.g., particular states' information.

# %%
for i in parliaments['data']:
    if i['label'] == 'Nordrhein-Westfalen':
        print(i['api_url'])
# Out:
# https://www.abgeordnetenwatch.de/api/v2/parliaments/4

# %%
for i in parliaments['data']:
    if i['label'] == 'Nordrhein-Westfalen':
        print(i['current_project']['api_url'])
# Out:
# https://www.abgeordnetenwatch.de/api/v2/parliament-periods/139

# %% [markdown]
# Now, let's get some data about politicians
#
# https://www.abgeordnetenwatch.de/api/v2/politicians  !

# %%
requests.get(url="https://www.abgeordnetenwatch.de/api/v2/politicians").json()
# Out:
# {'meta': {'abgeordnetenwatch_api': {'version': '2.7',
#    'changelog': 'https://www.abgeordnetenwatch.de/api/version-changelog/aktuell',
#    'licence': 'CC0 1.0',
#    'licence_link': 'https://creativecommons.org/publicdomain/zero/1.0/deed.de',
#    'documentation': 'https://www.abgeordnetenwatch.de/api/entitaeten/politician'},
#   'status': 'ok',
#   'status_message': '',
#   'result': {'count': 100,
#    'total': 32082,
#    'range_start': 0,
#    'range_end': 100}},
#  'data': [{'id': 180755,
#    'entity_type': 'politician',
#    'label': 'Dennis Klecker',
#    'api_url': 'https://www.abgeordnetenwatch.de/api/v2/politicians/180755',
#    'abgeordnetenwatch_url': 'https://www.abgeordnetenwatch.de/profile/dennis-klecker',
#    'first_name': 'Dennis',
#    'last_name': 'Klecker',
#    'birth_name': None,
#    'sex': 'm',
#    'year_of_birth': 1990,
#    'party': {'id': 9,
#     'entity_type': 'party',
#     'label': 'AfD',
#     'api_url': 'https://www.abgeordnetenwatch.de/api/v2/parties/9'},
#    'party_past': None,
#    'education': 'Werkfeuerwehrmann',
#    'residence': 'Ilsfeld',
#    'occupation': 'MdL',
#    'statistic_questions': None,
#    'statistic_questions_answered': None,
#    'ext_id_bundestagsverwaltung': None,
#    'qid_wikidata': None,
#    'field_title': None},
#   {'id': 180754,
#    'entity_type': 'politician',
#    'label': 'Leo Puddu',
#    'api_url': 'https://www.abgeordnetenwatch.de/api/v2/politicians/180754',
#    'abgeordnetenwatch_url': 'https://www.abgeordnetenwatch.de/profile/leo-puddu',
#    'first_name': 'Leo',
#    'last_name': 'Puddu',
#    'birth_name': None,
#    'sex': 'm',
#    'year_of_birth': 1966,
#    'party': {'id': 201,
#     'entity_type': 'party',
#     'label': 'dieBasis',
#     'api_url': 'https://www.abgeordnetenwatch.de/api/v2/parties/201'},
#    'party_past': None,
#    'education': None,
#    'residence': 'Limburg',
#    'occupation': 'Vertriebsmitarbeiter',
#    'statistic_questions': 1,
#    'statistic_questions_answered': 1,
#    'ext_id_bundestagsverwaltung': None,
#    'qid_wikidata': None,
#    'field_title': None},
#   {'id': 180753,
#    'entity_type': 'politician',
#    'label': 'Matthias Lißmann',
#    'api_url': 'https://www.abgeordnetenwatch.de/api/v2/politicians/180753',
#    'abgeordnetenwatch_url': 'https://www.abgeordnetenwatch.de/profile/matthias-lissmann',
#    'first_name': 'Matthias',
#    'last_name': 'Lißmann',
#    'birth_name': None,
#    'sex': 'm',
#    'year_of_birth': None,
#    'party': {'id': 16,
#     'entity_type': 'party',
#     'label': 'Die PARTEI',
#     'api_url': 'https://www.abgeordnetenwatch.de/api/v2/parties/16'},
#    'party_past': None,
#    'education': None,
#    'residence': 'Gauting',
#    'occupation': 'Textilbetriebswirt',
#    'statistic_questions': None,
#    'statistic_questions_answered': None,
#    'ext_id_bundestagsverwaltung': None,
#    'qid_wikidata': None,
#    'field_title': None},
#   {'id': 180752,
#    'entity_type': 'politician',
#    'label': 'Michael Herber',
#    'api_url': 'https://www.abgeordnetenwatch.de/api/v2/politicians/180752',
#    'abgeordnetenwatch_url': 'https://www.abgeordnetenwatch.de/profile/michael-herber',
#    'first_name': 'Michael',
#    'last_name': 'Herber',
#    'birth_name': None,
#    'sex': 'm',
#    'year_of_birth': None,
#    'party': {'id': 16,
#     'entity_type': 'party',
#     'label': 'Die PARTEI',
#     'api_url': 'https://www.abgeordnetenwatch.de/api/v2/parties/16'},
#    'party_past': None,
#    'education': None,
#    'residence': 'Pfaffenhofen a.d.Ilm',
#    'occupation': 'IT-Prozessmanager',
#    'statistic_questions': None,
#    'statistic_questions_answered': None,
#    'ext_id_bundestagsverwaltung': None,
#    'qid_wikidata': None,
#    'field_title': None},
#   {'id': 180751,
#    'entity_type': 'politician',
#    'label': 'Gabriele Käsler',
#    'api_url': 'https://www.abgeordnetenwatch.de/api/v2/politicians/180751',
#    'abgeordnetenwatch_url': 'https://www.abgeordnetenwatch.de/profile/gabriele-kaesler',
#    'first_name': 'Gabriele',
#    'last_name': 'Käsler',
#    'birth_name': None,
#    'sex': None,
#    'year_of_birth': None,
#    'party': {'id': 16,
#     'entity_type': 'party',
#     'label': 'Die PARTEI',
#     'api_url': 'https://www.abgeordnetenwatch.de/api/v2/parties/16'},
#    'party_past': None,
#    'education': None,
#    'residence': 'Königsmoos',
#    'occupation': None,
#    'statistic_questions': None,
#    'statistic_questions_answered': None,
#    'ext_id_bundestagsverwaltung': None,
#    'qid_wikidata': None,
#    'field_title': None},
#   {'id': 180750,
#    'entity_type': 'politician',
#    'label': 'Kilian Ponschab',
#    'api_url': 'https://www.abgeordnetenwatch.de/api/v2/politicians/180750',
#    'abgeordnetenwatch_url': 'https://www.abgeordnetenwatch.de/profile/kilian-ponschab',
#    'first_name': 'Kilian',
#    'last_name': 'Ponschab',
#    'birth_name': None,
#    'sex': 'm',
#    'year_of_birth': None,
#    'party': {'id': 16,
#     'entity_type': 'party',
#     'label': 'Die PARTEI',
#     'api_url': 'https://www.abgeordnetenwatch.de/api/v2/parties/16'},
#    'party_past': None,
#    'education': None,
#    'residence': 'Böhmfeld',
#    'occupation': 'Industriemechaniker',
#    'statistic_questions': 1,
#    'statistic_questions_answered': None,
#    'ext_id_bundestagsverwaltung': None,
#    'qid_wikidata': None,
#    'field_title': None},
#   {'id': 180749,
#    'entity_type': 'politician',
#    'label': 'Katharina Erdrich',
#    'api_url': 'https://www.abgeordnetenwatch.de/api/v2/politicians/180749',
#    'abgeordnetenwatch_url': 'https://www.abgeordnetenwatch.de/profile/katharina-erdrich',
#    'first_name': 'Katharina',
#    'last_name': 'Erdrich',
#    'birth_name': None,
#    'sex': 'f',
#    'year_of_birth': None,
#    'party': {'id': 16,
#     'entity_type': 'party',
#     'label': 'Die PARTEI',
#     'api_url': 'https://www.abgeordnetenwatch.de/api/v2/parties/16'},
#    'party_past': None,
#    'education': None,
#    'residence': 'München',
#    'occupation': 'Studentin',
#    'statistic_questions': None,
#    'statistic_questions_answered': None,
#    'ext_id_bundestagsverwaltung': None,
#    'qid_wikidata': None,
#    'field_title': None},
#   {'id': 180748,
#    'entity_type': 'politician',
#    'label': 'Tobias Bauerfeind',
#    'api_url': 'https://www.abgeordnetenwatch.de/api/v2/politicians/180748',
#    'abgeordnetenwatch_url': 'https://www.abgeordnetenwatch.de/profile/tobias-bauerfeind',
#    'first_name': 'Tobias',
#    'last_name': 'Bauerfeind',
#    'birth_name': None,
#    'sex': 'm',
#    'year_of_birth': None,
#    'party': {'id': 16,
#     'entity_type': 'party',
#     'label': 'Die PARTEI',
#     'api_url': 'https://www.abgeordnetenwatch.de/api/v2/parties/16'},
#    'party_past': None,
#    'education': None,
#    'residence': 'München',
#    'occupation': 'Mathematiker',
#    'statistic_questions': None,
#    'statistic_questions_answered': None,
#    'ext_id_bundestagsverwaltung': None,
#    'qid_wikidata': None,
#    'field_title': None},
#   {'id': 180747,
#    'entity_type': 'politician',
#    'label': 'Sercan Bünyamin Yolcu',
#    'api_url': 'https://www.abgeordnetenwatch.de/api/v2/politicians/180747',
#    'abgeordnetenwatch_url': 'https://www.abgeordnetenwatch.de/profile/sercan-buenyamin-yolcu',
#    'first_name': 'Sercan Bünyamin',
#    'last_name': 'Yolcu',
#    'birth_name': None,
#    'sex': 'm',
#    'year_of_birth': 1994,
#    'party': {'id': 16,
#     'entity_type': 'party',
#     'label': 'Die PARTEI',
#     'api_url': 'https://www.abgeordnetenwatch.de/api/v2/parties/16'},
#    'party_past': None,
#    'education': None,
#    'residence': 'Kempten',
#    'occupation': 'Elektroniker',
#    'statistic_questions': 1,
#    'statistic_questions_answered': 1,
#    'ext_id_bundestagsverwaltung': None,
#    'qid_wikidata': None,
#    'field_title': None},
#   {'id': 180746,
#    'entity_type': 'politician',
#    'label': 'Anja Klingelhöfer',
#    'api_url': 'https://www.abgeordnetenwatch.de/api/v2/politicians/180746',
#    'abgeordnetenwatch_url': 'https://www.abgeordnetenwatch.de/profile/anja-klingelhoefer',
#    'first_name': 'Anja',
#    'last_name': 'Klingelhöfer',
#    'birth_name': None,
#    'sex': 'f',
#    'year_of_birth': 1982,
#    'party': {'id': 16,
#     'entity_type': 'party',
#     'label': 'Die PARTEI',
#     'api_url': 'https://www.abgeordnetenwatch.de/api/v2/parties/16'},
#    'party_past': None,
#    'education': None,
#    'residence': 'Augsburg',
#    'occupation': 'Ausbilderin',
#    'statistic_questions': None,
#    'statistic_questions_answered': None,
#    'ext_id_bundestagsverwaltung': None,
#    'qid_wikidata': None,
#    'field_title': None},
#   {'id': 180745,
#    'entity_type': 'politician',
#    'label': 'Stefan Bob Meitinger',
#    'api_url': 'https://www.abgeordnetenwatch.de/api/v2/politicians/180745',
#    'abgeordnetenwatch_url': 'https://www.abgeordnetenwatch.de/profile/stefan-bob-meitinger',
#    'first_name': 'Stefan Bob',
#    'last_name': 'Meitinger',
#    'birth_name': None,
#    'sex': 'm',
#    'year_of_birth': 1969,
#    'party': {'id': 16,
#     'entity_type': 'party',
#     'label': 'Die PARTEI',
#     'api_url': 'https://www.abgeordnetenwatch.de/api/v2/parties/16'},
#    'party_past': None,
#    'education': None,
#    'residence': 'Augsburg',
#    'occupation': 'Gastronom',
#    'statistic_questions': None,
#    'statistic_questions_answered': None,
#    'ext_id_bundestagsverwaltung': None,
#    'qid_wikidata': None,
#    'field_title': None},
#   {'id': 180744,
#    'entity_type': 'politician',
#    'label': 'Lisa McQueen',
#    'api_url': 'https://www.abgeordnetenwatch.de/api/v2/politicians/180744',
#    'abgeordnetenwatch_url': 'https://www.abgeordnetenwatch.de/profile/lisa-mcqueen',
#    'first_name': 'Lisa',
#    'last_name': 'McQueen',
#    'birth_name': None,
#    'sex': 'f',
#    'year_of_birth': 1990,
#    'party': {'id': 16,
#     'entity_type': 'party',
#     'label': 'Die PARTEI',
#     'api_url': 'https://www.abgeordnetenwatch.de/api/v2/parties/16'},
#    'party_past': None,
#    'education': None,
#    'residence': 'Augsburg',
#    'occupation': 'Gastronomin',
#    'statistic_questions': None,
#    'statistic_questions_answered': None,
#    'ext_id_bundestagsverwaltung': None,
#    'qid_wikidata': None,
#    'field_title': None},
#   {'id': 180743,
#    'entity_type': 'politician',
#    'label': 'Ingeborg Groebel',
#    'api_url': 'https://www.abgeordnetenwatch.de/api/v2/politicians/180743',
#    'abgeordnetenwatch_url': 'https://www.abgeordnetenwatch.de/profile/ingeborg-groebel',
#    'first_name': 'Ingeborg',
#    'last_name': 'Groebel',
#    'birth_name': None,
#    'sex': 'f',
#    'year_of_birth': 1967,
#    'party': {'id': 1,
#     'entity_type': 'party',
#     'label': 'SPD',
#     'api_url': 'https://www.abgeordnetenwatch.de/api/v2/parties/1'},
#    'party_past': None,
#    'education': 'Dipl.-Politologin',
#    'residence': 'Wiesbaden',
#    'occupation': 'Leiterin Bildungsbüro Stadt Wiesbaden ',
#    'statistic_questions': 1,
#    'statistic_questions_answered': 1,
#    'ext_id_bundestagsverwaltung': None,
#    'qid_wikidata': None,
#    'field_title': None},
#   {'id': 180742,
#    'entity_type': 'politician',
#    'label': 'Elke Homm-Vogel',
#    'api_url': 'https://www.abgeordnetenwatch.de/api/v2/politicians/180742',
#    'abgeordnetenwatch_url': 'https://www.abgeordnetenwatch.de/profile/elke-homm-vogel',
#    'first_name': 'Elke',
#    'last_name': 'Homm-Vogel',
#    'birth_name': None,
#    'sex': 'f',
#    'year_of_birth': None,
#    'party': {'id': 7,
#     'entity_type': 'party',
#     'label': 'FREIE WÄHLER',
#     'api_url': 'https://www.abgeordnetenwatch.de/api/v2/parties/7'},
#    'party_past': None,
#    'education': None,
#    'residence': 'Ansbach',
#    'occupation': 'Angestellte',
#    'statistic_questions': None,
#    'statistic_questions_answered': None,
#    'ext_id_bundestagsverwaltung': None,
#    'qid_wikidata': None,
#    'field_title': None},
#   {'id': 180741,
#    'entity_type': 'politician',
#    'label': 'Martin Köppl',
#    'api_url': 'https://www.abgeordnetenwatch.de/api/v2/politicians/180741',
#    'abgeordnetenwatch_url': 'https://www.abgeordnetenwatch.de/profile/martin-koeppl',
#    'first_name': 'Martin',
#    'last_name': 'Köppl',
#    'birth_name': None,
#    'sex': 'm',
#    'year_of_birth': None,
#    'party': {'id': 9,
#     'entity_type': 'party',
#     'label': 'AfD',
#     'api_url': 'https://www.abgeordnetenwatch.de/api/v2/parties/9'},
#    'party_past': None,
#    'education': None,
#    'residence': None,
#    'occupation': 'Patentassessor',
#    'statistic_questions': None,
#    'statistic_questions_answered': None,
#    'ext_id_bundestagsverwaltung': None,
#    'qid_wikidata': None,
#    'field_title': None},
#   {'id': 180740,
#    'entity_type': 'politician',
#    'label': 'Jürgen Euler',
#    'api_url': 'https://www.abgeordnetenwatch.de/api/v2/politicians/180740',
#    'abgeordnetenwatch_url': 'https://www.abgeordnetenwatch.de/profile/juergen-euler',
#    'first_name': 'Jürgen',
#    'last_name': 'Euler',
#    'birth_name': None,
#    'sex': 'm',
#    'year_of_birth': 1966,
#    'party': {'id': 227,
#     'entity_type': 'party',
#     'label': 'Praktiker Partei',
#     'api_url': 'https://www.abgeordnetenwatch.de/api/v2/parties/227'},
#    'party_past': None,
#    'education': None,
#    'residence': 'Schwalmtal',
#    'occupation': 'Landwirt',
#    'statistic_questions': 3,
#    'statistic_questions_answered': None,
#    'ext_id_bundestagsverwaltung': None,
#    'qid_wikidata': None,
#    'field_title': None},
#   {'id': 180739,
#    'entity_type': 'politician',
#    'label': 'Mustfa Saleh',
#    'api_url': 'https://www.abgeordnetenwatch.de/api/v2/politicians/180739',
#    'abgeordnetenwatch_url': 'https://www.abgeordnetenwatch.de/profile/mustfa-saleh',
#    'first_name': 'Mustfa',
#    'last_name': 'Saleh',
#    'birth_name': None,
#    'sex': 'm',
#    'year_of_birth': 1993,
#    'party': {'id': 228,
#     'entity_type': 'party',
#     'label': 'Wählergruppe Solidaritätsbewegung',
#     'api_url': 'https://www.abgeordnetenwatch.de/api/v2/parties/228'},
#    'party_past': None,
#    'education': None,
#    'residence': 'Kassel',
#    'occupation': 'Student',
#    'statistic_questions': 1,
#    'statistic_questions_answered': None,
#    'ext_id_bundestagsverwaltung': None,
#    'qid_wikidata': None,
#    'field_title': None},
#   {'id': 180738,
#    'entity_type': 'politician',
#    'label': 'Abdullhadi Husein',
#    'api_url': 'https://www.abgeordnetenwatch.de/api/v2/politicians/180738',
#    'abgeordnetenwatch_url': 'https://www.abgeordnetenwatch.de/profile/abdullhadi-husein',
#    'first_name': 'Abdullhadi',
#    'last_name': 'Husein',
#    'birth_name': None,
#    'sex': 'm',
#    'year_of_birth': None,
#    'party': {'id': 228,
#     'entity_type': 'party',
#     'label': 'Wählergruppe Solidaritätsbewegung',
#     'api_url': 'https://www.abgeordnetenwatch.de/api/v2/parties/228'},
#    'party_past': None,
#    'education': None,
#    'residence': None,
#    'occupation': None,
#    'statistic_questions': 1,
#    'statistic_questions_answered': None,
#    'ext_id_bundestagsverwaltung': None,
#    'qid_wikidata': None,
#    'field_title': None},
#   {'id': 180737,
#    'entity_type': 'politician',
#    'label': 'Jürgen Menzel',
#    'api_url': 'https://www.abgeordnetenwatch.de/api/v2/politicians/180737',
#    'abgeordnetenwatch_url': 'https://www.abgeordnetenwatch.de/profile/juergen-menzel-0',
#    'first_name': 'Jürgen',
#    'last_name': 'Menzel',
#    'birth_name': None,
#    'sex': 'm',
#    'year_of_birth': 1966,
#    'party': {'id': 4,
#     'entity_type': 'party',
#     'label': 'FDP',
#     'api_url': 'https://www.abgeordnetenwatch.de/api/v2/parties/4'},
#    'party_past': None,
#    'education': None,
#    'residence': 'Kassel',
#    'occupation': 'Restaurantmanager',
#    'statistic_questions': 1,
#    'statistic_questions_answered': None,
#    'ext_id_bundestagsverwaltung': None,
#    'qid_wikidata': None,
#    'field_title': None},
#   {'id': 180736,
#    'entity_type': 'politician',
#    'label': 'Manuela Ernst',
#    'api_url': 'https://www.abgeordnetenwatch.de/api/v2/politicians/180736',
#    'abgeordnetenwatch_url': 'https://www.abgeordnetenwatch.de/profile/manuela-ernst',
#    'first_name': 'Manuela',
#    'last_name': 'Ernst',
#    'birth_name': None,
#    'sex': 'f',
#    'year_of_birth': 1974,
#    'party': {'id': 4,
#     'entity_type': 'party',
#     'label': 'FDP',
#     'api_url': 'https://www.abgeordnetenwatch.de/api/v2/parties/4'},
#    'party_past': None,
#    'education': None,
#    'residence': 'Kassel',
#    'occupation': None,
#    'statistic_questions': 1,
#    'statistic_questions_answered': None,
#    'ext_id_bundestagsverwaltung': None,
#    'qid_wikidata': None,
#    'field_title': None},
#   {'id': 180735,
#    'entity_type': 'politician',
#    'label': 'Norbert Taufertshöfer',
#    'api_url': 'https://www.abgeordnetenwatch.de/api/v2/politicians/180735',
#    'abgeordnetenwatch_url': 'https://www.abgeordnetenwatch.de/profile/norbert-taufertshoefer',
#    'first_name': 'Norbert',
#    'last_name': 'Taufertshöfer',
#    'birth_name': None,
#    'sex': 'm',
#    'year_of_birth': 1952,
#    'party': {'id': 9,
#     'entity_type': 'party',
#     'label': 'AfD',
#     'api_url': 'https://www.abgeordnetenwatch.de/api/v2/parties/9'},
#    'party_past': None,
#    'education': 'Dipl.-Ingenieur',
#    'residence': 'Heppenheim',
#    'occupation': None,
#    'statistic_questions': 2,
#    'statistic_questions_answered': 2,
#    'ext_id_bundestagsverwaltung': None,
#    'qid_wikidata': None,
#    'field_title': None},
#   {'id': 180734,
#    'entity_type': 'politician',
#    'label': 'Bernd Engemann',
#    'api_url': 'https://www.abgeordnetenwatch.de/api/v2/politicians/180734',
#    'abgeordnetenwatch_url': 'https://www.abgeordnetenwatch.de/profile/bernd-engemann',
#    'first_name': 'Bernd',
#    'last_name': 'Engemann',
#    'birth_name': None,
#    'sex': 'm',
#    'year_of_birth': 1949,
#    'party': {'id': 9,
#     'entity_type': 'party',
#     'label': 'AfD',
#     'api_url': 'https://www.abgeordnetenwatch.de/api/v2/parties/9'},
#    'party_past': None,
#    'education': 'Dipl.-Ingenieur',
#    'residence': 'Michelstadt',
#    'occupation': None,
#    'statistic_questions': None,
#    'statistic_questions_answered': None,
#    'ext_id_bundestagsverwaltung': None,
#    'qid_wikidata': None,
#    'field_title': 'Dr.'},
#   {'id': 180733,
#    'entity_type': 'politician',
#    'label': 'Steffen Beese',
#    'api_url': 'https://www.abgeordnetenwatch.de/api/v2/politicians/180733',
#    'abgeordnetenwatch_url': 'https://www.abgeordnetenwatch.de/profile/steffen-beese',
#    'first_name': 'Steffen',
#    'last_name': 'Beese',
#    'birth_name': None,
#    'sex': 'm',
#    'year_of_birth': 1987,
#    'party': {'id': 9,
#     'entity_type': 'party',
#     'label': 'AfD',
#     'api_url': 'https://www.abgeordnetenwatch.de/api/v2/parties/9'},
#    'party_past': None,
#    'education': None,
#    'residence': 'Elz',
#    'occupation': 'Kupolofenwerker',
#    'statistic_questions': None,
#    'statistic_questions_answered': None,
#    'ext_id_bundestagsverwaltung': None,
#    'qid_wikidata': None,
#    'field_title': None},
#   {'id': 180732,
#    'entity_type': 'politician',
#    'label': 'Gregor Ickert',
#    'api_url': 'https://www.abgeordnetenwatch.de/api/v2/politicians/180732',
#    'abgeordnetenwatch_url': 'https://www.abgeordnetenwatch.de/profile/gregor-ickert',
#    'first_name': 'Gregor',
#    'last_name': 'Ickert',
#    'birth_name': None,
#    'sex': 'm',
#    'year_of_birth': 1956,
#    'party': {'id': 9,
#     'entity_type': 'party',
#     'label': 'AfD',
#     'api_url': 'https://www.abgeordnetenwatch.de/api/v2/parties/9'},
#    'party_past': None,
#    'education': None,
#    'residence': 'Meißner',
#    'occupation': 'Rentner',
#    'statistic_questions': None,
#    'statistic_questions_answered': None,
#    'ext_id_bundestagsverwaltung': None,
#    'qid_wikidata': None,
#    'field_title': None},
#   {'id': 180730,
#    'entity_type': 'politician',
#    'label': 'Olaf Margraf',
#    'api_url': 'https://www.abgeordnetenwatch.de/api/v2/politicians/180730',
#    'abgeordnetenwatch_url': 'https://www.abgeordnetenwatch.de/profile/olaf-margraf',
#    'first_name': 'Olaf',
#    'last_name': 'Margraf',
#    'birth_name': None,
#    'sex': 'm',
#    'year_of_birth': 1961,
#    'party': {'id': 226,
#     'entity_type': 'party',
#     'label': 'Aktion Bürger für Gerechtigkeit',
#     'api_url': 'https://www.abgeordnetenwatch.de/api/v2/parties/226'},
#    'party_past': None,
#    'education': None,
#    'residence': 'Fulda',
#    'occupation': 'Rechtsanwalt',
#    'statistic_questions': None,
#    'statistic_questions_answered': None,
#    'ext_id_bundestagsverwaltung': None,
#    'qid_wikidata': None,
#    'field_title': None},
#   {'id': 180729,
#    'entity_type': 'politician',
#    'label': 'Evelyne Schuchmann',
#    'api_url': 'https://www.abgeordnetenwatch.de/api/v2/politicians/180729',
#    'abgeordnetenwatch_url': 'https://www.abgeordnetenwatch.de/profile/evelyne-schuchmann',
#    'first_name': 'Evelyne',
#    'last_name': 'Schuchmann',
#    'birth_name': 'Müller',
#    'sex': 'f',
#    'year_of_birth': 1954,
#    'party': {'id': 225,
#     'entity_type': 'party',
#     'label': 'SGV Partei',
#     'api_url': 'https://www.abgeordnetenwatch.de/api/v2/parties/225'},
#    'party_past': None,
#    'education': 'Verwaltungsangestellte',
#    'residence': '64560 Riedstadt',
#    'occupation': 'Rentnerin',
#    'statistic_questions': None,
#    'statistic_questions_answered': None,
#    'ext_id_bundestagsverwaltung': None,
#    'qid_wikidata': None,
#    'field_title': None},
#   {'id': 180728,
#    'entity_type': 'politician',
#    'label': 'Frank Michler',
#    'api_url': 'https://www.abgeordnetenwatch.de/api/v2/politicians/180728',
#    'abgeordnetenwatch_url': 'https://www.abgeordnetenwatch.de/profile/frank-michler',
#    'first_name': 'Frank',
#    'last_name': 'Michler',
#    'birth_name': None,
#    'sex': 'm',
#    'year_of_birth': 1976,
#    'party': {'id': 224,
#     'entity_type': 'party',
#     'label': 'Bürgerliste Weiterdenken',
#     'api_url': 'https://www.abgeordnetenwatch.de/api/v2/parties/224'},
#    'party_past': None,
#    'education': None,
#    'residence': 'Marburg',
#    'occupation': 'Software-Entwickler',
#    'statistic_questions': 3,
#    'statistic_questions_answered': None,
#    'ext_id_bundestagsverwaltung': None,
#    'qid_wikidata': None,
#    'field_title': 'Dr.'},
#   {'id': 180727,
#    'entity_type': 'politician',
#    'label': 'Vincent Welsch',
#    'api_url': 'https://www.abgeordnetenwatch.de/api/v2/politicians/180727',
#    'abgeordnetenwatch_url': 'https://www.abgeordnetenwatch.de/profile/vincent-welsch',
#    'first_name': 'Vincent',
#    'last_name': 'Welsch',
#    'birth_name': None,
#    'sex': 'm',
#    'year_of_birth': 1997,
#    'party': {'id': 222,
#     'entity_type': 'party',
#     'label': 'MERA25',
#     'api_url': 'https://www.abgeordnetenwatch.de/api/v2/parties/222'},
#    'party_past': None,
#    'education': None,
#    'residence': None,
#    'occupation': 'Auszubildender',
#    'statistic_questions': None,
#    'statistic_questions_answered': None,
#    'ext_id_bundestagsverwaltung': None,
#    'qid_wikidata': None,
#    'field_title': None},
#   {'id': 180726,
#    'entity_type': 'politician',
#    'label': 'Roman Bausch',
#    'api_url': 'https://www.abgeordnetenwatch.de/api/v2/politicians/180726',
#    'abgeordnetenwatch_url': 'https://www.abgeordnetenwatch.de/profile/roman-bausch',
#    'first_name': 'Roman',
#    'last_name': 'Bausch',
#    'birth_name': None,
#    'sex': 'm',
#    'year_of_birth': 1982,
#    'party': {'id': 9,
#     'entity_type': 'party',
#     'label': 'AfD',
#     'api_url': 'https://www.abgeordnetenwatch.de/api/v2/parties/9'},
#    'party_past': None,
#    'education': 'Doctor of Philosophy (Economics) / Chula Univ. ',
#    'residence': 'Wiesbaden',
#    'occupation': 'Fraktionsreferent',
#    'statistic_questions': 2,
#    'statistic_questions_answered': 2,
#    'ext_id_bundestagsverwaltung': None,
#    'qid_wikidata': None,
#    'field_title': None},
#   {'id': 180725,
#    'entity_type': 'politician',
#    'label': 'Norbert Hansmann',
#    'api_url': 'https://www.abgeordnetenwatch.de/api/v2/politicians/180725',
#    'abgeordnetenwatch_url': 'https://www.abgeordnetenwatch.de/profile/norbert-hansmann',
#    'first_name': 'Norbert',
#    'last_name': 'Hansmann',
#    'birth_name': None,
#    'sex': 'm',
#    'year_of_birth': 1961,
#    'party': {'id': 9,
#     'entity_type': 'party',
#     'label': 'AfD',
#     'api_url': 'https://www.abgeordnetenwatch.de/api/v2/parties/9'},
#    'party_past': None,
#    'education': None,
#    'residence': 'Kassel',
#    'occupation': None,
#    'statistic_questions': 1,
#    'statistic_questions_answered': None,
#    'ext_id_bundestagsverwaltung': None,
#    'qid_wikidata': None,
#    'field_title': None},
#   {'id': 180724,
#    'entity_type': 'politician',
#    'label': 'Gregory Scholz',
#    'api_url': 'https://www.abgeordnetenwatch.de/api/v2/politicians/180724',
#    'abgeordnetenwatch_url': 'https://www.abgeordnetenwatch.de/profile/gregory-scholz',
#    'first_name': 'Gregory',
#    'last_name': 'Scholz',
#    'birth_name': None,
#    'sex': 'm',
#    'year_of_birth': 1981,
#    'party': {'id': 1,
#     'entity_type': 'party',
#     'label': 'SPD',
#     'api_url': 'https://www.abgeordnetenwatch.de/api/v2/parties/1'},
#    'party_past': None,
#    'education': 'Lehrer',
#    'residence': 'Ludwigshafen-Oppau',
#    'occupation': None,
#    'statistic_questions': None,
#    'statistic_questions_answered': None,
#    'ext_id_bundestagsverwaltung': None,
#    'qid_wikidata': None,
#    'field_title': None},
#   {'id': 180723,
#    'entity_type': 'politician',
#    'label': 'Philipp Borgartz',
#    'api_url': 'https://www.abgeordnetenwatch.de/api/v2/politicians/180723',
#    'abgeordnetenwatch_url': 'https://www.abgeordnetenwatch.de/profile/philipp-borgartz',
#    'first_name': 'Philipp',
#    'last_name': 'Borgartz',
#    'birth_name': None,
#    'sex': 'm',
#    'year_of_birth': 1992,
#    'party': {'id': 89,
#     'entity_type': 'party',
#     'label': 'APPD',
#     'api_url': 'https://www.abgeordnetenwatch.de/api/v2/parties/89'},
#    'party_past': None,
#    'education': 'Berufskraftfahrer',
#    'residence': 'Darmstadt ',
#    'occupation': 'Politiker ',
#    'statistic_questions': 1,
#    'statistic_questions_answered': 1,
#    'ext_id_bundestagsverwaltung': None,
#    'qid_wikidata': None,
#    'field_title': None},
#   {'id': 180722,
#    'entity_type': 'politician',
#    'label': 'Andrea Rehwald',
#    'api_url': 'https://www.abgeordnetenwatch.de/api/v2/politicians/180722',
#    'abgeordnetenwatch_url': 'https://www.abgeordnetenwatch.de/profile/andrea-rehwald',
#    'first_name': 'Andrea',
#    'last_name': 'Rehwald',
#    'birth_name': 'Eisenbeis',
#    'sex': 'f',
#    'year_of_birth': 1964,
#    'party': {'id': 82,
#     'entity_type': 'party',
#     'label': 'Bündnis C',
#     'api_url': 'https://www.abgeordnetenwatch.de/api/v2/parties/82'},
#    'party_past': None,
#    'education': 'Bürokaufmann',
#    'residence': 'Merenberg',
#    'occupation': 'Vertriebsmitarbeiterin',
#    'statistic_questions': 1,
#    'statistic_questions_answered': 1,
#    'ext_id_bundestagsverwaltung': None,
#    'qid_wikidata': None,
#    'field_title': None},
#   {'id': 180721,
#    'entity_type': 'politician',
#    'label': 'Miriam Fuchs',
#    'api_url': 'https://www.abgeordnetenwatch.de/api/v2/politicians/180721',
#    'abgeordnetenwatch_url': 'https://www.abgeordnetenwatch.de/profile/miriam-fuchs',
#    'first_name': 'Miriam',
#    'last_name': 'Fuchs',
#    'birth_name': 'Schwarz',
#    'sex': 'f',
#    'year_of_birth': 1987,
#    'party': {'id': 5,
#     'entity_type': 'party',
#     'label': 'Bündnis 90/Die Grünen',
#     'api_url': 'https://www.abgeordnetenwatch.de/api/v2/parties/5'},
#    'party_past': None,
#    'education': 'Japanologin',
#    'residence': 'Taunusstein',
#    'occupation': 'Sprachdienstleisterin',
#    'statistic_questions': 3,
#    'statistic_questions_answered': 3,
#    'ext_id_bundestagsverwaltung': None,
#    'qid_wikidata': None,
#    'field_title': None},
#   {'id': 180720,
#    'entity_type': 'politician',
#    'label': 'Simon Stratthaus',
#    'api_url': 'https://www.abgeordnetenwatch.de/api/v2/politicians/180720',
#    'abgeordnetenwatch_url': 'https://www.abgeordnetenwatch.de/profile/simon-stratthaus',
#    'first_name': 'Simon',
#    'last_name': 'Stratthaus',
#    'birth_name': None,
#    'sex': 'm',
#    'year_of_birth': 1995,
#    'party': {'id': 16,
#     'entity_type': 'party',
#     'label': 'Die PARTEI',
#     'api_url': 'https://www.abgeordnetenwatch.de/api/v2/parties/16'},
#    'party_past': None,
#    'education': 'Industriemechaniker',
#    'residence': 'Offenbach am Main',
#    'occupation': 'Industriemechaniker',
#    'statistic_questions': None,
#    'statistic_questions_answered': None,
#    'ext_id_bundestagsverwaltung': None,
#    'qid_wikidata': None,
#    'field_title': None},
#   {'id': 180719,
#    'entity_type': 'politician',
#    'label': 'Iris Hofmann',
#    'api_url': 'https://www.abgeordnetenwatch.de/api/v2/politicians/180719',
#    'abgeordnetenwatch_url': 'https://www.abgeordnetenwatch.de/profile/iris-hofmann',
#    'first_name': 'Iris',
#    'last_name': 'Hofmann',
#    'birth_name': None,
#    'sex': 'f',
#    'year_of_birth': None,
#    'party': {'id': 1,
#     'entity_type': 'party',
#     'label': 'SPD',
#     'api_url': 'https://www.abgeordnetenwatch.de/api/v2/parties/1'},
#    'party_past': None,
#    'education': None,
#    'residence': None,
#    'occupation': None,
#    'statistic_questions': None,
#    'statistic_questions_answered': None,
#    'ext_id_bundestagsverwaltung': None,
#    'qid_wikidata': None,
#    'field_title': None},
#   {'id': 180718,
#    'entity_type': 'politician',
#    'label': 'Norbert Höhl',
#    'api_url': 'https://www.abgeordnetenwatch.de/api/v2/politicians/180718',
#    'abgeordnetenwatch_url': 'https://www.abgeordnetenwatch.de/profile/norbert-hoehl',
#    'first_name': 'Norbert',
#    'last_name': 'Höhl',
#    'birth_name': None,
#    'sex': 'm',
#    'year_of_birth': 1957,
#    'party': {'id': 82,
#     'entity_type': 'party',
#     'label': 'Bündnis C',
#     'api_url': 'https://www.abgeordnetenwatch.de/api/v2/parties/82'},
#    'party_past': None,
#    'education': None,
#    'residence': 'Petersberg',
#    'occupation': 'Lehrer',
#    'statistic_questions': 1,
#    'statistic_questions_answered': None,
#    'ext_id_bundestagsverwaltung': None,
#    'qid_wikidata': None,
#    'field_title': None},
#   {'id': 180717,
#    'entity_type': 'politician',
#    'label': 'Edgar Winand',
#    'api_url': 'https://www.abgeordnetenwatch.de/api/v2/politicians/180717',
#    'abgeordnetenwatch_url': 'https://www.abgeordnetenwatch.de/profile/edgar-winand',
#    'first_name': 'Edgar',
#    'last_name': 'Winand',
#    'birth_name': None,
#    'sex': 'm',
#    'year_of_birth': 1954,
#    'party': {'id': 82,
#     'entity_type': 'party',
#     'label': 'Bündnis C',
#     'api_url': 'https://www.abgeordnetenwatch.de/api/v2/parties/82'},
#    'party_past': None,
#    'education': None,
#    'residence': 'Usingen',
#    'occupation': 'Rentner',
#    'statistic_questions': 1,
#    'statistic_questions_answered': None,
#    'ext_id_bundestagsverwaltung': None,
#    'qid_wikidata': None,
#    'field_title': None},
#   {'id': 180716,
#    'entity_type': 'politician',
#    'label': 'Alain Kaffo',
#    'api_url': 'https://www.abgeordnetenwatch.de/api/v2/politicians/180716',
#    'abgeordnetenwatch_url': 'https://www.abgeordnetenwatch.de/profile/alain-kaffo',
#    'first_name': 'Alain',
#    'last_name': 'Kaffo',
#    'birth_name': None,
#    'sex': 'm',
#    'year_of_birth': 1980,
#    'party': {'id': 82,
#     'entity_type': 'party',
#     'label': 'Bündnis C',
#     'api_url': 'https://www.abgeordnetenwatch.de/api/v2/parties/82'},
#    'party_past': None,
#    'education': 'Wirtschaftsingenieur',
#    'residence': 'Fulda',
#    'occupation': 'IT-Berater',
#    'statistic_questions': 1,
#    'statistic_questions_answered': None,
#    'ext_id_bundestagsverwaltung': None,
#    'qid_wikidata': None,
#    'field_title': None},
#   {'id': 180715,
#    'entity_type': 'politician',
#    'label': 'Ludwig Grünert',
#    'api_url': 'https://www.abgeordnetenwatch.de/api/v2/politicians/180715',
#    'abgeordnetenwatch_url': 'https://www.abgeordnetenwatch.de/profile/ludwig-gruenert',
#    'first_name': 'Ludwig',
#    'last_name': 'Grünert',
#    'birth_name': None,
#    'sex': 'm',
#    'year_of_birth': 1992,
#    'party': {'id': 82,
#     'entity_type': 'party',
#     'label': 'Bündnis C',
#     'api_url': 'https://www.abgeordnetenwatch.de/api/v2/parties/82'},
#    'party_past': None,
#    'education': None,
#    'residence': 'Linden',
#    'occupation': 'Notfallsanitäter',
#    'statistic_questions': 1,
#    'statistic_questions_answered': None,
#    'ext_id_bundestagsverwaltung': None,
#    'qid_wikidata': None,
#    'field_title': None},
#   {'id': 180714,
#    'entity_type': 'politician',
#    'label': 'David Adler',
#    'api_url': 'https://www.abgeordnetenwatch.de/api/v2/politicians/180714',
#    'abgeordnetenwatch_url': 'https://www.abgeordnetenwatch.de/profile/david-adler',
#    'first_name': 'David',
#    'last_name': 'Adler',
#    'birth_name': None,
#    'sex': 'm',
#    'year_of_birth': 1995,
#    'party': {'id': 82,
#     'entity_type': 'party',
#     'label': 'Bündnis C',
#     'api_url': 'https://www.abgeordnetenwatch.de/api/v2/parties/82'},
#    'party_past': None,
#    'education': None,
#    'residence': 'Gießen',
#    'occupation': 'Kinder- und Jugendreferent',
#    'statistic_questions': 1,
#    'statistic_questions_answered': 1,
#    'ext_id_bundestagsverwaltung': None,
#    'qid_wikidata': None,
#    'field_title': None},
#   {'id': 180713,
#    'entity_type': 'politician',
#    'label': 'Nadine Recker',
#    'api_url': 'https://www.abgeordnetenwatch.de/api/v2/politicians/180713',
#    'abgeordnetenwatch_url': 'https://www.abgeordnetenwatch.de/profile/nadine-recker',
#    'first_name': 'Nadine',
#    'last_name': 'Recker',
#    'birth_name': None,
#    'sex': 'f',
#    'year_of_birth': 1994,
#    'party': {'id': 168,
#     'entity_type': 'party',
#     'label': 'V-Partei³',
#     'api_url': 'https://www.abgeordnetenwatch.de/api/v2/parties/168'},
#    'party_past': None,
#    'education': None,
#    'residence': 'Kassel',
#    'occupation': 'Arbeitslose',
#    'statistic_questions': 1,
#    'statistic_questions_answered': None,
#    'ext_id_bundestagsverwaltung': None,
#    'qid_wikidata': None,
#    'field_title': None},
#   {'id': 180712,
#    'entity_type': 'politician',
#    'label': 'Susanne Stachon',
#    'api_url': 'https://www.abgeordnetenwatch.de/api/v2/politicians/180712',
#    'abgeordnetenwatch_url': 'https://www.abgeordnetenwatch.de/profile/susanne-stachon',
#    'first_name': 'Susanne',
#    'last_name': 'Stachon',
#    'birth_name': None,
#    'sex': 'f',
#    'year_of_birth': None,
#    'party': {'id': 168,
#     'entity_type': 'party',
#     'label': 'V-Partei³',
#     'api_url': 'https://www.abgeordnetenwatch.de/api/v2/parties/168'},
#    'party_past': None,
#    'education': None,
#    'residence': None,
#    'occupation': None,
#    'statistic_questions': None,
#    'statistic_questions_answered': None,
#    'ext_id_bundestagsverwaltung': None,
#    'qid_wikidata': None,
#    'field_title': None},
#   {'id': 180711,
#    'entity_type': 'politician',
#    'label': 'Johanna Gomuloch',
#    'api_url': 'https://www.abgeordnetenwatch.de/api/v2/politicians/180711',
#    'abgeordnetenwatch_url': 'https://www.abgeordnetenwatch.de/profile/johanna-gomuloch',
#    'first_name': 'Johanna',
#    'last_name': 'Gomuloch',
#    'birth_name': None,
#    'sex': 'f',
#    'year_of_birth': None,
#    'party': {'id': 168,
#     'entity_type': 'party',
#     'label': 'V-Partei³',
#     'api_url': 'https://www.abgeordnetenwatch.de/api/v2/parties/168'},
#    'party_past': None,
#    'education': None,
#    'residence': None,
#    'occupation': None,
#    'statistic_questions': None,
#    'statistic_questions_answered': None,
#    'ext_id_bundestagsverwaltung': None,
#    'qid_wikidata': None,
#    'field_title': None},
#   {'id': 180710,
#    'entity_type': 'politician',
#    'label': 'Adriano Holatz',
#    'api_url': 'https://www.abgeordnetenwatch.de/api/v2/politicians/180710',
#    'abgeordnetenwatch_url': 'https://www.abgeordnetenwatch.de/profile/adriano-holatz',
#    'first_name': 'Adriano',
#    'last_name': 'Holatz',
#    'birth_name': None,
#    'sex': 'm',
#    'year_of_birth': None,
#    'party': {'id': 168,
#     'entity_type': 'party',
#     'label': 'V-Partei³',
#     'api_url': 'https://www.abgeordnetenwatch.de/api/v2/parties/168'},
#    'party_past': None,
#    'education': None,
#    'residence': None,
#    'occupation': None,
#    'statistic_questions': None,
#    'statistic_questions_answered': None,
#    'ext_id_bundestagsverwaltung': None,
#    'qid_wikidata': None,
#    'field_title': None},
#   {'id': 180709,
#    'entity_type': 'politician',
#    'label': 'Jas Fink',
#    'api_url': 'https://www.abgeordnetenwatch.de/api/v2/politicians/180709',
#    'abgeordnetenwatch_url': 'https://www.abgeordnetenwatch.de/profile/jas-fink',
#    'first_name': 'Jas',
#    'last_name': 'Fink',
#    'birth_name': None,
#    'sex': None,
#    'year_of_birth': None,
#    'party': {'id': 168,
#     'entity_type': 'party',
#     'label': 'V-Partei³',
#     'api_url': 'https://www.abgeordnetenwatch.de/api/v2/parties/168'},
#    'party_past': None,
#    'education': 'Coach für Teamentwicklung und Burnoutprävention',
#    'residence': 'Planet Erde',
#    'occupation': None,
#    'statistic_questions': None,
#    'statistic_questions_answered': None,
#    'ext_id_bundestagsverwaltung': None,
#    'qid_wikidata': None,
#    'field_title': None},
#   {'id': 180708,
#    'entity_type': 'politician',
#    'label': 'Yvonne Machalett',
#    'api_url': 'https://www.abgeordnetenwatch.de/api/v2/politicians/180708',
#    'abgeordnetenwatch_url': 'https://www.abgeordnetenwatch.de/profile/yvonne-machalett',
#    'first_name': 'Yvonne',
#    'last_name': 'Machalett',
#    'birth_name': None,
#    'sex': 'f',
#    'year_of_birth': None,
#    'party': {'id': 168,
#     'entity_type': 'party',
#     'label': 'V-Partei³',
#     'api_url': 'https://www.abgeordnetenwatch.de/api/v2/parties/168'},
#    'party_past': None,
#    'education': None,
#    'residence': None,
#    'occupation': None,
#    'statistic_questions': 2,
#    'statistic_questions_answered': 2,
#    'ext_id_bundestagsverwaltung': None,
#    'qid_wikidata': None,
#    'field_title': None},
#   {'id': 180707,
#    'entity_type': 'politician',
#    'label': 'Sabine Relovsky',
#    'api_url': 'https://www.abgeordnetenwatch.de/api/v2/politicians/180707',
#    'abgeordnetenwatch_url': 'https://www.abgeordnetenwatch.de/profile/sabine-relovsky',
#    'first_name': 'Sabine',
#    'last_name': 'Relovsky',
#    'birth_name': None,
#    'sex': 'f',
#    'year_of_birth': None,
#    'party': {'id': 168,
#     'entity_type': 'party',
#     'label': 'V-Partei³',
#     'api_url': 'https://www.abgeordnetenwatch.de/api/v2/parties/168'},
#    'party_past': None,
#    'education': None,
#    'residence': None,
#    'occupation': None,
#    'statistic_questions': None,
#    'statistic_questions_answered': None,
#    'ext_id_bundestagsverwaltung': None,
#    'qid_wikidata': None,
#    'field_title': None},
#   {'id': 180706,
#    'entity_type': 'politician',
#    'label': 'Tanja Kretzschmar',
#    'api_url': 'https://www.abgeordnetenwatch.de/api/v2/politicians/180706',
#    'abgeordnetenwatch_url': 'https://www.abgeordnetenwatch.de/profile/tanja-kretzschmar',
#    'first_name': 'Tanja',
#    'last_name': 'Kretzschmar',
#    'birth_name': None,
#    'sex': 'f',
#    'year_of_birth': None,
#    'party': {'id': 168,
#     'entity_type': 'party',
#     'label': 'V-Partei³',
#     'api_url': 'https://www.abgeordnetenwatch.de/api/v2/parties/168'},
#    'party_past': None,
#    'education': None,
#    'residence': None,
#    'occupation': None,
#    'statistic_questions': 1,
#    'statistic_questions_answered': None,
#    'ext_id_bundestagsverwaltung': None,
#    'qid_wikidata': None,
#    'field_title': None},
#   {'id': 180705,
#    'entity_type': 'politician',
#    'label': 'Kornelia Elsner',
#    'api_url': 'https://www.abgeordnetenwatch.de/api/v2/politicians/180705',
#    'abgeordnetenwatch_url': 'https://www.abgeordnetenwatch.de/profile/kornelia-elsner',
#    'first_name': 'Kornelia',
#    'last_name': 'Elsner',
#    'birth_name': None,
#    'sex': 'f',
#    'year_of_birth': None,
#    'party': {'id': 168,
#     'entity_type': 'party',
#     'label': 'V-Partei³',
#     'api_url': 'https://www.abgeordnetenwatch.de/api/v2/parties/168'},
#    'party_past': None,
#    'education': None,
#    'residence': None,
#    'occupation': None,
#    'statistic_questions': None,
#    'statistic_questions_answered': None,
#    'ext_id_bundestagsverwaltung': None,
#    'qid_wikidata': None,
#    'field_title': None},
#   {'id': 180704,
#    'entity_type': 'politician',
#    'label': 'Wilhelm Hartl',
#    'api_url': 'https://www.abgeordnetenwatch.de/api/v2/politicians/180704',
#    'abgeordnetenwatch_url': 'https://www.abgeordnetenwatch.de/profile/wilhelm-hartl',
#    'first_name': 'Wilhelm',
#    'last_name': 'Hartl',
#    'birth_name': None,
#    'sex': 'm',
#    'year_of_birth': 1971,
#    'party': {'id': 168,
#     'entity_type': 'party',
#     'label': 'V-Partei³',
#     'api_url': 'https://www.abgeordnetenwatch.de/api/v2/parties/168'},
#    'party_past': None,
#    'education': 'Geprüfter Wirtschaftsfachwirt (IHK)',
#    'residence': 'Buttenwiesen',
#    'occupation': 'aktuell arbeitsunfähig (Erwerbsminderungsrente)',
#    'statistic_questions': 2,
#    'statistic_questions_answered': 2,
#    'ext_id_bundestagsverwaltung': None,
#    'qid_wikidata': None,
#    'field_title': None},
#   {'id': 180703,
#    'entity_type': 'politician',
#    'label': 'Natalie Brugger',
#    'api_url': 'https://www.abgeordnetenwatch.de/api/v2/politicians/180703',
#    'abgeordnetenwatch_url': 'https://www.abgeordnetenwatch.de/profile/natalie-brugger',
#    'first_name': 'Natalie',
#    'last_name': 'Brugger',
#    'birth_name': None,
#    'sex': 'f',
#    'year_of_birth': None,
#    'party': {'id': 168,
#     'entity_type': 'party',
#     'label': 'V-Partei³',
#     'api_url': 'https://www.abgeordnetenwatch.de/api/v2/parties/168'},
#    'party_past': None,
#    'education': None,
#    'residence': None,
#    'occupation': None,
#    'statistic_questions': None,
#    'statistic_questions_answered': None,
#    'ext_id_bundestagsverwaltung': None,
#    'qid_wikidata': None,
#    'field_title': None},
#   {'id': 180702,
#    'entity_type': 'politician',
#    'label': 'Bernd Beigl',
#    'api_url': 'https://www.abgeordnetenwatch.de/api/v2/politicians/180702',
#    'abgeordnetenwatch_url': 'https://www.abgeordnetenwatch.de/profile/bernd-beigl',
#    'first_name': 'Bernd',
#    'last_name': 'Beigl',
#    'birth_name': None,
#    'sex': 'm',
#    'year_of_birth': None,
#    'party': {'id': 168,
#     'entity_type': 'party',
#     'label': 'V-Partei³',
#     'api_url': 'https://www.abgeordnetenwatch.de/api/v2/parties/168'},
#    'party_past': None,
#    'education': None,
#    'residence': None,
#    'occupation': None,
#    'statistic_questions': None,
#    'statistic_questions_answered': None,
#    'ext_id_bundestagsverwaltung': None,
#    'qid_wikidata': None,
#    'field_title': None},
#   {'id': 180701,
#    'entity_type': 'politician',
#    'label': 'Daniel Probst',
#    'api_url': 'https://www.abgeordnetenwatch.de/api/v2/politicians/180701',
#    'abgeordnetenwatch_url': 'https://www.abgeordnetenwatch.de/profile/daniel-probst',
#    'first_name': 'Daniel',
#    'last_name': 'Probst',
#    'birth_name': None,
#    'sex': 'm',
#    'year_of_birth': 1998,
#    'party': {'id': 168,
#     'entity_type': 'party',
#     'label': 'V-Partei³',
#     'api_url': 'https://www.abgeordnetenwatch.de/api/v2/parties/168'},
#    'party_past': None,
#    'education': None,
#    'residence': 'Regensburg',
#    'occupation': 'Finanzwirt',
#    'statistic_questions': None,
#    'statistic_questions_answered': None,
#    'ext_id_bundestagsverwaltung': None,
#    'qid_wikidata': None,
#    'field_title': None},
#   {'id': 180700,
#    'entity_type': 'politician',
#    'label': 'Melanie Zeletzki',
#    'api_url': 'https://www.abgeordnetenwatch.de/api/v2/politicians/180700',
#    'abgeordnetenwatch_url': 'https://www.abgeordnetenwatch.de/profile/melanie-zeletzki',
#    'first_name': 'Melanie',
#    'last_name': 'Zeletzki',
#    'birth_name': None,
#    'sex': 'f',
#    'year_of_birth': None,
#    'party': {'id': 168,
#     'entity_type': 'party',
#     'label': 'V-Partei³',
#     'api_url': 'https://www.abgeordnetenwatch.de/api/v2/parties/168'},
#    'party_past': None,
#    'education': None,
#    'residence': None,
#    'occupation': None,
#    'statistic_questions': None,
#    'statistic_questions_answered': None,
#    'ext_id_bundestagsverwaltung': None,
#    'qid_wikidata': None,
#    'field_title': None},
#   {'id': 180699,
#    'entity_type': 'politician',
#    'label': 'Carina Horner',
#    'api_url': 'https://www.abgeordnetenwatch.de/api/v2/politicians/180699',
#    'abgeordnetenwatch_url': 'https://www.abgeordnetenwatch.de/profile/carina-horner',
#    'first_name': 'Carina',
#    'last_name': 'Horner',
#    'birth_name': None,
#    'sex': 'f',
#    'year_of_birth': 1980,
#    'party': {'id': 168,
#     'entity_type': 'party',
#     'label': 'V-Partei³',
#     'api_url': 'https://www.abgeordnetenwatch.de/api/v2/parties/168'},
#    'party_past': None,
#    'education': 'Politikwissenschaftlerin',
#    'residence': None,
#    'occupation': 'Dozentin für Deutsch und Latein; Eselwanderin',
#    'statistic_questions': None,
#    'statistic_questions_answered': None,
#    'ext_id_bundestagsverwaltung': None,
#    'qid_wikidata': None,
#    'field_title': None},
#   {'id': 180698,
#    'entity_type': 'politician',
#    'label': 'Nina Veitengruber',
#    'api_url': 'https://www.abgeordnetenwatch.de/api/v2/politicians/180698',
#    'abgeordnetenwatch_url': 'https://www.abgeordnetenwatch.de/profile/nina-veitengruber',
#    'first_name': 'Nina',
#    'last_name': 'Veitengruber',
#    'birth_name': None,
#    'sex': None,
#    'year_of_birth': None,
#    'party': {'id': 168,
#     'entity_type': 'party',
#     'label': 'V-Partei³',
#     'api_url': 'https://www.abgeordnetenwatch.de/api/v2/parties/168'},
#    'party_past': None,
#    'education': None,
#    'residence': None,
#    'occupation': None,
#    'statistic_questions': 1,
#    'statistic_questions_answered': None,
#    'ext_id_bundestagsverwaltung': None,
#    'qid_wikidata': None,
#    'field_title': None},
#   {'id': 180697,
#    'entity_type': 'politician',
#    'label': 'Dominik Maier',
#    'api_url': 'https://www.abgeordnetenwatch.de/api/v2/politicians/180697',
#    'abgeordnetenwatch_url': 'https://www.abgeordnetenwatch.de/profile/dominik-maier',
#    'first_name': 'Dominik',
#    'last_name': 'Maier',
#    'birth_name': None,
#    'sex': 'm',
#    'year_of_birth': 1987,
#    'party': {'id': 168,
#     'entity_type': 'party',
#     'label': 'V-Partei³',
#     'api_url': 'https://www.abgeordnetenwatch.de/api/v2/parties/168'},
#    'party_past': None,
#    'education': 'Gärtner',
#    'residence': 'Unterwattenbach',
#    'occupation': 'Gärtner',
#    'statistic_questions': None,
#    'statistic_questions_answered': None,
#    'ext_id_bundestagsverwaltung': None,
#    'qid_wikidata': None,
#    'field_title': None},
#   {'id': 180696,
#    'entity_type': 'politician',
#    'label': 'Marco Döring',
#    'api_url': 'https://www.abgeordnetenwatch.de/api/v2/politicians/180696',
#    'abgeordnetenwatch_url': 'https://www.abgeordnetenwatch.de/profile/marco-doering',
#    'first_name': 'Marco',
#    'last_name': 'Döring',
#    'birth_name': None,
#    'sex': 'm',
#    'year_of_birth': None,
#    'party': {'id': 168,
#     'entity_type': 'party',
#     'label': 'V-Partei³',
#     'api_url': 'https://www.abgeordnetenwatch.de/api/v2/parties/168'},
#    'party_past': None,
#    'education': None,
#    'residence': None,
#    'occupation': None,
#    'statistic_questions': None,
#    'statistic_questions_answered': None,
#    'ext_id_bundestagsverwaltung': None,
#    'qid_wikidata': None,
#    'field_title': None},
#   {'id': 180695,
#    'entity_type': 'politician',
#    'label': 'Benedikt Wieden',
#    'api_url': 'https://www.abgeordnetenwatch.de/api/v2/politicians/180695',
#    'abgeordnetenwatch_url': 'https://www.abgeordnetenwatch.de/profile/benedikt-wieden',
#    'first_name': 'Benedikt',
#    'last_name': 'Wieden',
#    'birth_name': None,
#    'sex': 'm',
#    'year_of_birth': 1998,
#    'party': {'id': 168,
#     'entity_type': 'party',
#     'label': 'V-Partei³',
#     'api_url': 'https://www.abgeordnetenwatch.de/api/v2/parties/168'},
#    'party_past': None,
#    'education': 'Anlagenmechaniker SHK',
#    'residence': 'Traunreut',
#    'occupation': 'Anlagenmechaniker für Sanitär, Heizungs- & Klimatechnik',
#    'statistic_questions': 1,
#    'statistic_questions_answered': 1,
#    'ext_id_bundestagsverwaltung': None,
#    'qid_wikidata': None,
#    'field_title': None},
#   {'id': 180694,
#    'entity_type': 'politician',
#    'label': 'Sabine Ipek',
#    'api_url': 'https://www.abgeordnetenwatch.de/api/v2/politicians/180694',
#    'abgeordnetenwatch_url': 'https://www.abgeordnetenwatch.de/profile/sabine-ipek',
#    'first_name': 'Sabine',
#    'last_name': 'Ipek',
#    'birth_name': None,
#    'sex': 'f',
#    'year_of_birth': None,
#    'party': {'id': 168,
#     'entity_type': 'party',
#     'label': 'V-Partei³',
#     'api_url': 'https://www.abgeordnetenwatch.de/api/v2/parties/168'},
#    'party_past': None,
#    'education': None,
#    'residence': None,
#    'occupation': None,
#    'statistic_questions': None,
#    'statistic_questions_answered': None,
#    'ext_id_bundestagsverwaltung': None,
#    'qid_wikidata': None,
# ...
#    'party_past': None,
#    'education': None,
#    'residence': 'Gröbenzell',
#    'occupation': 'Student',
#    'statistic_questions': None,
#    'statistic_questions_answered': None,
#    'ext_id_bundestagsverwaltung': None,
#    'qid_wikidata': None,
#    'field_title': None},
#   {'id': 180674,
#    'entity_type': 'politician',
#    'label': 'Felicitas Koch',
#    'api_url': 'https://www.abgeordnetenwatch.de/api/v2/politicians/180674',
#    'abgeordnetenwatch_url': 'https://www.abgeordnetenwatch.de/profile/felicitas-koch',
#    'first_name': 'Felicitas',
#    'last_name': 'Koch',
#    'birth_name': None,
#    'sex': 'f',
#    'year_of_birth': None,
#    'party': {'id': 168,
#     'entity_type': 'party',
#     'label': 'V-Partei³',
#     'api_url': 'https://www.abgeordnetenwatch.de/api/v2/parties/168'},
#    'party_past': None,
#    'education': None,
#    'residence': None,
#    'occupation': None,
#    'statistic_questions': None,
#    'statistic_questions_answered': None,
#    'ext_id_bundestagsverwaltung': None,
#    'qid_wikidata': None,
#    'field_title': None},
#   {'id': 180673,
#    'entity_type': 'politician',
#    'label': 'Anna Simon',
#    'api_url': 'https://www.abgeordnetenwatch.de/api/v2/politicians/180673',
#    'abgeordnetenwatch_url': 'https://www.abgeordnetenwatch.de/profile/anna-simon',
#    'first_name': 'Anna',
#    'last_name': 'Simon',
#    'birth_name': None,
#    'sex': 'f',
#    'year_of_birth': None,
#    'party': {'id': 168,
#     'entity_type': 'party',
#     'label': 'V-Partei³',
#     'api_url': 'https://www.abgeordnetenwatch.de/api/v2/parties/168'},
#    'party_past': None,
#    'education': None,
#    'residence': None,
#    'occupation': None,
#    'statistic_questions': None,
#    'statistic_questions_answered': None,
#    'ext_id_bundestagsverwaltung': None,
#    'qid_wikidata': None,
#    'field_title': None},
#   {'id': 180672,
#    'entity_type': 'politician',
#    'label': 'Korbinian Zacherl',
#    'api_url': 'https://www.abgeordnetenwatch.de/api/v2/politicians/180672',
#    'abgeordnetenwatch_url': 'https://www.abgeordnetenwatch.de/profile/korbinian-zacherl',
#    'first_name': 'Korbinian',
#    'last_name': 'Zacherl',
#    'birth_name': None,
#    'sex': 'm',
#    'year_of_birth': None,
#    'party': {'id': 168,
#     'entity_type': 'party',
#     'label': 'V-Partei³',
#     'api_url': 'https://www.abgeordnetenwatch.de/api/v2/parties/168'},
#    'party_past': None,
#    'education': None,
#    'residence': None,
#    'occupation': None,
#    'statistic_questions': None,
#    'statistic_questions_answered': None,
#    'ext_id_bundestagsverwaltung': None,
#    'qid_wikidata': None,
#    'field_title': None},
#   {'id': 180671,
#    'entity_type': 'politician',
#    'label': 'Ralf Müller',
#    'api_url': 'https://www.abgeordnetenwatch.de/api/v2/politicians/180671',
#    'abgeordnetenwatch_url': 'https://www.abgeordnetenwatch.de/profile/ralf-mueller-1',
#    'first_name': 'Ralf',
#    'last_name': 'Müller',
#    'birth_name': 'Müller',
#    'sex': 'm',
#    'year_of_birth': 1963,
#    'party': {'id': 201,
#     'entity_type': 'party',
#     'label': 'dieBasis',
#     'api_url': 'https://www.abgeordnetenwatch.de/api/v2/parties/201'},
#    'party_past': None,
#    'education': 'Humanbiologe',
#    'residence': '89250 Senden',
#    'occupation': 'Forschung und Entwicklung',
#    'statistic_questions': None,
#    'statistic_questions_answered': None,
#    'ext_id_bundestagsverwaltung': None,
#    'qid_wikidata': None,
#    'field_title': 'Dr.'},
#   {'id': 180670,
#    'entity_type': 'politician',
#    'label': 'Ilona Christlmeier',
#    'api_url': 'https://www.abgeordnetenwatch.de/api/v2/politicians/180670',
#    'abgeordnetenwatch_url': 'https://www.abgeordnetenwatch.de/profile/ilona-christlmeier',
#    'first_name': 'Ilona',
#    'last_name': 'Christlmeier',
#    'birth_name': None,
#    'sex': 'f',
#    'year_of_birth': None,
#    'party': {'id': 201,
#     'entity_type': 'party',
#     'label': 'dieBasis',
#     'api_url': 'https://www.abgeordnetenwatch.de/api/v2/parties/201'},
#    'party_past': None,
#    'education': None,
#    'residence': None,
#    'occupation': 'IT-Mitarbeiterin',
#    'statistic_questions': 2,
#    'statistic_questions_answered': None,
#    'ext_id_bundestagsverwaltung': None,
#    'qid_wikidata': None,
#    'field_title': None},
#   {'id': 180669,
#    'entity_type': 'politician',
#    'label': 'Markus Bach',
#    'api_url': 'https://www.abgeordnetenwatch.de/api/v2/politicians/180669',
#    'abgeordnetenwatch_url': 'https://www.abgeordnetenwatch.de/profile/markus-bach',
#    'first_name': 'Markus',
#    'last_name': 'Bach',
#    'birth_name': None,
#    'sex': 'm',
#    'year_of_birth': None,
#    'party': {'id': 201,
#     'entity_type': 'party',
#     'label': 'dieBasis',
#     'api_url': 'https://www.abgeordnetenwatch.de/api/v2/parties/201'},
#    'party_past': None,
#    'education': None,
#    'residence': None,
#    'occupation': None,
#    'statistic_questions': 1,
#    'statistic_questions_answered': 1,
#    'ext_id_bundestagsverwaltung': None,
#    'qid_wikidata': None,
#    'field_title': None},
#   {'id': 180668,
#    'entity_type': 'politician',
#    'label': 'Margit Kiessling',
#    'api_url': 'https://www.abgeordnetenwatch.de/api/v2/politicians/180668',
#    'abgeordnetenwatch_url': 'https://www.abgeordnetenwatch.de/profile/margit-kiessling',
#    'first_name': 'Margit',
#    'last_name': 'Kiessling',
#    'birth_name': None,
#    'sex': 'f',
#    'year_of_birth': None,
#    'party': {'id': 201,
#     'entity_type': 'party',
#     'label': 'dieBasis',
#     'api_url': 'https://www.abgeordnetenwatch.de/api/v2/parties/201'},
#    'party_past': None,
#    'education': None,
#    'residence': None,
#    'occupation': None,
#    'statistic_questions': None,
#    'statistic_questions_answered': None,
#    'ext_id_bundestagsverwaltung': None,
#    'qid_wikidata': None,
#    'field_title': None},
#   {'id': 180667,
#    'entity_type': 'politician',
#    'label': 'Brigitte Tina',
#    'api_url': 'https://www.abgeordnetenwatch.de/api/v2/politicians/180667',
#    'abgeordnetenwatch_url': 'https://www.abgeordnetenwatch.de/profile/brigitte-tina',
#    'first_name': 'Brigitte',
#    'last_name': 'Tina',
#    'birth_name': 'Schimana',
#    'sex': 'f',
#    'year_of_birth': 1960,
#    'party': {'id': 201,
#     'entity_type': 'party',
#     'label': 'dieBasis',
#     'api_url': 'https://www.abgeordnetenwatch.de/api/v2/parties/201'},
#    'party_past': None,
#    'education': 'Medizinische Dokumentarin',
#    'residence': 'Senden',
#    'occupation': 'Rentnerin',
#    'statistic_questions': 1,
#    'statistic_questions_answered': 1,
#    'ext_id_bundestagsverwaltung': None,
#    'qid_wikidata': None,
#    'field_title': None},
#   {'id': 180666,
#    'entity_type': 'politician',
#    'label': 'Isabel Graumann',
#    'api_url': 'https://www.abgeordnetenwatch.de/api/v2/politicians/180666',
#    'abgeordnetenwatch_url': 'https://www.abgeordnetenwatch.de/profile/isabel-graumann',
#    'first_name': 'Isabel',
#    'last_name': 'Graumann',
#    'birth_name': None,
#    'sex': 'f',
#    'year_of_birth': None,
#    'party': {'id': 201,
#     'entity_type': 'party',
#     'label': 'dieBasis',
#     'api_url': 'https://www.abgeordnetenwatch.de/api/v2/parties/201'},
#    'party_past': None,
#    'education': None,
#    'residence': None,
#    'occupation': None,
#    'statistic_questions': 1,
#    'statistic_questions_answered': 1,
#    'ext_id_bundestagsverwaltung': None,
#    'qid_wikidata': None,
#    'field_title': None},
#   {'id': 180665,
#    'entity_type': 'politician',
#    'label': 'Peter Knörzer',
#    'api_url': 'https://www.abgeordnetenwatch.de/api/v2/politicians/180665',
#    'abgeordnetenwatch_url': 'https://www.abgeordnetenwatch.de/profile/peter-knoerzer',
#    'first_name': 'Peter',
#    'last_name': 'Knörzer',
#    'birth_name': None,
#    'sex': 'm',
#    'year_of_birth': 1958,
#    'party': {'id': 201,
#     'entity_type': 'party',
#     'label': 'dieBasis',
#     'api_url': 'https://www.abgeordnetenwatch.de/api/v2/parties/201'},
#    'party_past': None,
#    'education': 'Groß- und Außenhandelskaufmann',
#    'residence': 'Horgau',
#    'occupation': 'selbständiger Kaufmann',
#    'statistic_questions': 3,
#    'statistic_questions_answered': 3,
#    'ext_id_bundestagsverwaltung': None,
#    'qid_wikidata': None,
#    'field_title': None},
#   {'id': 180664,
#    'entity_type': 'politician',
#    'label': 'Benjamin Goßner',
#    'api_url': 'https://www.abgeordnetenwatch.de/api/v2/politicians/180664',
#    'abgeordnetenwatch_url': 'https://www.abgeordnetenwatch.de/profile/benjamin-gossner',
#    'first_name': 'Benjamin',
#    'last_name': 'Goßner',
#    'birth_name': None,
#    'sex': 'm',
#    'year_of_birth': 1986,
#    'party': {'id': 201,
#     'entity_type': 'party',
#     'label': 'dieBasis',
#     'api_url': 'https://www.abgeordnetenwatch.de/api/v2/parties/201'},
#    'party_past': None,
#    'education': None,
#    'residence': None,
#    'occupation': 'Gas- und Wasserinstallateur',
#    'statistic_questions': 2,
#    'statistic_questions_answered': 1,
#    'ext_id_bundestagsverwaltung': None,
#    'qid_wikidata': None,
#    'field_title': None},
#   {'id': 180663,
#    'entity_type': 'politician',
#    'label': 'Andreas Kahnt',
#    'api_url': 'https://www.abgeordnetenwatch.de/api/v2/politicians/180663',
#    'abgeordnetenwatch_url': 'https://www.abgeordnetenwatch.de/profile/andreas-kahnt',
#    'first_name': 'Andreas',
#    'last_name': 'Kahnt',
#    'birth_name': None,
#    'sex': 'm',
#    'year_of_birth': 1960,
#    'party': {'id': 201,
#     'entity_type': 'party',
#     'label': 'dieBasis',
#     'api_url': 'https://www.abgeordnetenwatch.de/api/v2/parties/201'},
#    'party_past': None,
#    'education': 'Diplom Ingenieur (FH)',
#    'residence': 'Friedberg',
#    'occupation': 'Linux Softwareentwickler',
#    'statistic_questions': 2,
#    'statistic_questions_answered': 1,
#    'ext_id_bundestagsverwaltung': None,
#    'qid_wikidata': None,
#    'field_title': None},
#   {'id': 180662,
#    'entity_type': 'politician',
#    'label': 'Erich Schenk',
#    'api_url': 'https://www.abgeordnetenwatch.de/api/v2/politicians/180662',
#    'abgeordnetenwatch_url': 'https://www.abgeordnetenwatch.de/profile/erich-schenk',
#    'first_name': 'Erich',
#    'last_name': 'Schenk',
#    'birth_name': None,
#    'sex': 'm',
#    'year_of_birth': None,
#    'party': {'id': 201,
#     'entity_type': 'party',
#     'label': 'dieBasis',
#     'api_url': 'https://www.abgeordnetenwatch.de/api/v2/parties/201'},
#    'party_past': None,
#    'education': None,
#    'residence': None,
#    'occupation': None,
#    'statistic_questions': None,
#    'statistic_questions_answered': None,
#    'ext_id_bundestagsverwaltung': None,
#    'qid_wikidata': None,
#    'field_title': None},
#   {'id': 180661,
#    'entity_type': 'politician',
#    'label': 'Elmar Straube',
#    'api_url': 'https://www.abgeordnetenwatch.de/api/v2/politicians/180661',
#    'abgeordnetenwatch_url': 'https://www.abgeordnetenwatch.de/profile/elmar-straube',
#    'first_name': 'Elmar',
#    'last_name': 'Straube',
#    'birth_name': 'Elmar Sebastian Wolfgang Straube',
#    'sex': 'm',
#    'year_of_birth': 1987,
#    'party': {'id': 201,
#     'entity_type': 'party',
#     'label': 'dieBasis',
#     'api_url': 'https://www.abgeordnetenwatch.de/api/v2/parties/201'},
#    'party_past': None,
#    'education': 'Promotion in Schulpädagogik; Master of Education; Ausgebildeter Erlebnispädagoge; ',
#    'residence': 'Augsburg',
#    'occupation': 'Wissenchaftlicher Mitarbeiter und Dozent im Bereich Schulpädagogik; Erlebnispädagoge',
#    'statistic_questions': 1,
#    'statistic_questions_answered': 1,
#    'ext_id_bundestagsverwaltung': None,
#    'qid_wikidata': None,
#    'field_title': 'Dr.'},
#   {'id': 180660,
#    'entity_type': 'politician',
#    'label': 'Stefan Ruthard',
#    'api_url': 'https://www.abgeordnetenwatch.de/api/v2/politicians/180660',
#    'abgeordnetenwatch_url': 'https://www.abgeordnetenwatch.de/profile/stefan-ruthard',
#    'first_name': 'Stefan',
#    'last_name': 'Ruthard',
#    'birth_name': 'Ruthard',
#    'sex': 'm',
#    'year_of_birth': 1962,
#    'party': {'id': 201,
#     'entity_type': 'party',
#     'label': 'dieBasis',
#     'api_url': 'https://www.abgeordnetenwatch.de/api/v2/parties/201'},
#    'party_past': None,
#    'education': 'Statlich geprüfter Techniker Fachrichtung Maschienenbau',
#    'residence': 'Eltmann',
#    'occupation': 'Angestellter Konstrukteur Sonderfahrzeugbau',
#    'statistic_questions': None,
#    'statistic_questions_answered': None,
#    'ext_id_bundestagsverwaltung': None,
#    'qid_wikidata': None,
#    'field_title': None},
#   {'id': 180659,
#    'entity_type': 'politician',
#    'label': 'Ronny Grünewald',
#    'api_url': 'https://www.abgeordnetenwatch.de/api/v2/politicians/180659',
#    'abgeordnetenwatch_url': 'https://www.abgeordnetenwatch.de/profile/ronny-gruenewald',
#    'first_name': 'Ronny',
#    'last_name': 'Grünewald',
#    'birth_name': None,
#    'sex': 'm',
#    'year_of_birth': 1983,
#    'party': {'id': 201,
#     'entity_type': 'party',
#     'label': 'dieBasis',
#     'api_url': 'https://www.abgeordnetenwatch.de/api/v2/parties/201'},
#    'party_past': None,
#    'education': 'Techniker',
#    'residence': 'Bergtheim',
#    'occupation': 'Informatiker',
#    'statistic_questions': 2,
#    'statistic_questions_answered': 2,
#    'ext_id_bundestagsverwaltung': None,
#    'qid_wikidata': None,
#    'field_title': None},
#   {'id': 180658,
#    'entity_type': 'politician',
#    'label': 'Kamilla Meisenberger',
#    'api_url': 'https://www.abgeordnetenwatch.de/api/v2/politicians/180658',
#    'abgeordnetenwatch_url': 'https://www.abgeordnetenwatch.de/profile/kamilla-meisenberger',
#    'first_name': 'Kamilla',
#    'last_name': 'Meisenberger',
#    'birth_name': None,
#    'sex': 'f',
#    'year_of_birth': None,
#    'party': {'id': 201,
#     'entity_type': 'party',
#     'label': 'dieBasis',
#     'api_url': 'https://www.abgeordnetenwatch.de/api/v2/parties/201'},
#    'party_past': None,
#    'education': None,
#    'residence': None,
#    'occupation': None,
#    'statistic_questions': None,
#    'statistic_questions_answered': None,
#    'ext_id_bundestagsverwaltung': None,
#    'qid_wikidata': None,
#    'field_title': None},
#   {'id': 180657,
#    'entity_type': 'politician',
#    'label': 'Franz Bachmann',
#    'api_url': 'https://www.abgeordnetenwatch.de/api/v2/politicians/180657',
#    'abgeordnetenwatch_url': 'https://www.abgeordnetenwatch.de/profile/franz-bachmann',
#    'first_name': 'Franz',
#    'last_name': 'Bachmann',
#    'birth_name': None,
#    'sex': 'm',
#    'year_of_birth': None,
#    'party': {'id': 201,
#     'entity_type': 'party',
#     'label': 'dieBasis',
#     'api_url': 'https://www.abgeordnetenwatch.de/api/v2/parties/201'},
#    'party_past': None,
#    'education': None,
#    'residence': None,
#    'occupation': None,
#    'statistic_questions': 1,
#    'statistic_questions_answered': 1,
#    'ext_id_bundestagsverwaltung': None,
#    'qid_wikidata': None,
#    'field_title': None},
#   {'id': 180656,
#    'entity_type': 'politician',
#    'label': 'Holger Klug',
#    'api_url': 'https://www.abgeordnetenwatch.de/api/v2/politicians/180656',
#    'abgeordnetenwatch_url': 'https://www.abgeordnetenwatch.de/profile/holger-klug',
#    'first_name': 'Holger',
#    'last_name': 'Klug',
#    'birth_name': None,
#    'sex': 'm',
#    'year_of_birth': None,
#    'party': {'id': 201,
#     'entity_type': 'party',
#     'label': 'dieBasis',
#     'api_url': 'https://www.abgeordnetenwatch.de/api/v2/parties/201'},
#    'party_past': None,
#    'education': None,
#    'residence': None,
#    'occupation': None,
#    'statistic_questions': 2,
#    'statistic_questions_answered': 1,
#    'ext_id_bundestagsverwaltung': None,
#    'qid_wikidata': None,
#    'field_title': None},
#   {'id': 180655,
#    'entity_type': 'politician',
#    'label': 'Gabriele Wittrich',
#    'api_url': 'https://www.abgeordnetenwatch.de/api/v2/politicians/180655',
#    'abgeordnetenwatch_url': 'https://www.abgeordnetenwatch.de/profile/gabriele-wittrich',
#    'first_name': 'Gabriele',
#    'last_name': 'Wittrich',
#    'birth_name': None,
#    'sex': 'f',
#    'year_of_birth': None,
#    'party': {'id': 201,
#     'entity_type': 'party',
#     'label': 'dieBasis',
#     'api_url': 'https://www.abgeordnetenwatch.de/api/v2/parties/201'},
#    'party_past': None,
#    'education': None,
#    'residence': None,
#    'occupation': None,
#    'statistic_questions': None,
#    'statistic_questions_answered': None,
#    'ext_id_bundestagsverwaltung': None,
#    'qid_wikidata': None,
#    'field_title': None}]}

# %% [markdown]
# Ok, then next: https://www.abgeordnetenwatch.de/api/v2/candidacies-mandates

# %%
nrw = requests.get(url='https://www.abgeordnetenwatch.de/api/v2/candidacies-mandates?parliament_period=139&range_end=500').json()

# %%
for mand in nrw['data']:
    if "bunse" in mand['label'].lower():
        print(mand)

# %% [markdown]
# A DataFrame would be more convenient

# %%
df = pd.DataFrame(nrw['data'])
df
# Out:
#         id        entity_type  \
# 0    58436  candidacy_mandate
# 1    58123  candidacy_mandate
# 2    57249  candidacy_mandate
# 3    57037  candidacy_mandate
# 4    56395  candidacy_mandate
# ..     ...                ...
# 190  56205  candidacy_mandate
# 191  56204  candidacy_mandate
# 192  56203  candidacy_mandate
# 193  56202  candidacy_mandate
# 194  56201  candidacy_mandate
#
#                                                  label  \
# 0    Stefan Kämmerling (Nordrhein-Westfalen 2022 - ...
# 1    Franziska Müller-Rech (Nordrhein-Westfalen 202...
# 2    Susanne Schneider (Nordrhein-Westfalen 2022 - ...
# 3    Ina Scharrenbach (Nordrhein-Westfalen 2022 - 2...
# 4    Andreas Keith-Volkmer (Nordrhein-Westfalen 202...
# ..                                                 ...
# 190  Romina Plonsker (Nordrhein-Westfalen 2022 - 2027)
# 191  Daniel Scheen-Pauls (Nordrhein-Westfalen 2022 ...
# 192  Hendrik Schmitz (Nordrhein-Westfalen 2022 - 2027)
# 193      Annika Fohn (Nordrhein-Westfalen 2022 - 2027)
# 194  Astrid Vogelheim (Nordrhein-Westfalen 2022 - 2...
#
#                                                api_url  \
# 0    https://www.abgeordnetenwatch.de/api/v2/candid...
# 1    https://www.abgeordnetenwatch.de/api/v2/candid...
# 2    https://www.abgeordnetenwatch.de/api/v2/candid...
# 3    https://www.abgeordnetenwatch.de/api/v2/candid...
# 4    https://www.abgeordnetenwatch.de/api/v2/candid...
# ..                                                 ...
# 190  https://www.abgeordnetenwatch.de/api/v2/candid...
# 191  https://www.abgeordnetenwatch.de/api/v2/candid...
# 192  https://www.abgeordnetenwatch.de/api/v2/candid...
# 193  https://www.abgeordnetenwatch.de/api/v2/candid...
# 194  https://www.abgeordnetenwatch.de/api/v2/candid...
#
#     id_external_administration id_external_administration_description  \
# 0                         None                                   None
# 1                         None                                   None
# 2                         None                                   None
# 3                         None                                   None
# 4                         None                                   None
# ..                         ...                                    ...
# 190                       None                                   None
# 191                       None                                   None
# 192                       None                                   None
# 193                       None                                   None
# 194                       None                                   None
#
#         type                                  parliament_period  \
# 0    mandate  {'id': 139, 'entity_type': 'parliament_period'...
# 1    mandate  {'id': 139, 'entity_type': 'parliament_period'...
# 2    mandate  {'id': 139, 'entity_type': 'parliament_period'...
# 3    mandate  {'id': 139, 'entity_type': 'parliament_period'...
# 4    mandate  {'id': 139, 'entity_type': 'parliament_period'...
# ..       ...                                                ...
# 190  mandate  {'id': 139, 'entity_type': 'parliament_period'...
# 191  mandate  {'id': 139, 'entity_type': 'parliament_period'...
# 192  mandate  {'id': 139, 'entity_type': 'parliament_period'...
# 193  mandate  {'id': 139, 'entity_type': 'parliament_period'...
# 194  mandate  {'id': 139, 'entity_type': 'parliament_period'...
#
#                                             politician  start_date end_date  \
# 0    {'id': 130706, 'entity_type': 'politician', 'l...  2023-03-04     None
# 1    {'id': 130233, 'entity_type': 'politician', 'l...  2023-01-27     None
# 2    {'id': 130718, 'entity_type': 'politician', 'l...  2023-01-01     None
# 3    {'id': 130328, 'entity_type': 'politician', 'l...  2022-06-30     None
# 4    {'id': 139739, 'entity_type': 'politician', 'l...        None     None
# ..                                                 ...         ...      ...
# 190  {'id': 130363, 'entity_type': 'politician', 'l...        None     None
# 191  {'id': 178595, 'entity_type': 'politician', 'l...        None     None
# 192  {'id': 130297, 'entity_type': 'politician', 'l...        None     None
# 193  {'id': 178594, 'entity_type': 'politician', 'l...        None     None
# 194  {'id': 178442, 'entity_type': 'politician', 'l...        None     None
#
#                                info  \
# 0     Nachgerückt für Ibrahim Yetim
# 1                              None
# 2                              None
# 3    Nachgerückt für Daniel Sieveke
# 4                              None
# ..                              ...
# 190                            None
# 191                            None
# 192                            None
# 193                            None
# 194                            None
#
#                                         electoral_data  \
# 0    {'id': 59360, 'entity_type': 'electoral_data',...
# 1    {'id': 59047, 'entity_type': 'electoral_data',...
# 2    {'id': 58173, 'entity_type': 'electoral_data',...
# 3    {'id': 57961, 'entity_type': 'electoral_data',...
# 4    {'id': 57319, 'entity_type': 'electoral_data',...
# ..                                                 ...
# 190  {'id': 57129, 'entity_type': 'electoral_data',...
# 191  {'id': 57128, 'entity_type': 'electoral_data',...
# 192  {'id': 57127, 'entity_type': 'electoral_data',...
# 193  {'id': 57126, 'entity_type': 'electoral_data',...
# 194  {'id': 57125, 'entity_type': 'electoral_data',...
#
#                                    fraction_membership
# 0    [{'id': 10871, 'entity_type': 'fraction_member...
# 1    [{'id': 10824, 'entity_type': 'fraction_member...
# 2    [{'id': 10817, 'entity_type': 'fraction_member...
# 3    [{'id': 10647, 'entity_type': 'fraction_member...
# 4    [{'id': 10625, 'entity_type': 'fraction_member...
# ..                                                 ...
# 190  [{'id': 10435, 'entity_type': 'fraction_member...
# 191  [{'id': 10434, 'entity_type': 'fraction_member...
# 192  [{'id': 10433, 'entity_type': 'fraction_member...
# 193  [{'id': 10432, 'entity_type': 'fraction_member...
# 194  [{'id': 10431, 'entity_type': 'fraction_member...
#
# [195 rows x 14 columns]

# %%
nrw['data'][0:10] # df works?
# Out:
# [{'id': 58436,
#   'entity_type': 'candidacy_mandate',
#   'label': 'Stefan Kämmerling (Nordrhein-Westfalen 2022 - 2027)',
#   'api_url': 'https://www.abgeordnetenwatch.de/api/v2/candidacies-mandates/58436',
#   'id_external_administration': None,
#   'id_external_administration_description': None,
#   'type': 'mandate',
#   'parliament_period': {'id': 139,
#    'entity_type': 'parliament_period',
#    'label': 'Nordrhein-Westfalen 2022 - 2027',
#    'api_url': 'https://www.abgeordnetenwatch.de/api/v2/parliament-periods/139',
#    'abgeordnetenwatch_url': 'https://www.abgeordnetenwatch.de/nordrhein-westfalen'},
#   'politician': {'id': 130706,
#    'entity_type': 'politician',
#    'label': 'Stefan Kämmerling',
#    'api_url': 'https://www.abgeordnetenwatch.de/api/v2/politicians/130706',
#    'abgeordnetenwatch_url': 'https://www.abgeordnetenwatch.de/profile/stefan-kaemmerling'},
#   'start_date': '2023-03-04',
#   'end_date': None,
#   'info': 'Nachgerückt für Ibrahim Yetim',
#   'electoral_data': {'id': 59360,
#    'entity_type': 'electoral_data',
#    'label': 'Stefan Kämmerling (Nordrhein-Westfalen 2022 - 2027)',
#    'electoral_list': None,
#    'list_position': None,
#    'constituency': None,
#    'constituency_result': None,
#    'constituency_result_count': None,
#    'mandate_won': 'moved_up'},
#   'fraction_membership': [{'id': 10871,
#     'entity_type': 'fraction_membership',
#     'label': 'SPD seit 04.03.2023',
#     'fraction': {'id': 350,
#      'entity_type': 'fraction',
#      'label': 'SPD (Nordrhein-Westfalen 2022 - 2027)',
#      'api_url': 'https://www.abgeordnetenwatch.de/api/v2/fractions/350'},
#     'valid_from': '2023-03-04',
#     'valid_until': None}]},
#  {'id': 58123,
#   'entity_type': 'candidacy_mandate',
#   'label': 'Franziska Müller-Rech (Nordrhein-Westfalen 2022 - 2027)',
#   'api_url': 'https://www.abgeordnetenwatch.de/api/v2/candidacies-mandates/58123',
#   'id_external_administration': None,
#   'id_external_administration_description': None,
#   'type': 'mandate',
#   'parliament_period': {'id': 139,
#    'entity_type': 'parliament_period',
#    'label': 'Nordrhein-Westfalen 2022 - 2027',
#    'api_url': 'https://www.abgeordnetenwatch.de/api/v2/parliament-periods/139',
#    'abgeordnetenwatch_url': 'https://www.abgeordnetenwatch.de/nordrhein-westfalen'},
#   'politician': {'id': 130233,
#    'entity_type': 'politician',
#    'label': 'Franziska Müller-Rech',
#    'api_url': 'https://www.abgeordnetenwatch.de/api/v2/politicians/130233',
#    'abgeordnetenwatch_url': 'https://www.abgeordnetenwatch.de/profile/franziska-mueller-rech'},
#   'start_date': '2023-01-27',
#   'end_date': None,
#   'info': None,
#   'electoral_data': {'id': 59047,
#    'entity_type': 'electoral_data',
#    'label': 'Franziska Müller-Rech (Nordrhein-Westfalen 2022 - 2027)',
#    'electoral_list': None,
#    'list_position': None,
#    'constituency': None,
#    'constituency_result': None,
#    'constituency_result_count': None,
#    'mandate_won': 'moved_up'},
#   'fraction_membership': [{'id': 10824,
#     'entity_type': 'fraction_membership',
#     'label': 'FDP seit 27.01.2023',
#     'fraction': {'id': 352,
#      'entity_type': 'fraction',
#      'label': 'FDP (Nordrhein-Westfalen 2022 - 2027)',
#      'api_url': 'https://www.abgeordnetenwatch.de/api/v2/fractions/352'},
#     'valid_from': '2023-01-27',
#     'valid_until': None}]},
#  {'id': 57249,
#   'entity_type': 'candidacy_mandate',
#   'label': 'Susanne Schneider (Nordrhein-Westfalen 2022 - 2027)',
#   'api_url': 'https://www.abgeordnetenwatch.de/api/v2/candidacies-mandates/57249',
#   'id_external_administration': None,
#   'id_external_administration_description': None,
#   'type': 'mandate',
#   'parliament_period': {'id': 139,
#    'entity_type': 'parliament_period',
#    'label': 'Nordrhein-Westfalen 2022 - 2027',
#    'api_url': 'https://www.abgeordnetenwatch.de/api/v2/parliament-periods/139',
#    'abgeordnetenwatch_url': 'https://www.abgeordnetenwatch.de/nordrhein-westfalen'},
#   'politician': {'id': 130718,
#    'entity_type': 'politician',
#    'label': 'Susanne Schneider',
#    'api_url': 'https://www.abgeordnetenwatch.de/api/v2/politicians/130718',
#    'abgeordnetenwatch_url': 'https://www.abgeordnetenwatch.de/profile/susanne-schneider'},
#   'start_date': '2023-01-01',
#   'end_date': None,
#   'info': None,
#   'electoral_data': {'id': 58173,
#    'entity_type': 'electoral_data',
#    'label': 'Susanne Schneider (Nordrhein-Westfalen 2022 - 2027)',
#    'electoral_list': None,
#    'list_position': None,
#    'constituency': None,
#    'constituency_result': None,
#    'constituency_result_count': None,
#    'mandate_won': 'moved_up'},
#   'fraction_membership': [{'id': 10817,
#     'entity_type': 'fraction_membership',
#     'label': 'FDP seit 01.01.2023',
#     'fraction': {'id': 352,
#      'entity_type': 'fraction',
#      'label': 'FDP (Nordrhein-Westfalen 2022 - 2027)',
#      'api_url': 'https://www.abgeordnetenwatch.de/api/v2/fractions/352'},
#     'valid_from': '2023-01-01',
#     'valid_until': None}]},
#  {'id': 57037,
#   'entity_type': 'candidacy_mandate',
#   'label': 'Ina Scharrenbach (Nordrhein-Westfalen 2022 - 2027)',
#   'api_url': 'https://www.abgeordnetenwatch.de/api/v2/candidacies-mandates/57037',
#   'id_external_administration': None,
#   'id_external_administration_description': None,
#   'type': 'mandate',
#   'parliament_period': {'id': 139,
#    'entity_type': 'parliament_period',
#    'label': 'Nordrhein-Westfalen 2022 - 2027',
#    'api_url': 'https://www.abgeordnetenwatch.de/api/v2/parliament-periods/139',
#    'abgeordnetenwatch_url': 'https://www.abgeordnetenwatch.de/nordrhein-westfalen'},
#   'politician': {'id': 130328,
#    'entity_type': 'politician',
#    'label': 'Ina Scharrenbach',
#    'api_url': 'https://www.abgeordnetenwatch.de/api/v2/politicians/130328',
#    'abgeordnetenwatch_url': 'https://www.abgeordnetenwatch.de/profile/ina-scharrenbach'},
#   'start_date': '2022-06-30',
#   'end_date': None,
#   'info': 'Nachgerückt für Daniel Sieveke',
#   'electoral_data': {'id': 57961,
#    'entity_type': 'electoral_data',
#    'label': 'Ina Scharrenbach (Nordrhein-Westfalen 2022 - 2027)',
#    'electoral_list': None,
#    'list_position': None,
#    'constituency': None,
#    'constituency_result': None,
#    'constituency_result_count': None,
#    'mandate_won': 'moved_up'},
#   'fraction_membership': [{'id': 10647,
#     'entity_type': 'fraction_membership',
#     'label': 'CDU seit 30.06.2022',
#     'fraction': {'id': 349,
#      'entity_type': 'fraction',
#      'label': 'CDU (Nordrhein-Westfalen 2022 - 2027)',
#      'api_url': 'https://www.abgeordnetenwatch.de/api/v2/fractions/349'},
#     'valid_from': '2022-06-30',
#     'valid_until': None}]},
#  {'id': 56395,
#   'entity_type': 'candidacy_mandate',
#   'label': 'Andreas Keith-Volkmer (Nordrhein-Westfalen 2022 - 2027)',
#   'api_url': 'https://www.abgeordnetenwatch.de/api/v2/candidacies-mandates/56395',
#   'id_external_administration': None,
#   'id_external_administration_description': None,
#   'type': 'mandate',
#   'parliament_period': {'id': 139,
#    'entity_type': 'parliament_period',
#    'label': 'Nordrhein-Westfalen 2022 - 2027',
#    'api_url': 'https://www.abgeordnetenwatch.de/api/v2/parliament-periods/139',
#    'abgeordnetenwatch_url': 'https://www.abgeordnetenwatch.de/nordrhein-westfalen'},
#   'politician': {'id': 139739,
#    'entity_type': 'politician',
#    'label': 'Andreas Keith-Volkmer',
#    'api_url': 'https://www.abgeordnetenwatch.de/api/v2/politicians/139739',
#    'abgeordnetenwatch_url': 'https://www.abgeordnetenwatch.de/profile/andreas-keith-volkmer'},
#   'start_date': None,
#   'end_date': None,
#   'info': None,
#   'electoral_data': {'id': 57319,
#    'entity_type': 'electoral_data',
#    'label': 'Andreas Keith-Volkmer (Nordrhein-Westfalen 2022 - 2027)',
#    'electoral_list': {'id': 509,
#     'entity_type': 'electoral_list',
#     'label': 'Landesliste AfD (Nordrhein-Westfalen 2022 - 2027)',
#     'api_url': 'https://www.abgeordnetenwatch.de/api/v2/electoral-lists/509'},
#    'list_position': 3,
#    'constituency': None,
#    'constituency_result': None,
#    'constituency_result_count': None,
#    'mandate_won': 'list'},
#   'fraction_membership': [{'id': 10625,
#     'entity_type': 'fraction_membership',
#     'label': 'AfD',
#     'fraction': {'id': 348,
#      'entity_type': 'fraction',
#      'label': 'AfD (Nordrhein-Westfalen 2022 - 2027)',
#      'api_url': 'https://www.abgeordnetenwatch.de/api/v2/fractions/348'},
#     'valid_from': None,
#     'valid_until': None}]},
#  {'id': 56394,
#   'entity_type': 'candidacy_mandate',
#   'label': 'Frederick Cordes (Nordrhein-Westfalen 2022 - 2027)',
#   'api_url': 'https://www.abgeordnetenwatch.de/api/v2/candidacies-mandates/56394',
#   'id_external_administration': None,
#   'id_external_administration_description': None,
#   'type': 'mandate',
#   'parliament_period': {'id': 139,
#    'entity_type': 'parliament_period',
#    'label': 'Nordrhein-Westfalen 2022 - 2027',
#    'api_url': 'https://www.abgeordnetenwatch.de/api/v2/parliament-periods/139',
#    'abgeordnetenwatch_url': 'https://www.abgeordnetenwatch.de/nordrhein-westfalen'},
#   'politician': {'id': 175245,
#    'entity_type': 'politician',
#    'label': 'Frederick Cordes',
#    'api_url': 'https://www.abgeordnetenwatch.de/api/v2/politicians/175245',
#    'abgeordnetenwatch_url': 'https://www.abgeordnetenwatch.de/profile/frederick-cordes'},
#   'start_date': None,
#   'end_date': None,
#   'info': None,
#   'electoral_data': {'id': 57318,
#    'entity_type': 'electoral_data',
#    'label': 'Frederick Cordes (Nordrhein-Westfalen 2022 - 2027)',
#    'electoral_list': {'id': 506,
#     'entity_type': 'electoral_list',
#     'label': 'Landesliste SPD (Nordrhein-Westfalen 2022 - 2027)',
#     'api_url': 'https://www.abgeordnetenwatch.de/api/v2/electoral-lists/506'},
#    'list_position': 13,
#    'constituency': None,
#    'constituency_result': None,
#    'constituency_result_count': None,
#    'mandate_won': 'list'},
#   'fraction_membership': [{'id': 10624,
#     'entity_type': 'fraction_membership',
#     'label': 'SPD',
#     'fraction': {'id': 350,
#      'entity_type': 'fraction',
#      'label': 'SPD (Nordrhein-Westfalen 2022 - 2027)',
#      'api_url': 'https://www.abgeordnetenwatch.de/api/v2/fractions/350'},
#     'valid_from': None,
#     'valid_until': None}]},
#  {'id': 56393,
#   'entity_type': 'candidacy_mandate',
#   'label': 'Gregor Kaiser (Nordrhein-Westfalen 2022 - 2027)',
#   'api_url': 'https://www.abgeordnetenwatch.de/api/v2/candidacies-mandates/56393',
#   'id_external_administration': None,
#   'id_external_administration_description': None,
#   'type': 'mandate',
#   'parliament_period': {'id': 139,
#    'entity_type': 'parliament_period',
#    'label': 'Nordrhein-Westfalen 2022 - 2027',
#    'api_url': 'https://www.abgeordnetenwatch.de/api/v2/parliament-periods/139',
#    'abgeordnetenwatch_url': 'https://www.abgeordnetenwatch.de/nordrhein-westfalen'},
#   'politician': {'id': 130256,
#    'entity_type': 'politician',
#    'label': 'Gregor Kaiser',
#    'api_url': 'https://www.abgeordnetenwatch.de/api/v2/politicians/130256',
#    'abgeordnetenwatch_url': 'https://www.abgeordnetenwatch.de/profile/gregor-kaiser'},
#   'start_date': None,
#   'end_date': None,
#   'info': None,
#   'electoral_data': {'id': 57317,
#    'entity_type': 'electoral_data',
#    'label': 'Gregor Kaiser (Nordrhein-Westfalen 2022 - 2027)',
#    'electoral_list': {'id': 508,
#     'entity_type': 'electoral_list',
#     'label': 'Landesliste Bündnis 90/Die Grünen (Nordrhein-Westfalen 2022 - 2027)',
#     'api_url': 'https://www.abgeordnetenwatch.de/api/v2/electoral-lists/508'},
#    'list_position': 28,
#    'constituency': {'id': 11867,
#     'entity_type': 'constituency',
#     'label': '128 - Olpe (Nordrhein-Westfalen 2022 - 2027)',
#     'api_url': 'https://www.abgeordnetenwatch.de/api/v2/constituencies/11867'},
#    'constituency_result': 11.6,
#    'constituency_result_count': None,
#    'mandate_won': 'list'},
#   'fraction_membership': [{'id': 10623,
#     'entity_type': 'fraction_membership',
#     'label': 'Bündnis 90/Die Grünen',
#     'fraction': {'id': 353,
#      'entity_type': 'fraction',
#      'label': 'Bündnis 90/Die Grünen (Nordrhein-Westfalen 2022 - 2027)',
#      'api_url': 'https://www.abgeordnetenwatch.de/api/v2/fractions/353'},
#     'valid_from': None,
#     'valid_until': None}]},
#  {'id': 56392,
#   'entity_type': 'candidacy_mandate',
#   'label': 'Christin-Marie Stamm (Nordrhein-Westfalen 2022 - 2027)',
#   'api_url': 'https://www.abgeordnetenwatch.de/api/v2/candidacies-mandates/56392',
#   'id_external_administration': None,
#   'id_external_administration_description': None,
#   'type': 'mandate',
#   'parliament_period': {'id': 139,
#    'entity_type': 'parliament_period',
#    'label': 'Nordrhein-Westfalen 2022 - 2027',
#    'api_url': 'https://www.abgeordnetenwatch.de/api/v2/parliament-periods/139',
#    'abgeordnetenwatch_url': 'https://www.abgeordnetenwatch.de/nordrhein-westfalen'},
#   'politician': {'id': 178441,
#    'entity_type': 'politician',
#    'label': 'Christin-Marie Stamm',
#    'api_url': 'https://www.abgeordnetenwatch.de/api/v2/politicians/178441',
#    'abgeordnetenwatch_url': 'https://www.abgeordnetenwatch.de/profile/christin-marie-stamm'},
#   'start_date': None,
#   'end_date': None,
#   'info': None,
#   'electoral_data': {'id': 57316,
#    'entity_type': 'electoral_data',
#    'label': 'Christin-Marie Stamm (Nordrhein-Westfalen 2022 - 2027)',
#    'electoral_list': {'id': 506,
#     'entity_type': 'electoral_list',
#     'label': 'Landesliste SPD (Nordrhein-Westfalen 2022 - 2027)',
#     'api_url': 'https://www.abgeordnetenwatch.de/api/v2/electoral-lists/506'},
#    'list_position': 12,
#    'constituency': {'id': 11867,
#     'entity_type': 'constituency',
#     'label': '128 - Olpe (Nordrhein-Westfalen 2022 - 2027)',
#     'api_url': 'https://www.abgeordnetenwatch.de/api/v2/constituencies/11867'},
#    'constituency_result': 20.1,
#    'constituency_result_count': None,
#    'mandate_won': 'list'},
#   'fraction_membership': [{'id': 10622,
#     'entity_type': 'fraction_membership',
#     'label': 'SPD',
#     'fraction': {'id': 350,
#      'entity_type': 'fraction',
#      'label': 'SPD (Nordrhein-Westfalen 2022 - 2027)',
#      'api_url': 'https://www.abgeordnetenwatch.de/api/v2/fractions/350'},
#     'valid_from': None,
#     'valid_until': None}]},
#  {'id': 56391,
#   'entity_type': 'candidacy_mandate',
#   'label': 'Angela Freimuth (Nordrhein-Westfalen 2022 - 2027)',
#   'api_url': 'https://www.abgeordnetenwatch.de/api/v2/candidacies-mandates/56391',
#   'id_external_administration': None,
#   'id_external_administration_description': None,
#   'type': 'mandate',
#   'parliament_period': {'id': 139,
#    'entity_type': 'parliament_period',
#    'label': 'Nordrhein-Westfalen 2022 - 2027',
#    'api_url': 'https://www.abgeordnetenwatch.de/api/v2/parliament-periods/139',
#    'abgeordnetenwatch_url': 'https://www.abgeordnetenwatch.de/nordrhein-westfalen'},
#   'politician': {'id': 130060,
#    'entity_type': 'politician',
#    'label': 'Angela Freimuth',
#    'api_url': 'https://www.abgeordnetenwatch.de/api/v2/politicians/130060',
#    'abgeordnetenwatch_url': 'https://www.abgeordnetenwatch.de/profile/angela-freimuth'},
#   'start_date': None,
#   'end_date': None,
#   'info': None,
#   'electoral_data': {'id': 57315,
#    'entity_type': 'electoral_data',
#    'label': 'Angela Freimuth (Nordrhein-Westfalen 2022 - 2027)',
#    'electoral_list': {'id': 507,
#     'entity_type': 'electoral_list',
#     'label': 'Landesliste FDP (Nordrhein-Westfalen 2022 - 2027)',
#     'api_url': 'https://www.abgeordnetenwatch.de/api/v2/electoral-lists/507'},
#    'list_position': 5,
#    'constituency': {'id': 11862,
#     'entity_type': 'constituency',
#     'label': '123 - Märkischer Kreis III (Nordrhein-Westfalen 2022 - 2027)',
#     'api_url': 'https://www.abgeordnetenwatch.de/api/v2/constituencies/11862'},
#    'constituency_result': 6.5,
#    'constituency_result_count': None,
#    'mandate_won': 'list'},
#   'fraction_membership': [{'id': 10621,
#     'entity_type': 'fraction_membership',
#     'label': 'FDP',
#     'fraction': {'id': 352,
#      'entity_type': 'fraction',
#      'label': 'FDP (Nordrhein-Westfalen 2022 - 2027)',
#      'api_url': 'https://www.abgeordnetenwatch.de/api/v2/fractions/352'},
#     'valid_from': None,
#     'valid_until': None}]},
#  {'id': 56390,
#   'entity_type': 'candidacy_mandate',
#   'label': 'Gordan Dudas (Nordrhein-Westfalen 2022 - 2027)',
#   'api_url': 'https://www.abgeordnetenwatch.de/api/v2/candidacies-mandates/56390',
#   'id_external_administration': None,
#   'id_external_administration_description': None,
#   'type': 'mandate',
#   'parliament_period': {'id': 139,
#    'entity_type': 'parliament_period',
#    'label': 'Nordrhein-Westfalen 2022 - 2027',
#    'api_url': 'https://www.abgeordnetenwatch.de/api/v2/parliament-periods/139',
#    'abgeordnetenwatch_url': 'https://www.abgeordnetenwatch.de/nordrhein-westfalen'},
#   'politician': {'id': 130254,
#    'entity_type': 'politician',
#    'label': 'Gordan Dudas',
#    'api_url': 'https://www.abgeordnetenwatch.de/api/v2/politicians/130254',
#    'abgeordnetenwatch_url': 'https://www.abgeordnetenwatch.de/profile/gordan-dudas'},
#   'start_date': None,
#   'end_date': None,
#   'info': None,
#   'electoral_data': {'id': 57314,
#    'entity_type': 'electoral_data',
#    'label': 'Gordan Dudas (Nordrhein-Westfalen 2022 - 2027)',
#    'electoral_list': {'id': 506,
#     'entity_type': 'electoral_list',
#     'label': 'Landesliste SPD (Nordrhein-Westfalen 2022 - 2027)',
#     'api_url': 'https://www.abgeordnetenwatch.de/api/v2/electoral-lists/506'},
#    'list_position': 9,
#    'constituency': {'id': 11862,
#     'entity_type': 'constituency',
#     'label': '123 - Märkischer Kreis III (Nordrhein-Westfalen 2022 - 2027)',
#     'api_url': 'https://www.abgeordnetenwatch.de/api/v2/constituencies/11862'},
#    'constituency_result': 35.6,
#    'constituency_result_count': None,
#    'mandate_won': 'list'},
#   'fraction_membership': [{'id': 10620,
#     'entity_type': 'fraction_membership',
#     'label': 'SPD',
#     'fraction': {'id': 350,
#      'entity_type': 'fraction',
#      'label': 'SPD (Nordrhein-Westfalen 2022 - 2027)',
#      'api_url': 'https://www.abgeordnetenwatch.de/api/v2/fractions/350'},
#     'valid_from': None,
#     'valid_until': None}]}]

# %%
nrw_for_df = []

for mand in nrw['data']:
    print(mand['label'])
    mand_dict = {}
    mand_dict['id']=mand['id']
    mand_dict['label']=mand['label']
    mand_dict['pol_full_name']=mand['politician']['label']
    mand_dict['pol_url']=mand['politician']['api_url']
    mand_dict['start_date']=mand['start_date']
    mand_dict['constituency_label']=mand['electoral_data']['constituency']['label']
    nrw_for_df.append(mand_dict)
# Out:
# Stefan Kämmerling (Nordrhein-Westfalen 2022 - 2027)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[40], line 11
#       9 mand_dict['pol_url']=mand['politician']['api_url']
#      10 mand_dict['start_date']=mand['start_date']
# ---> 11 mand_dict['constituency_label']=mand['electoral_data']['constituency']['label']
#      12 nrw_for_df.append(mand_dict)
#
# TypeError: 'NoneType' object is not subscriptable

# %%
nrw_for_df = []

for mand in nrw['data']:
    print(mand['label'])
    mand_dict = {}
    mand_dict['id']=mand['id']
    mand_dict['label']=mand['label']
    mand_dict['pol_full_name']=mand['politician']['label']
    mand_dict['pol_url']=mand['politician']['api_url']
    mand_dict['start_date']=mand['start_date']
    try: mand_dict['constituency_label']=mand['electoral_data']['constituency']['label']
    except: mand_dict['constituency_label']= None
    nrw_for_df.append(mand_dict)
# Out:
# Stefan Kämmerling (Nordrhein-Westfalen 2022 - 2027)
# Franziska Müller-Rech (Nordrhein-Westfalen 2022 - 2027)
# Susanne Schneider (Nordrhein-Westfalen 2022 - 2027)
# Ina Scharrenbach (Nordrhein-Westfalen 2022 - 2027)
# Andreas Keith-Volkmer (Nordrhein-Westfalen 2022 - 2027)
# Frederick Cordes (Nordrhein-Westfalen 2022 - 2027)
# Gregor Kaiser (Nordrhein-Westfalen 2022 - 2027)
# Christin-Marie Stamm (Nordrhein-Westfalen 2022 - 2027)
# Angela Freimuth (Nordrhein-Westfalen 2022 - 2027)
# Gordan Dudas (Nordrhein-Westfalen 2022 - 2027)
# Inge Blask (Nordrhein-Westfalen 2022 - 2027)
# Dagmar Hanses (Nordrhein-Westfalen 2022 - 2027)
# Christof Rasche (Nordrhein-Westfalen 2022 - 2027)
# Michael Röls (Nordrhein-Westfalen 2022 - 2027)
# Christian Loose (Nordrhein-Westfalen 2022 - 2027)
# Verena Schäffer (Nordrhein-Westfalen 2022 - 2027)
# Marc Lürbke (Nordrhein-Westfalen 2022 - 2027)
# Norika Creuzmann (Nordrhein-Westfalen 2022 - 2027)
# Julia Eisentraut (Nordrhein-Westfalen 2022 - 2027)
# Ellen Stock (Nordrhein-Westfalen 2022 - 2027)
# Wibke Brems (Nordrhein-Westfalen 2022 - 2027)
# Christina Osei (Nordrhein-Westfalen 2022 - 2027)
# Markus Wagner (Nordrhein-Westfalen 2022 - 2027)
# Benjamin Rauer (Nordrhein-Westfalen 2022 - 2027)
# Christian Blex (Nordrhein-Westfalen 2022 - 2027)
# Hedwig Tarner (Nordrhein-Westfalen 2022 - 2027)
# Josefine Paul (Nordrhein-Westfalen 2022 - 2027)
# Norwich Rüße (Nordrhein-Westfalen 2022 - 2027)
# Dennis Sonne (Nordrhein-Westfalen 2022 - 2027)
# André Stinka (Nordrhein-Westfalen 2022 - 2027)
# Henning Höne (Nordrhein-Westfalen 2022 - 2027)
# Nina Andrieshen (Nordrhein-Westfalen 2022 - 2027)
# Ilayda Bostancieri (Nordrhein-Westfalen 2022 - 2027)
# Enxhi Seli-Zacharias (Nordrhein-Westfalen 2022 - 2027)
# Daniel Zerbin (Nordrhein-Westfalen 2022 - 2027)
# Jan Matzoll (Nordrhein-Westfalen 2022 - 2027)
# Mehrdad Mostofizadeh (Nordrhein-Westfalen 2022 - 2027)
# Ralf Witzel (Nordrhein-Westfalen 2022 - 2027)
# Gönül Eğlence (Nordrhein-Westfalen 2022 - 2027)
# Jule Wenzel (Nordrhein-Westfalen 2022 - 2027)
# Volkhard Wille (Nordrhein-Westfalen 2022 - 2027)
# Dietmar Brockes (Nordrhein-Westfalen 2022 - 2027)
# Lena Zingsheim-Zobel (Nordrhein-Westfalen 2022 - 2027)
# Meral Thoms (Nordrhein-Westfalen 2022 - 2027)
# Martin Vincentz (Nordrhein-Westfalen 2022 - 2027)
# Simon Rock (Nordrhein-Westfalen 2022 - 2027)
# Zacharias Schalley (Nordrhein-Westfalen 2022 - 2027)
# Stefan Engstfeld (Nordrhein-Westfalen 2022 - 2027)
# Mona Neubaur (Nordrhein-Westfalen 2022 - 2027)
# Elisabeth Müller-Witt (Nordrhein-Westfalen 2022 - 2027)
# Ina Besche-Krastl (Nordrhein-Westfalen 2022 - 2027)
# Dirk Wedel (Nordrhein-Westfalen 2022 - 2027)
# Sven Wolf (Nordrhein-Westfalen 2022 - 2027)
# Hartmut Beucker (Nordrhein-Westfalen 2022 - 2027)
# Marcel Hafke (Nordrhein-Westfalen 2022 - 2027)
# Julia Höller (Nordrhein-Westfalen 2022 - 2027)
# Tim Achtermeyer (Nordrhein-Westfalen 2022 - 2027)
# Martin Metz (Nordrhein-Westfalen 2022 - 2027)
# Marc Zimmermann (Nordrhein-Westfalen 2022 - 2027)
# Carlo Clemens (Nordrhein-Westfalen 2022 - 2027)
# Tülay Durdu (Nordrhein-Westfalen 2022 - 2027)
# Sven Tritschler (Nordrhein-Westfalen 2022 - 2027)
# Yvonne Gebauer (Nordrhein-Westfalen 2022 - 2027)
# Jochen Ott (Nordrhein-Westfalen 2022 - 2027)
# Klaus Esser (Nordrhein-Westfalen 2022 - 2027)
# Antje Grothus (Nordrhein-Westfalen 2022 - 2027)
# Anja von Marenholtz-Diemer (Nordrhein-Westfalen 2022 - 2027)
# Laura Postma (Nordrhein-Westfalen 2022 - 2027)
# Werner Pfeil (Nordrhein-Westfalen 2022 - 2027)
# Lisa-Kristin Kapteinat (Nordrhein-Westfalen 2022 - 2027)
# Anna Teresa Kavena (Nordrhein-Westfalen 2022 - 2027)
# Oliver Krauß (Nordrhein-Westfalen 2022 - 2027)
# Jochen Ritter (Nordrhein-Westfalen 2022 - 2027)
# Anke Fuchs-Dreisbach (Nordrhein-Westfalen 2022 - 2027)
# Jens Kamieth (Nordrhein-Westfalen 2022 - 2027)
# Matthias Kerkhoff (Nordrhein-Westfalen 2022 - 2027)
# Klaus Kaiser (Nordrhein-Westfalen 2022 - 2027)
# Ralf Schwarzkopf (Nordrhein-Westfalen 2022 - 2027)
# Matthias Eggers (Nordrhein-Westfalen 2022 - 2027)
# Thorsten Schick (Nordrhein-Westfalen 2022 - 2027)
# Jörg Blöming (Nordrhein-Westfalen 2022 - 2027)
# Heinrich Frieling (Nordrhein-Westfalen 2022 - 2027)
# Justus Moor (Nordrhein-Westfalen 2022 - 2027)
# Silvia Gosewinkel (Nordrhein-Westfalen 2022 - 2027)
# Rainer Schmeltzer (Nordrhein-Westfalen 2022 - 2027)
# Hartmut Ganzke (Nordrhein-Westfalen 2022 - 2027)
# Anja Butschkau (Nordrhein-Westfalen 2022 - 2027)
# Nadja Lüders (Nordrhein-Westfalen 2022 - 2027)
# Volkan Baran (Nordrhein-Westfalen 2022 - 2027)
# Ralf Stoltze (Nordrhein-Westfalen 2022 - 2027)
# Alexander Vogt (Nordrhein-Westfalen 2022 - 2027)
# Serdar Yüksel (Nordrhein-Westfalen 2022 - 2027)
# Bastian Hartmann (Nordrhein-Westfalen 2022 - 2027)
# Andrea Busche (Nordrhein-Westfalen 2022 - 2027)
# Nadja Büteführ (Nordrhein-Westfalen 2022 - 2027)
# Kirsten Stich (Nordrhein-Westfalen 2022 - 2027)
# Ina Blumenthal (Nordrhein-Westfalen 2022 - 2027)
# Wolfgang Jörg (Nordrhein-Westfalen 2022 - 2027)
# Matthias Goeken (Nordrhein-Westfalen 2022 - 2027)
# Bernhard Hoppe-Biermeyer (Nordrhein-Westfalen 2022 - 2027)
# Dennis Maelzer (Nordrhein-Westfalen 2022 - 2027)
# Alexander Baer (Nordrhein-Westfalen 2022 - 2027)
# Klaus Hansen (Nordrhein-Westfalen 2022 - 2027)
# André Kuper (Nordrhein-Westfalen 2022 - 2027)
# Raphael Tigges (Nordrhein-Westfalen 2022 - 2027)
# Thorsten Klute (Nordrhein-Westfalen 2022 - 2027)
# Tom Brüntrup (Nordrhein-Westfalen 2022 - 2027)
# Christina Kampmann (Nordrhein-Westfalen 2022 - 2027)
# Christian Obrok (Nordrhein-Westfalen 2022 - 2027)
# Christian Dahm (Nordrhein-Westfalen 2022 - 2027)
# Christina Weng (Nordrhein-Westfalen 2022 - 2027)
# Bianca Winkelmann (Nordrhein-Westfalen 2022 - 2027)
# Markus Höner (Nordrhein-Westfalen 2022 - 2027)
# Daniel Hagemeier (Nordrhein-Westfalen 2022 - 2027)
# Dorothea Deppermann (Nordrhein-Westfalen 2022 - 2027)
# Robin Korte (Nordrhein-Westfalen 2022 - 2027)
# Simone Wendland (Nordrhein-Westfalen 2022 - 2027)
# Karl-Josef Laumann (Nordrhein-Westfalen 2022 - 2027)
# Andrea Stullich (Nordrhein-Westfalen 2022 - 2027)
# Christina Schulze Föcking (Nordrhein-Westfalen 2022 - 2027)
# Dietmar Panske (Nordrhein-Westfalen 2022 - 2027)
# Wilhelm Korth (Nordrhein-Westfalen 2022 - 2027)
# Heike Wermer (Nordrhein-Westfalen 2022 - 2027)
# Hendrik Wüst (Nordrhein-Westfalen 2022 - 2027)
# Thomas Göddertz (Nordrhein-Westfalen 2022 - 2027)
# Sebastian Watermeier (Nordrhein-Westfalen 2022 - 2027)
# Christin Siebel (Nordrhein-Westfalen 2022 - 2027)
# Josef Hovenjürgen (Nordrhein-Westfalen 2022 - 2027)
# Carsten Löcker (Nordrhein-Westfalen 2022 - 2027)
# Fabian Schrumpf (Nordrhein-Westfalen 2022 - 2027)
# Julia Kahle-Hausmann (Nordrhein-Westfalen 2022 - 2027)
# Frank Müller (Nordrhein-Westfalen 2022 - 2027)
# Thomas Kutschaty (Nordrhein-Westfalen 2022 - 2027)
# Rodion Bakum (Nordrhein-Westfalen 2022 - 2027)
# Frank Börner (Nordrhein-Westfalen 2022 - 2027)
# Benedikt Falszewski (Nordrhein-Westfalen 2022 - 2027)
# Sarah Philipp (Nordrhein-Westfalen 2022 - 2027)
# Charlotte Quik (Nordrhein-Westfalen 2022 - 2027)
# René Schneider (Nordrhein-Westfalen 2022 - 2027)
# Stefan Zimkeit (Nordrhein-Westfalen 2022 - 2027)
# Sonja Bongers (Nordrhein-Westfalen 2022 - 2027)
# Günther Bergmann (Nordrhein-Westfalen 2022 - 2027)
# Stephan Wolters (Nordrhein-Westfalen 2022 - 2027)
# Marcus Optendrenk (Nordrhein-Westfalen 2022 - 2027)
# Guido Görtz (Nordrhein-Westfalen 2022 - 2027)
# Jochen Klenner (Nordrhein-Westfalen 2022 - 2027)
# Vanessa Odermatt (Nordrhein-Westfalen 2022 - 2027)
# Marc Blondin (Nordrhein-Westfalen 2022 - 2027)
# Britta Oellers (Nordrhein-Westfalen 2022 - 2027)
# Lutz Lienenkämper (Nordrhein-Westfalen 2022 - 2027)
# Heike Troles (Nordrhein-Westfalen 2022 - 2027)
# Jörg Geerlings (Nordrhein-Westfalen 2022 - 2027)
# Peter Blumenrath (Nordrhein-Westfalen 2022 - 2027)
# Angela Erwin (Nordrhein-Westfalen 2022 - 2027)
# Marco Schmitz (Nordrhein-Westfalen 2022 - 2027)
# Olaf Lehne (Nordrhein-Westfalen 2022 - 2027)
# Martin Sträßer (Nordrhein-Westfalen 2022 - 2027)
# Jan Volker Heinisch (Nordrhein-Westfalen 2022 - 2027)
# Christian Untrieser (Nordrhein-Westfalen 2022 - 2027)
# Claudia Schlottmann (Nordrhein-Westfalen 2022 - 2027)
# Jens-Peter Nettekoven (Nordrhein-Westfalen 2022 - 2027)
# Sebastian Haug (Nordrhein-Westfalen 2022 - 2027)
# Josef Neumann (Nordrhein-Westfalen 2022 - 2027)
# Dilek Engin (Nordrhein-Westfalen 2022 - 2027)
# Andreas Bialas (Nordrhein-Westfalen 2022 - 2027)
# Christos Katzidis (Nordrhein-Westfalen 2022 - 2027)
# Guido Déus (Nordrhein-Westfalen 2022 - 2027)
# Sascha Lienesch (Nordrhein-Westfalen 2022 - 2027)
# Katharina Gebauer (Nordrhein-Westfalen 2022 - 2027)
# Jonathan Grunwald (Nordrhein-Westfalen 2022 - 2027)
# Björn Franken (Nordrhein-Westfalen 2022 - 2027)
# Bodo Löttgen (Nordrhein-Westfalen 2022 - 2027)
# Christian Berger (Nordrhein-Westfalen 2022 - 2027)
# Herbert Reul (Nordrhein-Westfalen 2022 - 2027)
# Martin Lucke (Nordrhein-Westfalen 2022 - 2027)
# Rüdiger Scholz (Nordrhein-Westfalen 2022 - 2027)
# Carolin Kirsch (Nordrhein-Westfalen 2022 - 2027)
# Berivan Aymaz (Nordrhein-Westfalen 2022 - 2027)
# Florian Braun (Nordrhein-Westfalen 2022 - 2027)
# Lena Teschlade (Nordrhein-Westfalen 2022 - 2027)
# Arndt Klocke (Nordrhein-Westfalen 2022 - 2027)
# Frank Jablonski (Nordrhein-Westfalen 2022 - 2027)
# Eileen Woestmann (Nordrhein-Westfalen 2022 - 2027)
# Ralf Nolten (Nordrhein-Westfalen 2022 - 2027)
# Patricia Peill (Nordrhein-Westfalen 2022 - 2027)
# Thomas Schnelle (Nordrhein-Westfalen 2022 - 2027)
# Bernd Krückel (Nordrhein-Westfalen 2022 - 2027)
# Klaus Voussem (Nordrhein-Westfalen 2022 - 2027)
# Gregor Golland (Nordrhein-Westfalen 2022 - 2027)
# Thomas Okos (Nordrhein-Westfalen 2022 - 2027)
# Romina Plonsker (Nordrhein-Westfalen 2022 - 2027)
# Daniel Scheen-Pauls (Nordrhein-Westfalen 2022 - 2027)
# Hendrik Schmitz (Nordrhein-Westfalen 2022 - 2027)
# Annika Fohn (Nordrhein-Westfalen 2022 - 2027)
# Astrid Vogelheim (Nordrhein-Westfalen 2022 - 2027)

# %%
nrw_for_df
# Out:
# [{'id': 58436,
#   'label': 'Stefan Kämmerling (Nordrhein-Westfalen 2022 - 2027)',
#   'pol_full_name': 'Stefan Kämmerling',
#   'pol_url': 'https://www.abgeordnetenwatch.de/api/v2/politicians/130706',
#   'start_date': '2023-03-04',
#   'constituency_label': None},
#  {'id': 58123,
#   'label': 'Franziska Müller-Rech (Nordrhein-Westfalen 2022 - 2027)',
#   'pol_full_name': 'Franziska Müller-Rech',
#   'pol_url': 'https://www.abgeordnetenwatch.de/api/v2/politicians/130233',
#   'start_date': '2023-01-27',
#   'constituency_label': None},
#  {'id': 57249,
#   'label': 'Susanne Schneider (Nordrhein-Westfalen 2022 - 2027)',
#   'pol_full_name': 'Susanne Schneider',
#   'pol_url': 'https://www.abgeordnetenwatch.de/api/v2/politicians/130718',
#   'start_date': '2023-01-01',
#   'constituency_label': None},
#  {'id': 57037,
#   'label': 'Ina Scharrenbach (Nordrhein-Westfalen 2022 - 2027)',
#   'pol_full_name': 'Ina Scharrenbach',
#   'pol_url': 'https://www.abgeordnetenwatch.de/api/v2/politicians/130328',
#   'start_date': '2022-06-30',
#   'constituency_label': None},
#  {'id': 56395,
#   'label': 'Andreas Keith-Volkmer (Nordrhein-Westfalen 2022 - 2027)',
#   'pol_full_name': 'Andreas Keith-Volkmer',
#   'pol_url': 'https://www.abgeordnetenwatch.de/api/v2/politicians/139739',
#   'start_date': None,
#   'constituency_label': None},
#  {'id': 56394,
#   'label': 'Frederick Cordes (Nordrhein-Westfalen 2022 - 2027)',
#   'pol_full_name': 'Frederick Cordes',
#   'pol_url': 'https://www.abgeordnetenwatch.de/api/v2/politicians/175245',
#   'start_date': None,
#   'constituency_label': None},
#  {'id': 56393,
#   'label': 'Gregor Kaiser (Nordrhein-Westfalen 2022 - 2027)',
#   'pol_full_name': 'Gregor Kaiser',
#   'pol_url': 'https://www.abgeordnetenwatch.de/api/v2/politicians/130256',
#   'start_date': None,
#   'constituency_label': '128 - Olpe (Nordrhein-Westfalen 2022 - 2027)'},
#  {'id': 56392,
#   'label': 'Christin-Marie Stamm (Nordrhein-Westfalen 2022 - 2027)',
#   'pol_full_name': 'Christin-Marie Stamm',
#   'pol_url': 'https://www.abgeordnetenwatch.de/api/v2/politicians/178441',
#   'start_date': None,
#   'constituency_label': '128 - Olpe (Nordrhein-Westfalen 2022 - 2027)'},
#  {'id': 56391,
#   'label': 'Angela Freimuth (Nordrhein-Westfalen 2022 - 2027)',
#   'pol_full_name': 'Angela Freimuth',
#   'pol_url': 'https://www.abgeordnetenwatch.de/api/v2/politicians/130060',
#   'start_date': None,
#   'constituency_label': '123 - Märkischer Kreis III (Nordrhein-Westfalen 2022 - 2027)'},
#  {'id': 56390,
#   'label': 'Gordan Dudas (Nordrhein-Westfalen 2022 - 2027)',
#   'pol_full_name': 'Gordan Dudas',
#   'pol_url': 'https://www.abgeordnetenwatch.de/api/v2/politicians/130254',
#   'start_date': None,
#   'constituency_label': '123 - Märkischer Kreis III (Nordrhein-Westfalen 2022 - 2027)'},
#  {'id': 56389,
#   'label': 'Inge Blask (Nordrhein-Westfalen 2022 - 2027)',
#   'pol_full_name': 'Inge Blask',
#   'pol_url': 'https://www.abgeordnetenwatch.de/api/v2/politicians/130372',
#   'start_date': None,
#   'constituency_label': '122 - Märkischer Kreis II (Nordrhein-Westfalen 2022 - 2027)'},
#  {'id': 56388,
#   'label': 'Dagmar Hanses (Nordrhein-Westfalen 2022 - 2027)',
#   'pol_full_name': 'Dagmar Hanses',
#   'pol_url': 'https://www.abgeordnetenwatch.de/api/v2/politicians/130159',
#   'start_date': None,
#   'constituency_label': '120 - Soest II (Nordrhein-Westfalen 2022 - 2027)'},
#  {'id': 56387,
#   'label': 'Christof Rasche (Nordrhein-Westfalen 2022 - 2027)',
#   'pol_full_name': 'Christof Rasche',
#   'pol_url': 'https://www.abgeordnetenwatch.de/api/v2/politicians/130146',
#   'start_date': None,
#   'constituency_label': '120 - Soest II (Nordrhein-Westfalen 2022 - 2027)'},
#  {'id': 56386,
#   'label': 'Michael Röls (Nordrhein-Westfalen 2022 - 2027)',
#   'pol_full_name': 'Michael Röls',
#   'pol_url': 'https://www.abgeordnetenwatch.de/api/v2/politicians/178516',
#   'start_date': None,
#   'constituency_label': '111 - Dortmund I (Nordrhein-Westfalen 2022 - 2027)'},
#  {'id': 56385,
#   'label': 'Christian Loose (Nordrhein-Westfalen 2022 - 2027)',
#   'pol_full_name': 'Christian Loose',
#   'pol_url': 'https://www.abgeordnetenwatch.de/api/v2/politicians/130032',
#   'start_date': None,
#   'constituency_label': '109 - Bochum III (Nordrhein-Westfalen 2022 - 2027)'},
#  {'id': 56384,
#   'label': 'Verena Schäffer (Nordrhein-Westfalen 2022 - 2027)',
#   'pol_full_name': 'Verena Schäffer',
#   'pol_url': 'https://www.abgeordnetenwatch.de/api/v2/politicians/131071',
#   'start_date': None,
#   'constituency_label': '106 - Ennepe-Ruhr-Kreis II (Nordrhein-Westfalen 2022 - 2027)'},
#  {'id': 56383,
#   'label': 'Marc Lürbke (Nordrhein-Westfalen 2022 - 2027)',
#   'pol_full_name': 'Marc Lürbke',
#   'pol_url': 'https://www.abgeordnetenwatch.de/api/v2/politicians/130508',
#   'start_date': None,
#   'constituency_label': '101 - Paderborn II (Nordrhein-Westfalen 2022 - 2027)'},
#  {'id': 56382,
#   'label': 'Norika Creuzmann (Nordrhein-Westfalen 2022 - 2027)',
#   'pol_full_name': 'Norika Creuzmann',
#   'pol_url': 'https://www.abgeordnetenwatch.de/api/v2/politicians/130591',
#   'start_date': None,
#   'constituency_label': '100 - Paderborn I (Nordrhein-Westfalen 2022 - 2027)'},
#  {'id': 56381,
#   'label': 'Julia Eisentraut (Nordrhein-Westfalen 2022 - 2027)',
#   'pol_full_name': 'Julia Eisentraut',
#   'pol_url': 'https://www.abgeordnetenwatch.de/api/v2/politicians/178505',
#   'start_date': None,
#   'constituency_label': '97 - Lippe I (Nordrhein-Westfalen 2022 - 2027)'},
#  {'id': 56380,
#   'label': 'Ellen Stock (Nordrhein-Westfalen 2022 - 2027)',
#   'pol_full_name': 'Ellen Stock',
#   'pol_url': 'https://www.abgeordnetenwatch.de/api/v2/politicians/130344',
#   'start_date': None,
#   'constituency_label': '97 - Lippe I (Nordrhein-Westfalen 2022 - 2027)'},
#  {'id': 56379,
#   'label': 'Wibke Brems (Nordrhein-Westfalen 2022 - 2027)',
#   'pol_full_name': 'Wibke Brems',
#   'pol_url': 'https://www.abgeordnetenwatch.de/api/v2/politicians/131086',
#   'start_date': None,
#   'constituency_label': '95 - Gütersloh II (Nordrhein-Westfalen 2022 - 2027)'},
#  {'id': 56378,
#   'label': 'Christina Osei (Nordrhein-Westfalen 2022 - 2027)',
#   'pol_full_name': 'Christina Osei',
#   'pol_url': 'https://www.abgeordnetenwatch.de/api/v2/politicians/130125',
#   'start_date': None,
#   'constituency_label': '92 - Bielefeld I (Nordrhein-Westfalen 2022 - 2027)'},
#  {'id': 56377,
#   'label': 'Markus Wagner (Nordrhein-Westfalen 2022 - 2027)',
#   'pol_full_name': 'Markus Wagner',
#   'pol_url': 'https://www.abgeordnetenwatch.de/api/v2/politicians/130546',
#   'start_date': None,
#   'constituency_label': '91 - Herford II - Minden-Lübbecke III (Nordrhein-Westfalen 2022 - 2027)'},
#  {'id': 56376,
#   'label': 'Benjamin Rauer (Nordrhein-Westfalen 2022 - 2027)',
#   'pol_full_name': 'Benjamin Rauer',
#   'pol_url': 'https://www.abgeordnetenwatch.de/api/v2/politicians/130117',
#   'start_date': None,
#   'constituency_label': '88 - Minden-Lübbecke I (Nordrhein-Westfalen 2022 - 2027)'},
#  {'id': 56375,
#   'label': 'Christian Blex (Nordrhein-Westfalen 2022 - 2027)',
#   'pol_full_name': 'Christian Blex',
#   'pol_url': 'https://www.abgeordnetenwatch.de/api/v2/politicians/121096',
#   'start_date': None,
#   'constituency_label': '87 - Warendorf II (Nordrhein-Westfalen 2022 - 2027)'},
#  {'id': 56374,
#   'label': 'Hedwig Tarner (Nordrhein-Westfalen 2022 - 2027)',
#   'pol_full_name': 'Hedwig Tarner',
#   'pol_url': 'https://www.abgeordnetenwatch.de/api/v2/politicians/178499',
#   'start_date': None,
#   'constituency_label': '86 - Warendorf I (Nordrhein-Westfalen 2022 - 2027)'},
#  {'id': 56373,
#   'label': 'Josefine Paul (Nordrhein-Westfalen 2022 - 2027)',
#   'pol_full_name': 'Josefine Paul',
#   'pol_url': 'https://www.abgeordnetenwatch.de/api/v2/politicians/130416',
#   'start_date': None,
#   'constituency_label': '83 - Münster I - Steinfurt IV (Nordrhein-Westfalen 2022 - 2027)'},
#  {'id': 56372,
#   'label': 'Norwich Rüße (Nordrhein-Westfalen 2022 - 2027)',
#   'pol_full_name': 'Norwich Rüße',
#   'pol_url': 'https://www.abgeordnetenwatch.de/api/v2/politicians/130592',
#   'start_date': None,
#   'constituency_label': '80 - Steinfurt I (Nordrhein-Westfalen 2022 - 2027)'},
#  {'id': 56371,
#   'label': 'Dennis Sonne (Nordrhein-Westfalen 2022 - 2027)',
#   'pol_full_name': 'Dennis Sonne',
#   'pol_url': 'https://www.abgeordnetenwatch.de/api/v2/politicians/178494',
#   'start_date': None,
#   'constituency_label': '79 - Coesfeld II (Nordrhein-Westfalen 2022 - 2027)'},
#  {'id': 56370,
#   'label': 'André Stinka (Nordrhein-Westfalen 2022 - 2027)',
#   'pol_full_name': 'André Stinka',
#   'pol_url': 'https://www.abgeordnetenwatch.de/api/v2/politicians/130048',
#   'start_date': None,
#   'constituency_label': '79 - Coesfeld II (Nordrhein-Westfalen 2022 - 2027)'},
#  {'id': 56369,
#   'label': 'Henning Höne (Nordrhein-Westfalen 2022 - 2027)',
#   'pol_full_name': 'Henning Höne',
#   'pol_url': 'https://www.abgeordnetenwatch.de/api/v2/politicians/130299',
#   'start_date': None,
#   'constituency_label': '78 - Coesfeld I - Borken III (Nordrhein-Westfalen 2022 - 2027)'},
#  {'id': 56368,
#   'label': 'Nina Andrieshen (Nordrhein-Westfalen 2022 - 2027)',
#   'pol_full_name': 'Nina Andrieshen',
#   'pol_url': 'https://www.abgeordnetenwatch.de/api/v2/politicians/130583',
#   'start_date': None,
#   'constituency_label': '76 - Borken I (Nordrhein-Westfalen 2022 - 2027)'},
#  {'id': 56367,
#   'label': 'Ilayda Bostancieri (Nordrhein-Westfalen 2022 - 2027)',
#   'pol_full_name': 'Ilayda Bostancieri',
#   'pol_url': 'https://www.abgeordnetenwatch.de/api/v2/politicians/178492',
#   'start_date': None,
#   'constituency_label': '74 - Gelsenkirchen II (Nordrhein-Westfalen 2022 - 2027)'},
#  {'id': 56366,
#   'label': 'Enxhi Seli-Zacharias (Nordrhein-Westfalen 2022 - 2027)',
#   'pol_full_name': 'Enxhi Seli-Zacharias',
#   'pol_url': 'https://www.abgeordnetenwatch.de/api/v2/politicians/178586',
#   'start_date': None,
#   'constituency_label': '74 - Gelsenkirchen II (Nordrhein-Westfalen 2022 - 2027)'},
#  {'id': 56365,
#   'label': 'Daniel Zerbin (Nordrhein-Westfalen 2022 - 2027)',
#   'pol_full_name': 'Daniel Zerbin',
#   'pol_url': 'https://www.abgeordnetenwatch.de/api/v2/politicians/178558',
#   'start_date': None,
#   'constituency_label': '71 - Recklinghausen III (Nordrhein-Westfalen 2022 - 2027)'},
#  {'id': 56364,
#   'label': 'Jan Matzoll (Nordrhein-Westfalen 2022 - 2027)',
#   'pol_full_name': 'Jan Matzoll',
#   'pol_url': 'https://www.abgeordnetenwatch.de/api/v2/politicians/145962',
#   'start_date': None,
#   'constituency_label': '69 - Recklinghausen I (Nordrhein-Westfalen 2022 - 2027)'},
#  {'id': 56363,
#   'label': 'Mehrdad Mostofizadeh (Nordrhein-Westfalen 2022 - 2027)',
#   'pol_full_name': 'Mehrdad Mostofizadeh',
#   'pol_url': 'https://www.abgeordnetenwatch.de/api/v2/politicians/119069',
#   'start_date': None,
#   'constituency_label': '68 - Essen IV (Nordrhein-Westfalen 2022 - 2027)'},
#  {'id': 56362,
#   'label': 'Ralf Witzel (Nordrhein-Westfalen 2022 - 2027)',
#   'pol_full_name': 'Ralf Witzel',
#   'pol_url': 'https://www.abgeordnetenwatch.de/api/v2/politicians/130652',
#   'start_date': None,
#   'constituency_label': '68 - Essen IV (Nordrhein-Westfalen 2022 - 2027)'},
#  {'id': 56361,
#   'label': 'Gönül Eğlence (Nordrhein-Westfalen 2022 - 2027)',
#   'pol_full_name': 'Gönül Eğlence',
#   'pol_url': 'https://www.abgeordnetenwatch.de/api/v2/politicians/85448',
#   'start_date': None,
#   'constituency_label': '66 - Essen II (Nordrhein-Westfalen 2022 - 2027)'},
#  {'id': 56360,
#   'label': 'Jule Wenzel (Nordrhein-Westfalen 2022 - 2027)',
#   'pol_full_name': 'Jule Wenzel',
#   'pol_url': 'https://www.abgeordnetenwatch.de/api/v2/politicians/178483',
#   'start_date': None,
#   'constituency_label': '61 - Duisburg I (Nordrhein-Westfalen 2022 - 2027)'},
#  {'id': 56359,
#   'label': 'Volkhard Wille (Nordrhein-Westfalen 2022 - 2027)',
#   'pol_full_name': 'Volkhard Wille',
#   'pol_url': 'https://www.abgeordnetenwatch.de/api/v2/politicians/178480',
#   'start_date': None,
#   'constituency_label': '55 - Kleve II (Nordrhein-Westfalen 2022 - 2027)'},
#  {'id': 56358,
#   'label': 'Dietmar Brockes (Nordrhein-Westfalen 2022 - 2027)',
#   'pol_full_name': 'Dietmar Brockes',
#   'pol_url': 'https://www.abgeordnetenwatch.de/api/v2/politicians/130182',
#   'start_date': None,
#   'constituency_label': '53 - Viersen II (Nordrhein-Westfalen 2022 - 2027)'},
#  {'id': 56357,
#   'label': 'Lena Zingsheim-Zobel (Nordrhein-Westfalen 2022 - 2027)',
#   'pol_full_name': 'Lena Zingsheim-Zobel',
#   'pol_url': 'https://www.abgeordnetenwatch.de/api/v2/politicians/130471',
#   'start_date': None,
#   'constituency_label': '50 - Mönchengladbach I (Nordrhein-Westfalen 2022 - 2027)'},
#  {'id': 56356,
#   'label': 'Meral Thoms (Nordrhein-Westfalen 2022 - 2027)',
#   'pol_full_name': 'Meral Thoms',
#   'pol_url': 'https://www.abgeordnetenwatch.de/api/v2/politicians/178474',
#   'start_date': None,
#   'constituency_label': '48 - Krefeld I - Viersen III (Nordrhein-Westfalen 2022 - 2027)'},
#  {'id': 56355,
#   'label': 'Martin Vincentz (Nordrhein-Westfalen 2022 - 2027)',
#   'pol_full_name': 'Martin Vincentz',
#   'pol_url': 'https://www.abgeordnetenwatch.de/api/v2/politicians/140820',
#   'start_date': None,
#   'constituency_label': '48 - Krefeld I - Viersen III (Nordrhein-Westfalen 2022 - 2027)'},
#  {'id': 56354,
#   'label': 'Simon Rock (Nordrhein-Westfalen 2022 - 2027)',
#   'pol_full_name': 'Simon Rock',
#   'pol_url': 'https://www.abgeordnetenwatch.de/api/v2/politicians/137649',
#   'start_date': None,
#   'constituency_label': '47 - Rhein-Kreis Neuss III (Nordrhein-Westfalen 2022 - 2027)'},
#  {'id': 56353,
#   'label': 'Zacharias Schalley (Nordrhein-Westfalen 2022 - 2027)',
#   'pol_full_name': 'Zacharias Schalley',
#   'pol_url': 'https://www.abgeordnetenwatch.de/api/v2/politicians/178570',
#   'start_date': None,
#   'constituency_label': '47 - Rhein-Kreis Neuss III (Nordrhein-Westfalen 2022 - 2027)'},
#  {'id': 56352,
#   'label': 'Stefan Engstfeld (Nordrhein-Westfalen 2022 - 2027)',
#   'pol_full_name': 'Stefan Engstfeld',
#   'pol_url': 'https://www.abgeordnetenwatch.de/api/v2/politicians/130705',
#   'start_date': None,
#   'constituency_label': '43 - Düsseldorf III (Nordrhein-Westfalen 2022 - 2027)'},
#  {'id': 56351,
#   'label': 'Mona Neubaur (Nordrhein-Westfalen 2022 - 2027)',
#   'pol_full_name': 'Mona Neubaur',
#   'pol_url': 'https://www.abgeordnetenwatch.de/api/v2/politicians/120397',
#   'start_date': None,
#   'constituency_label': '41 - Düsseldorf I (Nordrhein-Westfalen 2022 - 2027)'},
#  {'id': 56350,
#   'label': 'Elisabeth Müller-Witt (Nordrhein-Westfalen 2022 - 2027)',
#   'pol_full_name': 'Elisabeth Müller-Witt',
#   'pol_url': 'https://www.abgeordnetenwatch.de/api/v2/politicians/130197',
#   'start_date': None,
#   'constituency_label': '39 - Mettmann III - Mülheim II (Nordrhein-Westfalen 2022 - 2027)'},
#  {'id': 56349,
#   'label': 'Ina Besche-Krastl (Nordrhein-Westfalen 2022 - 2027)',
#   'pol_full_name': 'Ina Besche-Krastl',
#   'pol_url': 'https://www.abgeordnetenwatch.de/api/v2/politicians/130327',
#   'start_date': None,
#   'constituency_label': '38 - Mettmann II (Nordrhein-Westfalen 2022 - 2027)'},
#  {'id': 56348,
#   'label': 'Dirk Wedel (Nordrhein-Westfalen 2022 - 2027)',
#   'pol_full_name': 'Dirk Wedel',
#   'pol_url': 'https://www.abgeordnetenwatch.de/api/v2/politicians/118319',
#   'start_date': None,
#   'constituency_label': '38 - Mettmann II (Nordrhein-Westfalen 2022 - 2027)'},
#  {'id': 56347,
#   'label': 'Sven Wolf (Nordrhein-Westfalen 2022 - 2027)',
#   'pol_full_name': 'Sven Wolf',
#   'pol_url': 'https://www.abgeordnetenwatch.de/api/v2/politicians/130174',
#   'start_date': None,
#   'constituency_label': '36 - Remscheid I - Oberbergischer Kreis III (Nordrhein-Westfalen 2022 - 2027)'},
#  {'id': 56346,
#   'label': 'Hartmut Beucker (Nordrhein-Westfalen 2022 - 2027)',
#   'pol_full_name': 'Hartmut Beucker',
#   'pol_url': 'https://www.abgeordnetenwatch.de/api/v2/politicians/130107',
#   'start_date': None,
#   'constituency_label': '32 - Wuppertal I (Nordrhein-Westfalen 2022 - 2027)'},
#  {'id': 56345,
#   'label': 'Marcel Hafke (Nordrhein-Westfalen 2022 - 2027)',
#   'pol_full_name': 'Marcel Hafke',
#   'pol_url': 'https://www.abgeordnetenwatch.de/api/v2/politicians/130511',
#   'start_date': None,
#   'constituency_label': '32 - Wuppertal I (Nordrhein-Westfalen 2022 - 2027)'},
#  {'id': 56344,
#   'label': 'Julia Höller (Nordrhein-Westfalen 2022 - 2027)',
#   'pol_full_name': 'Julia Höller',
#   'pol_url': 'https://www.abgeordnetenwatch.de/api/v2/politicians/178463',
#   'start_date': None,
#   'constituency_label': '31 - Bonn II (Nordrhein-Westfalen 2022 - 2027)'},
#  {'id': 56342,
#   'label': 'Tim Achtermeyer (Nordrhein-Westfalen 2022 - 2027)',
#   'pol_full_name': 'Tim Achtermeyer',
#   'pol_url': 'https://www.abgeordnetenwatch.de/api/v2/politicians/178462',
#   'start_date': None,
#   'constituency_label': '30 - Bonn I (Nordrhein-Westfalen 2022 - 2027)'},
#  {'id': 56341,
#   'label': 'Martin Metz (Nordrhein-Westfalen 2022 - 2027)',
#   'pol_full_name': 'Martin Metz',
#   'pol_url': 'https://www.abgeordnetenwatch.de/api/v2/politicians/145950',
#   'start_date': None,
#   'constituency_label': '29 - Rhein-Sieg-Kreis V (Nordrhein-Westfalen 2022 - 2027)'},
#  {'id': 56339,
#   'label': 'Marc Zimmermann (Nordrhein-Westfalen 2022 - 2027)',
#   'pol_full_name': 'Marc Zimmermann',
#   'pol_url': 'https://www.abgeordnetenwatch.de/api/v2/politicians/178458',
#   'start_date': None,
#   'constituency_label': '24 - Oberbergischer Kreis II (Nordrhein-Westfalen 2022 - 2027)'},
#  {'id': 56338,
#   'label': 'Carlo Clemens (Nordrhein-Westfalen 2022 - 2027)',
#   'pol_full_name': 'Carlo Clemens',
#   'pol_url': 'https://www.abgeordnetenwatch.de/api/v2/politicians/178540',
#   'start_date': None,
#   'constituency_label': '22 - Rheinisch-Bergischer Kreis II (Nordrhein-Westfalen 2022 - 2027)'},
#  {'id': 56337,
#   'label': 'Tülay Durdu (Nordrhein-Westfalen 2022 - 2027)',
#   'pol_full_name': 'Tülay Durdu',
#   'pol_url': 'https://www.abgeordnetenwatch.de/api/v2/politicians/178377',
#   'start_date': None,
#   'constituency_label': '21 - Rheinisch-Bergischer Kreis I (Nordrhein-Westfalen 2022 - 2027)'},
#  {'id': 56336,
#   'label': 'Sven Tritschler (Nordrhein-Westfalen 2022 - 2027)',
#   'pol_full_name': 'Sven Tritschler',
#   'pol_url': 'https://www.abgeordnetenwatch.de/api/v2/politicians/131046',
#   'start_date': None,
#   'constituency_label': '16 - Köln IV (Nordrhein-Westfalen 2022 - 2027)'},
#  {'id': 56335,
#   'label': 'Yvonne Gebauer (Nordrhein-Westfalen 2022 - 2027)',
#   'pol_full_name': 'Yvonne Gebauer',
#   'pol_url': 'https://www.abgeordnetenwatch.de/api/v2/politicians/131103',
#   'start_date': None,
#   'constituency_label': '16 - Köln IV (Nordrhein-Westfalen 2022 - 2027)'},
#  {'id': 56334,
#   'label': 'Jochen Ott (Nordrhein-Westfalen 2022 - 2027)',
#   'pol_full_name': 'Jochen Ott',
#   'pol_url': 'https://www.abgeordnetenwatch.de/api/v2/politicians/85457',
#   'start_date': None,
#   'constituency_label': '15 - Köln III (Nordrhein-Westfalen 2022 - 2027)'},
#  {'id': 56333,
#   'label': 'Klaus Esser (Nordrhein-Westfalen 2022 - 2027)',
#   'pol_full_name': 'Klaus Esser',
#   'pol_url': 'https://www.abgeordnetenwatch.de/api/v2/politicians/178536',
#   'start_date': None,
#   'constituency_label': '12 - Düren II - Euskirchen II (Nordrhein-Westfalen 2022 - 2027)'},
#  {'id': 56332,
#   'label': 'Antje Grothus (Nordrhein-Westfalen 2022 - 2027)',
#   'pol_full_name': 'Antje Grothus',
#   'pol_url': 'https://www.abgeordnetenwatch.de/api/v2/politicians/178447',
#   'start_date': None,
#   'constituency_label': '6 - Rhein-Erft-Kreis II (Nordrhein-Westfalen 2022 - 2027)'},
#  {'id': 56331,
#   'label': 'Anja von Marenholtz-Diemer (Nordrhein-Westfalen 2022 - 2027)',
#   'pol_full_name': 'Anja von Marenholtz-Diemer',
#   'pol_url': 'https://www.abgeordnetenwatch.de/api/v2/politicians/130331',
#   'start_date': None,
#   'constituency_label': '5 - Rhein-Erft-Kreis I (Nordrhein-Westfalen 2022 - 2027)'},
#  {'id': 56330,
#   'label': 'Laura Postma (Nordrhein-Westfalen 2022 - 2027)',
#   'pol_full_name': 'Laura Postma',
#   'pol_url': 'https://www.abgeordnetenwatch.de/api/v2/politicians/178444',
#   'start_date': None,
#   'constituency_label': '3 - Aachen III (Nordrhein-Westfalen 2022 - 2027)'},
#  {'id': 56329,
#   'label': 'Werner Pfeil (Nordrhein-Westfalen 2022 - 2027)',
#   'pol_full_name': 'Werner Pfeil',
#   'pol_url': 'https://www.abgeordnetenwatch.de/api/v2/politicians/130454',
#   'start_date': None,
#   'constituency_label': '3 - Aachen III (Nordrhein-Westfalen 2022 - 2027)'},
#  {'id': 56328,
#   'label': 'Lisa-Kristin Kapteinat (Nordrhein-Westfalen 2022 - 2027)',
#   'pol_full_name': 'Lisa-Kristin Kapteinat',
#   'pol_url': 'https://www.abgeordnetenwatch.de/api/v2/politicians/130428',
#   'start_date': None,
#   'constituency_label': '72 - Recklinghausen IV (Nordrhein-Westfalen 2022 - 2027)'},
#  {'id': 56327,
#   'label': 'Anna Teresa Kavena (Nordrhein-Westfalen 2022 - 2027)',
#   'pol_full_name': 'Anna Teresa Kavena',
#   'pol_url': 'https://www.abgeordnetenwatch.de/api/v2/politicians/178406',
#   'start_date': None,
#   'constituency_label': '69 - Recklinghausen I (Nordrhein-Westfalen 2022 - 2027)'},
#  {'id': 56326,
#   'label': 'Oliver Krauß (Nordrhein-Westfalen 2022 - 2027)',
#   'pol_full_name': 'Oliver Krauß',
#   'pol_url': 'https://www.abgeordnetenwatch.de/api/v2/politicians/130599',
#   'start_date': None,
#   'constituency_label': '27 - Rhein-Sieg-Kreis III - Euskirchen III (Nordrhein-Westfalen 2022 - 2027)'},
#  {'id': 56325,
#   'label': 'Jochen Ritter (Nordrhein-Westfalen 2022 - 2027)',
#   'pol_full_name': 'Jochen Ritter',
#   'pol_url': 'https://www.abgeordnetenwatch.de/api/v2/politicians/130404',
#   'start_date': None,
#   'constituency_label': '128 - Olpe (Nordrhein-Westfalen 2022 - 2027)'},
#  {'id': 56324,
#   'label': 'Anke Fuchs-Dreisbach (Nordrhein-Westfalen 2022 - 2027)',
#   'pol_full_name': 'Anke Fuchs-Dreisbach',
#   'pol_url': 'https://www.abgeordnetenwatch.de/api/v2/politicians/130065',
#   'start_date': None,
#   'constituency_label': '127 - Siegen-Wittgenstein II (Nordrhein-Westfalen 2022 - 2027)'},
#  {'id': 56323,
#   'label': 'Jens Kamieth (Nordrhein-Westfalen 2022 - 2027)',
#   'pol_full_name': 'Jens Kamieth',
#   'pol_url': 'https://www.abgeordnetenwatch.de/api/v2/politicians/130394',
#   'start_date': None,
#   'constituency_label': '126 - Siegen-Wittgenstein I (Nordrhein-Westfalen 2022 - 2027)'},
#  {'id': 56322,
#   'label': 'Matthias Kerkhoff (Nordrhein-Westfalen 2022 - 2027)',
#   'pol_full_name': 'Matthias Kerkhoff',
#   'pol_url': 'https://www.abgeordnetenwatch.de/api/v2/politicians/130544',
#   'start_date': None,
#   'constituency_label': '125 - Hochsauerlandkreis II (Nordrhein-Westfalen 2022 - 2027)'},
#  {'id': 56321,
#   'label': 'Klaus Kaiser (Nordrhein-Westfalen 2022 - 2027)',
#   'pol_full_name': 'Klaus Kaiser',
#   'pol_url': 'https://www.abgeordnetenwatch.de/api/v2/politicians/130441',
#   'start_date': None,
#   'constituency_label': '124 - Hochsauerlandkreis I (Nordrhein-Westfalen 2022 - 2027)'},
#  {'id': 56320,
#   'label': 'Ralf Schwarzkopf (Nordrhein-Westfalen 2022 - 2027)',
#   'pol_full_name': 'Ralf Schwarzkopf',
#   'pol_url': 'https://www.abgeordnetenwatch.de/api/v2/politicians/130359',
#   'start_date': None,
#   'constituency_label': '123 - Märkischer Kreis III (Nordrhein-Westfalen 2022 - 2027)'},
#  {'id': 56319,
#   'label': 'Matthias Eggers (Nordrhein-Westfalen 2022 - 2027)',
#   'pol_full_name': 'Matthias Eggers',
#   'pol_url': 'https://www.abgeordnetenwatch.de/api/v2/politicians/178640',
#   'start_date': None,
#   'constituency_label': '122 - Märkischer Kreis II (Nordrhein-Westfalen 2022 - 2027)'},
#  {'id': 56318,
#   'label': 'Thorsten Schick (Nordrhein-Westfalen 2022 - 2027)',
#   'pol_full_name': 'Thorsten Schick',
#   'pol_url': 'https://www.abgeordnetenwatch.de/api/v2/politicians/131041',
#   'start_date': None,
#   'constituency_label': '121 - Märkischer Kreis I (Nordrhein-Westfalen 2022 - 2027)'},
#  {'id': 56317,
#   'label': 'Jörg Blöming (Nordrhein-Westfalen 2022 - 2027)',
#   'pol_full_name': 'Jörg Blöming',
#   'pol_url': 'https://www.abgeordnetenwatch.de/api/v2/politicians/130409',
#   'start_date': None,
#   'constituency_label': '120 - Soest II (Nordrhein-Westfalen 2022 - 2027)'},
#  {'id': 56316,
#   'label': 'Heinrich Frieling (Nordrhein-Westfalen 2022 - 2027)',
#   'pol_full_name': 'Heinrich Frieling',
#   'pol_url': 'https://www.abgeordnetenwatch.de/api/v2/politicians/130292',
#   'start_date': None,
#   'constituency_label': '119 - Soest I (Nordrhein-Westfalen 2022 - 2027)'},
#  {'id': 56315,
#   'label': 'Justus Moor (Nordrhein-Westfalen 2022 - 2027)',
#   'pol_full_name': 'Justus Moor',
#   'pol_url': 'https://www.abgeordnetenwatch.de/api/v2/politicians/178433',
#   'start_date': None,
#   'constituency_label': '118 - Hamm I (Nordrhein-Westfalen 2022 - 2027)'},
#  {'id': 56314,
#   'label': 'Silvia Gosewinkel (Nordrhein-Westfalen 2022 - 2027)',
#   'pol_full_name': 'Silvia Gosewinkel',
#   'pol_url': 'https://www.abgeordnetenwatch.de/api/v2/politicians/178432',
#   'start_date': None,
#   'constituency_label': '117 - Unna III - Hamm II (Nordrhein-Westfalen 2022 - 2027)'},
#  {'id': 56313,
#   'label': 'Rainer Schmeltzer (Nordrhein-Westfalen 2022 - 2027)',
#   'pol_full_name': 'Rainer Schmeltzer',
#   'pol_url': 'https://www.abgeordnetenwatch.de/api/v2/politicians/130642',
#   'start_date': None,
#   'constituency_label': '116 - Unna II (Nordrhein-Westfalen 2022 - 2027)'},
#  {'id': 56312,
#   'label': 'Hartmut Ganzke (Nordrhein-Westfalen 2022 - 2027)',
#   'pol_full_name': 'Hartmut Ganzke',
#   'pol_url': 'https://www.abgeordnetenwatch.de/api/v2/politicians/130281',
#   'start_date': None,
#   'constituency_label': '115 - Unna I (Nordrhein-Westfalen 2022 - 2027)'},
#  {'id': 56311,
#   'label': 'Anja Butschkau (Nordrhein-Westfalen 2022 - 2027)',
#   'pol_full_name': 'Anja Butschkau',
#   'pol_url': 'https://www.abgeordnetenwatch.de/api/v2/politicians/131028',
#   'start_date': None,
#   'constituency_label': '114 - Dortmund IV (Nordrhein-Westfalen 2022 - 2027)'},
#  {'id': 56310,
#   'label': 'Nadja Lüders (Nordrhein-Westfalen 2022 - 2027)',
#   'pol_full_name': 'Nadja Lüders',
#   'pol_url': 'https://www.abgeordnetenwatch.de/api/v2/politicians/130576',
#   'start_date': None,
#   'constituency_label': '113 - Dortmund III (Nordrhein-Westfalen 2022 - 2027)'},
#  {'id': 56309,
#   'label': 'Volkan Baran (Nordrhein-Westfalen 2022 - 2027)',
#   'pol_full_name': 'Volkan Baran',
#   'pol_url': 'https://www.abgeordnetenwatch.de/api/v2/politicians/131068',
#   'start_date': None,
#   'constituency_label': '112 - Dortmund II (Nordrhein-Westfalen 2022 - 2027)'},
#  {'id': 56308,
#   'label': 'Ralf Stoltze (Nordrhein-Westfalen 2022 - 2027)',
#   'pol_full_name': 'Ralf Stoltze',
#   'pol_url': 'https://www.abgeordnetenwatch.de/api/v2/politicians/178431',
#   'start_date': None,
#   'constituency_label': '111 - Dortmund I (Nordrhein-Westfalen 2022 - 2027)'},
#  {'id': 56307,
#   'label': 'Alexander Vogt (Nordrhein-Westfalen 2022 - 2027)',
#   'pol_full_name': 'Alexander Vogt',
#   'pol_url': 'https://www.abgeordnetenwatch.de/api/v2/politicians/130040',
#   'start_date': None,
#   'constituency_label': '110 - Herne I (Nordrhein-Westfalen 2022 - 2027)'},
#  {'id': 56306,
#   'label': 'Serdar Yüksel (Nordrhein-Westfalen 2022 - 2027)',
#   'pol_full_name': 'Serdar Yüksel',
#   'pol_url': 'https://www.abgeordnetenwatch.de/api/v2/politicians/130692',
#   'start_date': None,
#   'constituency_label': '109 - Bochum III (Nordrhein-Westfalen 2022 - 2027)'},
#  {'id': 56305,
#   'label': 'Bastian Hartmann (Nordrhein-Westfalen 2022 - 2027)',
#   'pol_full_name': 'Bastian Hartmann',
#   'pol_url': 'https://www.abgeordnetenwatch.de/api/v2/politicians/178430',
#   'start_date': None,
#   'constituency_label': '108 - Bochum II (Nordrhein-Westfalen 2022 - 2027)'},
#  {'id': 56304,
#   'label': 'Andrea Busche (Nordrhein-Westfalen 2022 - 2027)',
#   'pol_full_name': 'Andrea Busche',
#   'pol_url': 'https://www.abgeordnetenwatch.de/api/v2/politicians/178429',
#   'start_date': None,
#   'constituency_label': '107 - Bochum I (Nordrhein-Westfalen 2022 - 2027)'},
#  {'id': 56303,
#   'label': 'Nadja Büteführ (Nordrhein-Westfalen 2022 - 2027)',
#   'pol_full_name': 'Nadja Büteführ',
#   'pol_url': 'https://www.abgeordnetenwatch.de/api/v2/politicians/130355',
#   'start_date': None,
#   'constituency_label': '106 - Ennepe-Ruhr-Kreis II (Nordrhein-Westfalen 2022 - 2027)'},
#  {'id': 56302,
#   'label': 'Kirsten Stich (Nordrhein-Westfalen 2022 - 2027)',
#   'pol_full_name': 'Kirsten Stich',
#   'pol_url': 'https://www.abgeordnetenwatch.de/api/v2/politicians/178428',
#   'start_date': None,
#   'constituency_label': '105 - Ennepe-Ruhr-Kreis I (Nordrhein-Westfalen 2022 - 2027)'},
#  {'id': 56301,
#   'label': 'Ina Blumenthal (Nordrhein-Westfalen 2022 - 2027)',
#   'pol_full_name': 'Ina Blumenthal',
#   'pol_url': 'https://www.abgeordnetenwatch.de/api/v2/politicians/178427',
#   'start_date': None,
#   'constituency_label': '104 - Hagen II - Ennepe-Ruhr-Kreis III (Nordrhein-Westfalen 2022 - 2027)'},
#  {'id': 56300,
#   'label': 'Wolfgang Jörg (Nordrhein-Westfalen 2022 - 2027)',
#   'pol_full_name': 'Wolfgang Jörg',
#   'pol_url': 'https://www.abgeordnetenwatch.de/api/v2/politicians/131097',
#   'start_date': None,
#   'constituency_label': '103 - Hagen I (Nordrhein-Westfalen 2022 - 2027)'},
#  {'id': 56299,
#   'label': 'Matthias Goeken (Nordrhein-Westfalen 2022 - 2027)',
#   'pol_full_name': 'Matthias Goeken',
#   'pol_url': 'https://www.abgeordnetenwatch.de/api/v2/politicians/130251',
#   'start_date': None,
#   'constituency_label': '102 - Höxter (Nordrhein-Westfalen 2022 - 2027)'},
#  {'id': 56297,
#   'label': 'Bernhard Hoppe-Biermeyer (Nordrhein-Westfalen 2022 - 2027)',
#   'pol_full_name': 'Bernhard Hoppe-Biermeyer',
#   'pol_url': 'https://www.abgeordnetenwatch.de/api/v2/politicians/130348',
#   'start_date': None,
#   'constituency_label': '100 - Paderborn I (Nordrhein-Westfalen 2022 - 2027)'},
#  {'id': 56296,
#   'label': 'Dennis Maelzer (Nordrhein-Westfalen 2022 - 2027)',
#   'pol_full_name': 'Dennis Maelzer',
#   'pol_url': 'https://www.abgeordnetenwatch.de/api/v2/politicians/130170',
#   'start_date': None,
#   'constituency_label': '99 - Lippe III (Nordrhein-Westfalen 2022 - 2027)'},
#  {'id': 56295,
#   'label': 'Alexander Baer (Nordrhein-Westfalen 2022 - 2027)',
#   'pol_full_name': 'Alexander Baer',
#   'pol_url': 'https://www.abgeordnetenwatch.de/api/v2/politicians/178423',
#   'start_date': None,
#   'constituency_label': '98 - Lippe II - Herford III (Nordrhein-Westfalen 2022 - 2027)'},
#  {'id': 56294,
#   'label': 'Klaus Hansen (Nordrhein-Westfalen 2022 - 2027)',
#   'pol_full_name': 'Klaus Hansen',
#   'pol_url': 'https://www.abgeordnetenwatch.de/api/v2/politicians/178626',
#   'start_date': None,
#   'constituency_label': '97 - Lippe I (Nordrhein-Westfalen 2022 - 2027)'},
#  {'id': 56293,
#   'label': 'André Kuper (Nordrhein-Westfalen 2022 - 2027)',
#   'pol_full_name': 'André Kuper',
#   'pol_url': 'https://www.abgeordnetenwatch.de/api/v2/politicians/130047',
#   'start_date': None,
#   'constituency_label': '96 - Gütersloh III (Nordrhein-Westfalen 2022 - 2027)'},
#  {'id': 56292,
#   'label': 'Raphael Tigges (Nordrhein-Westfalen 2022 - 2027)',
#   'pol_full_name': 'Raphael Tigges',
#   'pol_url': 'https://www.abgeordnetenwatch.de/api/v2/politicians/130361',
#   'start_date': None,
#   'constituency_label': '95 - Gütersloh II (Nordrhein-Westfalen 2022 - 2027)'},
#  {'id': 56291,
#   'label': 'Thorsten Klute (Nordrhein-Westfalen 2022 - 2027)',
#   'pol_full_name': 'Thorsten Klute',
#   'pol_url': 'https://www.abgeordnetenwatch.de/api/v2/politicians/122046',
#   'start_date': None,
#   'constituency_label': '94 - Gütersloh I - Bielefeld III (Nordrhein-Westfalen 2022 - 2027)'},
#  {'id': 56290,
#   'label': 'Tom Brüntrup (Nordrhein-Westfalen 2022 - 2027)',
#   'pol_full_name': 'Tom Brüntrup',
#   'pol_url': 'https://www.abgeordnetenwatch.de/api/v2/politicians/178624',
#   'start_date': None,
#   'constituency_label': '93 - Bielefeld II (Nordrhein-Westfalen 2022 - 2027)'},
#  {'id': 56289,
#   'label': 'Christina Kampmann (Nordrhein-Westfalen 2022 - 2027)',
#   'pol_full_name': 'Christina Kampmann',
#   'pol_url': 'https://www.abgeordnetenwatch.de/api/v2/politicians/79261',
#   'start_date': None,
#   'constituency_label': '92 - Bielefeld I (Nordrhein-Westfalen 2022 - 2027)'},
#  {'id': 56288,
#   'label': 'Christian Obrok (Nordrhein-Westfalen 2022 - 2027)',
#   'pol_full_name': 'Christian Obrok',
#   'pol_url': 'https://www.abgeordnetenwatch.de/api/v2/politicians/178419',
#   'start_date': None,
#   'constituency_label': '91 - Herford II - Minden-Lübbecke III (Nordrhein-Westfalen 2022 - 2027)'},
#  {'id': 56287,
#   'label': 'Christian Dahm (Nordrhein-Westfalen 2022 - 2027)',
#   'pol_full_name': 'Christian Dahm',
#   'pol_url': 'https://www.abgeordnetenwatch.de/api/v2/politicians/130137',
#   'start_date': None,
#   'constituency_label': '90 - Herford I (Nordrhein-Westfalen 2022 - 2027)'},
#  {'id': 56286,
#   'label': 'Christina Weng (Nordrhein-Westfalen 2022 - 2027)',
#   'pol_full_name': 'Christina Weng',
#   'pol_url': 'https://www.abgeordnetenwatch.de/api/v2/politicians/130144',
#   'start_date': None,
#   'constituency_label': '89 - Minden-Lübbecke II (Nordrhein-Westfalen 2022 - 2027)'},
#  {'id': 56285,
#   'label': 'Bianca Winkelmann (Nordrhein-Westfalen 2022 - 2027)',
#   'pol_full_name': 'Bianca Winkelmann',
#   'pol_url': 'https://www.abgeordnetenwatch.de/api/v2/politicians/130370',
#   'start_date': None,
#   'constituency_label': '88 - Minden-Lübbecke I (Nordrhein-Westfalen 2022 - 2027)'},
#  {'id': 56284,
#   'label': 'Markus Höner (Nordrhein-Westfalen 2022 - 2027)',
#   'pol_full_name': 'Markus Höner',
#   'pol_url': 'https://www.abgeordnetenwatch.de/api/v2/politicians/178621',
#   'start_date': None,
#   'constituency_label': '87 - Warendorf II (Nordrhein-Westfalen 2022 - 2027)'},
#  {'id': 56283,
#   'label': 'Daniel Hagemeier (Nordrhein-Westfalen 2022 - 2027)',
#   'pol_full_name': 'Daniel Hagemeier',
#   'pol_url': 'https://www.abgeordnetenwatch.de/api/v2/politicians/131092',
#   'start_date': None,
#   'constituency_label': '86 - Warendorf I (Nordrhein-Westfalen 2022 - 2027)'},
#  {'id': 56282,
#   'label': 'Dorothea Deppermann (Nordrhein-Westfalen 2022 - 2027)',
#   'pol_full_name': 'Dorothea Deppermann',
#   'pol_url': 'https://www.abgeordnetenwatch.de/api/v2/politicians/178498',
#   'start_date': None,
#   'constituency_label': '85 - Münster III - Coesfeld III (Nordrhein-Westfalen 2022 - 2027)'},
#  {'id': 56281,
#   'label': 'Robin Korte (Nordrhein-Westfalen 2022 - 2027)',
#   'pol_full_name': 'Robin Korte',
#   'pol_url': 'https://www.abgeordnetenwatch.de/api/v2/politicians/178497',
#   'start_date': None,
#   'constituency_label': '84 - Münster II (Nordrhein-Westfalen 2022 - 2027)'},
#  {'id': 56280,
#   'label': 'Simone Wendland (Nordrhein-Westfalen 2022 - 2027)',
#   'pol_full_name': 'Simone Wendland',
#   'pol_url': 'https://www.abgeordnetenwatch.de/api/v2/politicians/131084',
#   'start_date': None,
#   'constituency_label': '83 - Münster I - Steinfurt IV (Nordrhein-Westfalen 2022 - 2027)'},
#  {'id': 56279,
#   'label': 'Karl-Josef Laumann (Nordrhein-Westfalen 2022 - 2027)',
#   'pol_full_name': 'Karl-Josef Laumann',
#   'pol_url': 'https://www.abgeordnetenwatch.de/api/v2/politicians/136809',
#   'start_date': None,
#   'constituency_label': '82 - Steinfurt III (Nordrhein-Westfalen 2022 - 2027)'},
#  {'id': 56278,
#   'label': 'Andrea Stullich (Nordrhein-Westfalen 2022 - 2027)',
#   'pol_full_name': 'Andrea Stullich',
#   'pol_url': 'https://www.abgeordnetenwatch.de/api/v2/politicians/130030',
#   'start_date': None,
#   'constituency_label': '81 - Steinfurt II (Nordrhein-Westfalen 2022 - 2027)'},
#  {'id': 56277,
#   'label': 'Christina Schulze Föcking (Nordrhein-Westfalen 2022 - 2027)',
#   'pol_full_name': 'Christina Schulze Föcking',
#   'pol_url': 'https://www.abgeordnetenwatch.de/api/v2/politicians/130142',
#   'start_date': None,
#   'constituency_label': '80 - Steinfurt I (Nordrhein-Westfalen 2022 - 2027)'},
#  {'id': 56276,
#   'label': 'Dietmar Panske (Nordrhein-Westfalen 2022 - 2027)',
#   'pol_full_name': 'Dietmar Panske',
#   'pol_url': 'https://www.abgeordnetenwatch.de/api/v2/politicians/130342',
#   'start_date': None,
#   'constituency_label': '79 - Coesfeld II (Nordrhein-Westfalen 2022 - 2027)'},
#  {'id': 56275,
#   'label': 'Wilhelm Korth (Nordrhein-Westfalen 2022 - 2027)',
#   'pol_full_name': 'Wilhelm Korth',
#   'pol_url': 'https://www.abgeordnetenwatch.de/api/v2/politicians/131090',
#   'start_date': None,
#   'constituency_label': '78 - Coesfeld I - Borken III (Nordrhein-Westfalen 2022 - 2027)'},
#  {'id': 56274,
#   'label': 'Heike Wermer (Nordrhein-Westfalen 2022 - 2027)',
#   'pol_full_name': 'Heike Wermer',
#   'pol_url': 'https://www.abgeordnetenwatch.de/api/v2/politicians/130287',
#   'start_date': None,
#   'constituency_label': '77 - Borken II (Nordrhein-Westfalen 2022 - 2027)'},
#  {'id': 56273,
#   'label': 'Hendrik Wüst (Nordrhein-Westfalen 2022 - 2027)',
#   'pol_full_name': 'Hendrik Wüst',
#   'pol_url': 'https://www.abgeordnetenwatch.de/api/v2/politicians/130298',
#   'start_date': None,
#   'constituency_label': '76 - Borken I (Nordrhein-Westfalen 2022 - 2027)'},
#  {'id': 56272,
#   'label': 'Thomas Göddertz (Nordrhein-Westfalen 2022 - 2027)',
#   'pol_full_name': 'Thomas Göddertz',
#   'pol_url': 'https://www.abgeordnetenwatch.de/api/v2/politicians/125450',
#   'start_date': None,
#   'constituency_label': '75 - Bottrop - Recklinghausen VI (Nordrhein-Westfalen 2022 - 2027)'},
#  {'id': 56271,
#   'label': 'Sebastian Watermeier (Nordrhein-Westfalen 2022 - 2027)',
#   'pol_full_name': 'Sebastian Watermeier',
#   'pol_url': 'https://www.abgeordnetenwatch.de/api/v2/politicians/130689',
#   'start_date': None,
#   'constituency_label': '74 - Gelsenkirchen II (Nordrhein-Westfalen 2022 - 2027)'},
#  {'id': 56270,
#   'label': 'Christin Siebel (Nordrhein-Westfalen 2022 - 2027)',
#   'pol_full_name': 'Christin Siebel',
#   'pol_url': 'https://www.abgeordnetenwatch.de/api/v2/politicians/178408',
#   'start_date': None,
#   'constituency_label': '73 - Gelsenkirchen I - Recklinghausen V (Nordrhein-Westfalen 2022 - 2027)'},
#  {'id': 56269,
#   'label': 'Josef Hovenjürgen (Nordrhein-Westfalen 2022 - 2027)',
#   'pol_full_name': 'Josef Hovenjürgen',
#   'pol_url': 'https://www.abgeordnetenwatch.de/api/v2/politicians/130455',
#   'start_date': None,
#   'constituency_label': '71 - Recklinghausen III (Nordrhein-Westfalen 2022 - 2027)'},
#  {'id': 56268,
#   'label': 'Carsten Löcker (Nordrhein-Westfalen 2022 - 2027)',
#   'pol_full_name': 'Carsten Löcker',
#   'pol_url': 'https://www.abgeordnetenwatch.de/api/v2/politicians/130133',
#   'start_date': None,
#   'constituency_label': '70 - Recklinghausen II (Nordrhein-Westfalen 2022 - 2027)'},
#  {'id': 56267,
#   'label': 'Fabian Schrumpf (Nordrhein-Westfalen 2022 - 2027)',
#   'pol_full_name': 'Fabian Schrumpf',
#   'pol_url': 'https://www.abgeordnetenwatch.de/api/v2/politicians/130687',
#   'start_date': None,
#   'constituency_label': '68 - Essen IV (Nordrhein-Westfalen 2022 - 2027)'},
#  {'id': 56266,
#   'label': 'Julia Kahle-Hausmann (Nordrhein-Westfalen 2022 - 2027)',
#   'pol_full_name': 'Julia Kahle-Hausmann',
#   'pol_url': 'https://www.abgeordnetenwatch.de/api/v2/politicians/178404',
#   'start_date': None,
#   'constituency_label': '67 - Essen III (Nordrhein-Westfalen 2022 - 2027)'},
#  {'id': 56265,
#   'label': 'Frank Müller (Nordrhein-Westfalen 2022 - 2027)',
#   'pol_full_name': 'Frank Müller',
#   'pol_url': 'https://www.abgeordnetenwatch.de/api/v2/politicians/130225',
#   'start_date': None,
#   'constituency_label': '66 - Essen II (Nordrhein-Westfalen 2022 - 2027)'},
#  {'id': 56264,
#   'label': 'Thomas Kutschaty (Nordrhein-Westfalen 2022 - 2027)',
#   'pol_full_name': 'Thomas Kutschaty',
#   'pol_url': 'https://www.abgeordnetenwatch.de/api/v2/politicians/131033',
#   'start_date': None,
#   'constituency_label': '65 - Essen I (Nordrhein-Westfalen 2022 - 2027)'},
#  {'id': 56263,
#   'label': 'Rodion Bakum (Nordrhein-Westfalen 2022 - 2027)',
#   'pol_full_name': 'Rodion Bakum',
#   'pol_url': 'https://www.abgeordnetenwatch.de/api/v2/politicians/178403',
#   'start_date': None,
#   'constituency_label': '64 - Mülheim I (Nordrhein-Westfalen 2022 - 2027)'},
#  {'id': 56262,
#   'label': 'Frank Börner (Nordrhein-Westfalen 2022 - 2027)',
#   'pol_full_name': 'Frank Börner',
#   'pol_url': 'https://www.abgeordnetenwatch.de/api/v2/politicians/130229',
#   'start_date': None,
#   'constituency_label': '63 - Duisburg III (Nordrhein-Westfalen 2022 - 2027)'},
#  {'id': 56261,
#   'label': 'Benedikt Falszewski (Nordrhein-Westfalen 2022 - 2027)',
#   'pol_full_name': 'Benedikt Falszewski',
#   'pol_url': 'https://www.abgeordnetenwatch.de/api/v2/politicians/178402',
#   'start_date': None,
#   'constituency_label': '62 - Duisburg II (Nordrhein-Westfalen 2022 - 2027)'},
#  {'id': 56260,
#   'label': 'Sarah Philipp (Nordrhein-Westfalen 2022 - 2027)',
#   'pol_full_name': 'Sarah Philipp',
#   'pol_url': 'https://www.abgeordnetenwatch.de/api/v2/politicians/130358',
#   'start_date': None,
#   'constituency_label': '61 - Duisburg I (Nordrhein-Westfalen 2022 - 2027)'},
#  {'id': 56258,
#   'label': 'Charlotte Quik (Nordrhein-Westfalen 2022 - 2027)',
#   'pol_full_name': 'Charlotte Quik',
#   'pol_url': 'https://www.abgeordnetenwatch.de/api/v2/politicians/130136',
#   'start_date': None,
#   'constituency_label': '59 - Wesel III (Nordrhein-Westfalen 2022 - 2027)'},
#  {'id': 56257,
#   'label': 'René Schneider (Nordrhein-Westfalen 2022 - 2027)',
#   'pol_full_name': 'René Schneider',
#   'pol_url': 'https://www.abgeordnetenwatch.de/api/v2/politicians/130660',
#   'start_date': None,
#   'constituency_label': '58 - Wesel II (Nordrhein-Westfalen 2022 - 2027)'},
#  {'id': 56256,
#   'label': 'Stefan Zimkeit (Nordrhein-Westfalen 2022 - 2027)',
#   'pol_full_name': 'Stefan Zimkeit',
#   'pol_url': 'https://www.abgeordnetenwatch.de/api/v2/politicians/130709',
#   'start_date': None,
#   'constituency_label': '57 - Oberhausen II - Wesel I (Nordrhein-Westfalen 2022 - 2027)'},
#  {'id': 56255,
#   'label': 'Sonja Bongers (Nordrhein-Westfalen 2022 - 2027)',
#   'pol_full_name': 'Sonja Bongers',
#   'pol_url': 'https://www.abgeordnetenwatch.de/api/v2/politicians/130114',
#   'start_date': None,
#   'constituency_label': '56 - Oberhausen I (Nordrhein-Westfalen 2022 - 2027)'},
#  {'id': 56254,
#   'label': 'Günther Bergmann (Nordrhein-Westfalen 2022 - 2027)',
#   'pol_full_name': 'Günther Bergmann',
#   'pol_url': 'https://www.abgeordnetenwatch.de/api/v2/politicians/130262',
#   'start_date': None,
#   'constituency_label': '55 - Kleve II (Nordrhein-Westfalen 2022 - 2027)'},
#  {'id': 56253,
#   'label': 'Stephan Wolters (Nordrhein-Westfalen 2022 - 2027)',
#   'pol_full_name': 'Stephan Wolters',
#   'pol_url': 'https://www.abgeordnetenwatch.de/api/v2/politicians/178947',
#   'start_date': None,
#   'constituency_label': '54 - Kleve I (Nordrhein-Westfalen 2022 - 2027)'},
#  {'id': 56252,
#   'label': 'Marcus Optendrenk (Nordrhein-Westfalen 2022 - 2027)',
#   'pol_full_name': 'Marcus Optendrenk',
#   'pol_url': 'https://www.abgeordnetenwatch.de/api/v2/politicians/130514',
#   'start_date': None,
#   'constituency_label': '53 - Viersen II (Nordrhein-Westfalen 2022 - 2027)'},
#  {'id': 56251,
#   'label': 'Guido Görtz (Nordrhein-Westfalen 2022 - 2027)',
#   'pol_full_name': 'Guido Görtz',
#   'pol_url': 'https://www.abgeordnetenwatch.de/api/v2/politicians/178605',
#   'start_date': None,
#   'constituency_label': '52 - Viersen I (Nordrhein-Westfalen 2022 - 2027)'},
#  {'id': 56250,
#   'label': 'Jochen Klenner (Nordrhein-Westfalen 2022 - 2027)',
#   'pol_full_name': 'Jochen Klenner',
#   'pol_url': 'https://www.abgeordnetenwatch.de/api/v2/politicians/130403',
#   'start_date': None,
#   'constituency_label': '51 - Mönchengladbach II (Nordrhein-Westfalen 2022 - 2027)'},
#  {'id': 56249,
#   'label': 'Vanessa Odermatt (Nordrhein-Westfalen 2022 - 2027)',
#   'pol_full_name': 'Vanessa Odermatt',
#   'pol_url': 'https://www.abgeordnetenwatch.de/api/v2/politicians/178604',
#   'start_date': None,
#   'constituency_label': '50 - Mönchengladbach I (Nordrhein-Westfalen 2022 - 2027)'},
#  {'id': 56248,
#   'label': 'Marc Blondin (Nordrhein-Westfalen 2022 - 2027)',
#   'pol_full_name': 'Marc Blondin',
#   'pol_url': 'https://www.abgeordnetenwatch.de/api/v2/politicians/130506',
#   'start_date': None,
#   'constituency_label': '49 - Krefeld II (Nordrhein-Westfalen 2022 - 2027)'},
#  {'id': 56247,
#   'label': 'Britta Oellers (Nordrhein-Westfalen 2022 - 2027)',
#   'pol_full_name': 'Britta Oellers',
#   'pol_url': 'https://www.abgeordnetenwatch.de/api/v2/politicians/130120',
#   'start_date': None,
#   'constituency_label': '48 - Krefeld I - Viersen III (Nordrhein-Westfalen 2022 - 2027)'},
#  {'id': 56246,
#   'label': 'Lutz Lienenkämper (Nordrhein-Westfalen 2022 - 2027)',
#   'pol_full_name': 'Lutz Lienenkämper',
#   'pol_url': 'https://www.abgeordnetenwatch.de/api/v2/politicians/130466',
#   'start_date': None,
#   'constituency_label': '47 - Rhein-Kreis Neuss III (Nordrhein-Westfalen 2022 - 2027)'},
#  {'id': 56245,
#   'label': 'Heike Troles (Nordrhein-Westfalen 2022 - 2027)',
#   'pol_full_name': 'Heike Troles',
#   'pol_url': 'https://www.abgeordnetenwatch.de/api/v2/politicians/130286',
#   'start_date': None,
#   'constituency_label': '46 - Rhein-Kreis Neuss II (Nordrhein-Westfalen 2022 - 2027)'},
#  {'id': 56244,
#   'label': 'Jörg Geerlings (Nordrhein-Westfalen 2022 - 2027)',
#   'pol_full_name': 'Jörg Geerlings',
#   'pol_url': 'https://www.abgeordnetenwatch.de/api/v2/politicians/130408',
#   'start_date': None,
#   'constituency_label': '45 - Rhein-Kreis Neuss I (Nordrhein-Westfalen 2022 - 2027)'},
#  {'id': 56243,
#   'label': 'Peter Blumenrath (Nordrhein-Westfalen 2022 - 2027)',
#   'pol_full_name': 'Peter Blumenrath',
#   'pol_url': 'https://www.abgeordnetenwatch.de/api/v2/politicians/178603',
#   'start_date': None,
#   'constituency_label': '44 - Düsseldorf IV (Nordrhein-Westfalen 2022 - 2027)'},
#  {'id': 56242,
#   'label': 'Angela Erwin (Nordrhein-Westfalen 2022 - 2027)',
#   'pol_full_name': 'Angela Erwin',
#   'pol_url': 'https://www.abgeordnetenwatch.de/api/v2/politicians/130059',
#   'start_date': None,
#   'constituency_label': '43 - Düsseldorf III (Nordrhein-Westfalen 2022 - 2027)'},
#  {'id': 56241,
#   'label': 'Marco Schmitz (Nordrhein-Westfalen 2022 - 2027)',
#   'pol_full_name': 'Marco Schmitz',
#   'pol_url': 'https://www.abgeordnetenwatch.de/api/v2/politicians/130512',
#   'start_date': None,
#   'constituency_label': '42 - Düsseldorf II (Nordrhein-Westfalen 2022 - 2027)'},
#  {'id': 56240,
#   'label': 'Olaf Lehne (Nordrhein-Westfalen 2022 - 2027)',
#   'pol_full_name': 'Olaf Lehne',
#   'pol_url': 'https://www.abgeordnetenwatch.de/api/v2/politicians/130600',
#   'start_date': None,
#   'constituency_label': '41 - Düsseldorf I (Nordrhein-Westfalen 2022 - 2027)'},
#  {'id': 56239,
#   'label': 'Martin Sträßer (Nordrhein-Westfalen 2022 - 2027)',
#   'pol_full_name': 'Martin Sträßer',
#   'pol_url': 'https://www.abgeordnetenwatch.de/api/v2/politicians/130533',
#   'start_date': None,
#   'constituency_label': '40 - Mettmann IV (Nordrhein-Westfalen 2022 - 2027)'},
#  {'id': 56238,
#   'label': 'Jan Volker Heinisch (Nordrhein-Westfalen 2022 - 2027)',
#   'pol_full_name': 'Jan Volker Heinisch',
#   'pol_url': 'https://www.abgeordnetenwatch.de/api/v2/politicians/130494',
#   'start_date': None,
#   'constituency_label': '39 - Mettmann III - Mülheim II (Nordrhein-Westfalen 2022 - 2027)'},
#  {'id': 56237,
#   'label': 'Christian Untrieser (Nordrhein-Westfalen 2022 - 2027)',
#   'pol_full_name': 'Christian Untrieser',
#   'pol_url': 'https://www.abgeordnetenwatch.de/api/v2/politicians/130141',
#   'start_date': None,
#   'constituency_label': '38 - Mettmann II (Nordrhein-Westfalen 2022 - 2027)'},
#  {'id': 56236,
#   'label': 'Claudia Schlottmann (Nordrhein-Westfalen 2022 - 2027)',
#   'pol_full_name': 'Claudia Schlottmann',
#   'pol_url': 'https://www.abgeordnetenwatch.de/api/v2/politicians/130126',
#   'start_date': None,
#   'constituency_label': '37 - Mettmann I (Nordrhein-Westfalen 2022 - 2027)'},
#  {'id': 56235,
#   'label': 'Jens-Peter Nettekoven (Nordrhein-Westfalen 2022 - 2027)',
#   'pol_full_name': 'Jens-Peter Nettekoven',
#   'pol_url': 'https://www.abgeordnetenwatch.de/api/v2/politicians/130392',
#   'start_date': None,
#   'constituency_label': '36 - Remscheid I - Oberbergischer Kreis III (Nordrhein-Westfalen 2022 - 2027)'},
#  {'id': 56234,
#   'label': 'Sebastian Haug (Nordrhein-Westfalen 2022 - 2027)',
#   'pol_full_name': 'Sebastian Haug',
#   'pol_url': 'https://www.abgeordnetenwatch.de/api/v2/politicians/178602',
#   'start_date': None,
#   'constituency_label': '35 - Solingen I (Nordrhein-Westfalen 2022 - 2027)'},
#  {'id': 56233,
#   'label': 'Josef Neumann (Nordrhein-Westfalen 2022 - 2027)',
#   'pol_full_name': 'Josef Neumann',
#   'pol_url': 'https://www.abgeordnetenwatch.de/api/v2/politicians/130415',
#   'start_date': None,
#   'constituency_label': '34 - Wuppertal III - Solingen II (Nordrhein-Westfalen 2022 - 2027)'},
#  {'id': 56232,
#   'label': 'Dilek Engin (Nordrhein-Westfalen 2022 - 2027)',
#   'pol_full_name': 'Dilek Engin',
#   'pol_url': 'https://www.abgeordnetenwatch.de/api/v2/politicians/178386',
#   'start_date': None,
#   'constituency_label': '33 - Wuppertal II (Nordrhein-Westfalen 2022 - 2027)'},
#  {'id': 56231,
#   'label': 'Andreas Bialas (Nordrhein-Westfalen 2022 - 2027)',
#   'pol_full_name': 'Andreas Bialas',
#   'pol_url': 'https://www.abgeordnetenwatch.de/api/v2/politicians/130053',
#   'start_date': None,
#   'constituency_label': '32 - Wuppertal I (Nordrhein-Westfalen 2022 - 2027)'},
#  {'id': 56230,
#   'label': 'Christos Katzidis (Nordrhein-Westfalen 2022 - 2027)',
#   'pol_full_name': 'Christos Katzidis',
#   'pol_url': 'https://www.abgeordnetenwatch.de/api/v2/politicians/130447',
#   'start_date': None,
#   'constituency_label': '31 - Bonn II (Nordrhein-Westfalen 2022 - 2027)'},
#  {'id': 56229,
#   'label': 'Guido Déus (Nordrhein-Westfalen 2022 - 2027)',
#   'pol_full_name': 'Guido Déus',
#   'pol_url': 'https://www.abgeordnetenwatch.de/api/v2/politicians/130448',
#   'start_date': None,
#   'constituency_label': '30 - Bonn I (Nordrhein-Westfalen 2022 - 2027)'},
#  {'id': 56228,
#   'label': 'Sascha Lienesch (Nordrhein-Westfalen 2022 - 2027)',
#   'pol_full_name': 'Sascha Lienesch',
#   'pol_url': 'https://www.abgeordnetenwatch.de/api/v2/politicians/178943',
#   'start_date': None,
#   'constituency_label': '29 - Rhein-Sieg-Kreis V (Nordrhein-Westfalen 2022 - 2027)'},
#  {'id': 56227,
#   'label': 'Katharina Gebauer (Nordrhein-Westfalen 2022 - 2027)',
#   'pol_full_name': 'Katharina Gebauer',
#   'pol_url': 'https://www.abgeordnetenwatch.de/api/v2/politicians/130434',
#   'start_date': None,
#   'constituency_label': '28 - Rhein-Sieg-Kreis IV (Nordrhein-Westfalen 2022 - 2027)'},
#  {'id': 56226,
#   'label': 'Jonathan Grunwald (Nordrhein-Westfalen 2022 - 2027)',
#   'pol_full_name': 'Jonathan Grunwald',
#   'pol_url': 'https://www.abgeordnetenwatch.de/api/v2/politicians/178600',
#   'start_date': None,
#   'constituency_label': '26 - Rhein-Sieg-Kreis II (Nordrhein-Westfalen 2022 - 2027)'},
#  {'id': 56225,
#   'label': 'Björn Franken (Nordrhein-Westfalen 2022 - 2027)',
#   'pol_full_name': 'Björn Franken',
#   'pol_url': 'https://www.abgeordnetenwatch.de/api/v2/politicians/130108',
#   'start_date': None,
#   'constituency_label': '25 - Rhein-Sieg-Kreis I (Nordrhein-Westfalen 2022 - 2027)'},
#  {'id': 56224,
#   'label': 'Bodo Löttgen (Nordrhein-Westfalen 2022 - 2027)',
#   'pol_full_name': 'Bodo Löttgen',
#   'pol_url': 'https://www.abgeordnetenwatch.de/api/v2/politicians/130112',
#   'start_date': None,
#   'constituency_label': '24 - Oberbergischer Kreis II (Nordrhein-Westfalen 2022 - 2027)'},
#  {'id': 56223,
#   'label': 'Christian Berger (Nordrhein-Westfalen 2022 - 2027)',
#   'pol_full_name': 'Christian Berger',
#   'pol_url': 'https://www.abgeordnetenwatch.de/api/v2/politicians/178599',
#   'start_date': None,
#   'constituency_label': '23 - Oberbergischer Kreis I (Nordrhein-Westfalen 2022 - 2027)'},
#  {'id': 56222,
#   'label': 'Herbert Reul (Nordrhein-Westfalen 2022 - 2027)',
#   'pol_full_name': 'Herbert Reul',
#   'pol_url': 'https://www.abgeordnetenwatch.de/api/v2/politicians/28907',
#   'start_date': None,
#   'constituency_label': '22 - Rheinisch-Bergischer Kreis II (Nordrhein-Westfalen 2022 - 2027)'},
#  {'id': 56221,
#   'label': 'Martin Lucke (Nordrhein-Westfalen 2022 - 2027)',
#   'pol_full_name': 'Martin Lucke',
#   'pol_url': 'https://www.abgeordnetenwatch.de/api/v2/politicians/178598',
#   'start_date': None,
#   'constituency_label': '21 - Rheinisch-Bergischer Kreis I (Nordrhein-Westfalen 2022 - 2027)'},
#  {'id': 56220,
#   'label': 'Rüdiger Scholz (Nordrhein-Westfalen 2022 - 2027)',
#   'pol_full_name': 'Rüdiger Scholz',
#   'pol_url': 'https://www.abgeordnetenwatch.de/api/v2/politicians/130686',
#   'start_date': None,
#   'constituency_label': '20 - Leverkusen (Nordrhein-Westfalen 2022 - 2027)'},
#  {'id': 56219,
#   'label': 'Carolin Kirsch (Nordrhein-Westfalen 2022 - 2027)',
#   'pol_full_name': 'Carolin Kirsch',
#   'pol_url': 'https://www.abgeordnetenwatch.de/api/v2/politicians/178375',
#   'start_date': None,
#   'constituency_label': '19 - Köln VII (Nordrhein-Westfalen 2022 - 2027)'},
#  {'id': 56218,
#   'label': 'Berivan Aymaz (Nordrhein-Westfalen 2022 - 2027)',
#   'pol_full_name': 'Berivan Aymaz',
#   'pol_url': 'https://www.abgeordnetenwatch.de/api/v2/politicians/120921',
#   'start_date': None,
#   'constituency_label': '18 - Köln VI (Nordrhein-Westfalen 2022 - 2027)'},
#  {'id': 56217,
#   'label': 'Florian Braun (Nordrhein-Westfalen 2022 - 2027)',
#   'pol_full_name': 'Florian Braun',
#   'pol_url': 'https://www.abgeordnetenwatch.de/api/v2/politicians/130630',
#   'start_date': None,
#   'constituency_label': '17 - Köln V (Nordrhein-Westfalen 2022 - 2027)'},
#  {'id': 56216,
#   'label': 'Lena Teschlade (Nordrhein-Westfalen 2022 - 2027)',
#   'pol_full_name': 'Lena Teschlade',
#   'pol_url': 'https://www.abgeordnetenwatch.de/api/v2/politicians/178372',
#   'start_date': None,
#   'constituency_label': '16 - Köln IV (Nordrhein-Westfalen 2022 - 2027)'},
#  {'id': 56215,
#   'label': 'Arndt Klocke (Nordrhein-Westfalen 2022 - 2027)',
#   'pol_full_name': 'Arndt Klocke',
#   'pol_url': 'https://www.abgeordnetenwatch.de/api/v2/politicians/130074',
#   'start_date': None,
#   'constituency_label': '15 - Köln III (Nordrhein-Westfalen 2022 - 2027)'},
#  {'id': 56214,
#   'label': 'Frank Jablonski (Nordrhein-Westfalen 2022 - 2027)',
#   'pol_full_name': 'Frank Jablonski',
#   'pol_url': 'https://www.abgeordnetenwatch.de/api/v2/politicians/130461',
#   'start_date': None,
#   'constituency_label': '14 - Köln II (Nordrhein-Westfalen 2022 - 2027)'},
#  {'id': 56213,
#   'label': 'Eileen Woestmann (Nordrhein-Westfalen 2022 - 2027)',
#   'pol_full_name': 'Eileen Woestmann',
#   'pol_url': 'https://www.abgeordnetenwatch.de/api/v2/politicians/178452',
#   'start_date': None,
#   'constituency_label': '13 - Köln I (Nordrhein-Westfalen 2022 - 2027)'},
#  {'id': 56212,
#   'label': 'Ralf Nolten (Nordrhein-Westfalen 2022 - 2027)',
#   'pol_full_name': 'Ralf Nolten',
#   'pol_url': 'https://www.abgeordnetenwatch.de/api/v2/politicians/130651',
#   'start_date': None,
#   'constituency_label': '12 - Düren II - Euskirchen II (Nordrhein-Westfalen 2022 - 2027)'},
#  {'id': 56211,
#   'label': 'Patricia Peill (Nordrhein-Westfalen 2022 - 2027)',
#   'pol_full_name': 'Patricia Peill',
#   'pol_url': 'https://www.abgeordnetenwatch.de/api/v2/politicians/29358',
#   'start_date': None,
#   'constituency_label': '11 - Düren I (Nordrhein-Westfalen 2022 - 2027)'},
#  {'id': 56210,
#   'label': 'Thomas Schnelle (Nordrhein-Westfalen 2022 - 2027)',
#   'pol_full_name': 'Thomas Schnelle',
#   'pol_url': 'https://www.abgeordnetenwatch.de/api/v2/politicians/130367',
#   'start_date': None,
#   'constituency_label': '10 - Heinsberg II (Nordrhein-Westfalen 2022 - 2027)'},
#  {'id': 56209,
#   'label': 'Bernd Krückel (Nordrhein-Westfalen 2022 - 2027)',
#   'pol_full_name': 'Bernd Krückel',
#   'pol_url': 'https://www.abgeordnetenwatch.de/api/v2/politicians/130102',
#   'start_date': None,
#   'constituency_label': '9 - Heinsberg I (Nordrhein-Westfalen 2022 - 2027)'},
#  {'id': 56208,
#   'label': 'Klaus Voussem (Nordrhein-Westfalen 2022 - 2027)',
#   'pol_full_name': 'Klaus Voussem',
#   'pol_url': 'https://www.abgeordnetenwatch.de/api/v2/politicians/130424',
#   'start_date': None,
#   'constituency_label': '8 - Euskirchen I (Nordrhein-Westfalen 2022 - 2027)'},
#  {'id': 56207,
#   'label': 'Gregor Golland (Nordrhein-Westfalen 2022 - 2027)',
#   'pol_full_name': 'Gregor Golland',
#   'pol_url': 'https://www.abgeordnetenwatch.de/api/v2/politicians/130255',
#   'start_date': None,
#   'constituency_label': '7 - Rhein-Erft-Kreis III (Nordrhein-Westfalen 2022 - 2027)'},
#  {'id': 56206,
#   'label': 'Thomas Okos (Nordrhein-Westfalen 2022 - 2027)',
#   'pol_full_name': 'Thomas Okos',
#   'pol_url': 'https://www.abgeordnetenwatch.de/api/v2/politicians/178596',
#   'start_date': None,
#   'constituency_label': '6 - Rhein-Erft-Kreis II (Nordrhein-Westfalen 2022 - 2027)'},
#  {'id': 56205,
#   'label': 'Romina Plonsker (Nordrhein-Westfalen 2022 - 2027)',
#   'pol_full_name': 'Romina Plonsker',
#   'pol_url': 'https://www.abgeordnetenwatch.de/api/v2/politicians/130363',
#   'start_date': None,
#   'constituency_label': '5 - Rhein-Erft-Kreis I (Nordrhein-Westfalen 2022 - 2027)'},
#  {'id': 56204,
#   'label': 'Daniel Scheen-Pauls (Nordrhein-Westfalen 2022 - 2027)',
#   'pol_full_name': 'Daniel Scheen-Pauls',
#   'pol_url': 'https://www.abgeordnetenwatch.de/api/v2/politicians/178595',
#   'start_date': None,
#   'constituency_label': '4 - Aachen IV (Nordrhein-Westfalen 2022 - 2027)'},
#  {'id': 56203,
#   'label': 'Hendrik Schmitz (Nordrhein-Westfalen 2022 - 2027)',
#   'pol_full_name': 'Hendrik Schmitz',
#   'pol_url': 'https://www.abgeordnetenwatch.de/api/v2/politicians/130297',
#   'start_date': None,
#   'constituency_label': '3 - Aachen III (Nordrhein-Westfalen 2022 - 2027)'},
#  {'id': 56202,
#   'label': 'Annika Fohn (Nordrhein-Westfalen 2022 - 2027)',
#   'pol_full_name': 'Annika Fohn',
#   'pol_url': 'https://www.abgeordnetenwatch.de/api/v2/politicians/178594',
#   'start_date': None,
#   'constituency_label': '2 - Aachen II (Nordrhein-Westfalen 2022 - 2027)'},
#  {'id': 56201,
#   'label': 'Astrid Vogelheim (Nordrhein-Westfalen 2022 - 2027)',
#   'pol_full_name': 'Astrid Vogelheim',
#   'pol_url': 'https://www.abgeordnetenwatch.de/api/v2/politicians/178442',
#   'start_date': None,
#   'constituency_label': '1 - Aachen I (Nordrhein-Westfalen 2022 - 2027)'}]

# %%
nrw_df = pd.DataFrame(nrw_for_df)
nrw_df
# Out:
#         id                                              label  \
# 0    58436  Stefan Kämmerling (Nordrhein-Westfalen 2022 - ...
# 1    58123  Franziska Müller-Rech (Nordrhein-Westfalen 202...
# 2    57249  Susanne Schneider (Nordrhein-Westfalen 2022 - ...
# 3    57037  Ina Scharrenbach (Nordrhein-Westfalen 2022 - 2...
# 4    56395  Andreas Keith-Volkmer (Nordrhein-Westfalen 202...
# ..     ...                                                ...
# 190  56205  Romina Plonsker (Nordrhein-Westfalen 2022 - 2027)
# 191  56204  Daniel Scheen-Pauls (Nordrhein-Westfalen 2022 ...
# 192  56203  Hendrik Schmitz (Nordrhein-Westfalen 2022 - 2027)
# 193  56202      Annika Fohn (Nordrhein-Westfalen 2022 - 2027)
# 194  56201  Astrid Vogelheim (Nordrhein-Westfalen 2022 - 2...
#
#              pol_full_name                                            pol_url  \
# 0        Stefan Kämmerling  https://www.abgeordnetenwatch.de/api/v2/politi...
# 1    Franziska Müller-Rech  https://www.abgeordnetenwatch.de/api/v2/politi...
# 2        Susanne Schneider  https://www.abgeordnetenwatch.de/api/v2/politi...
# 3         Ina Scharrenbach  https://www.abgeordnetenwatch.de/api/v2/politi...
# 4    Andreas Keith-Volkmer  https://www.abgeordnetenwatch.de/api/v2/politi...
# ..                     ...                                                ...
# 190        Romina Plonsker  https://www.abgeordnetenwatch.de/api/v2/politi...
# 191    Daniel Scheen-Pauls  https://www.abgeordnetenwatch.de/api/v2/politi...
# 192        Hendrik Schmitz  https://www.abgeordnetenwatch.de/api/v2/politi...
# 193            Annika Fohn  https://www.abgeordnetenwatch.de/api/v2/politi...
# 194       Astrid Vogelheim  https://www.abgeordnetenwatch.de/api/v2/politi...
#
#      start_date                                 constituency_label
# 0    2023-03-04                                               None
# 1    2023-01-27                                               None
# 2    2023-01-01                                               None
# 3    2022-06-30                                               None
# 4          None                                               None
# ..          ...                                                ...
# 190        None  5 - Rhein-Erft-Kreis I (Nordrhein-Westfalen 20...
# 191        None    4 - Aachen IV (Nordrhein-Westfalen 2022 - 2027)
# 192        None   3 - Aachen III (Nordrhein-Westfalen 2022 - 2027)
# 193        None    2 - Aachen II (Nordrhein-Westfalen 2022 - 2027)
# 194        None     1 - Aachen I (Nordrhein-Westfalen 2022 - 2027)
#
# [195 rows x 6 columns]

# %%
nrw_df[nrw_df.pol_full_name.str.contains('Martin Vincentz')]
# Out:
#        id                                              label    pol_full_name  \
# 44  56355  Martin Vincentz (Nordrhein-Westfalen 2022 - 2027)  Martin Vincentz
#
#                                               pol_url start_date  \
# 44  https://www.abgeordnetenwatch.de/api/v2/politi...       None
#
#                                    constituency_label
# 44  48 - Krefeld I - Viersen III (Nordrhein-Westfa...

# %%
len(nrw_df)
# Out:
# 195

# %%
nrw_df[-20:]
# Out:
#         id                                              label  \
# 179  41473  Britta Altenkamp (Nordrhein-Westfalen 2017 - 2...
# 180  41468    Sonja Bongers (Nordrhein-Westfalen 2017 - 2022)
# 181  41464    Björn Franken (Nordrhein-Westfalen 2017 - 2022)
# 182  41463    Bernd Krückel (Nordrhein-Westfalen 2017 - 2022)
# 183  41449  Anke Fuchs-Dreisbach (Nordrhein-Westfalen 2017...
# 184  41446      Angela Lück (Nordrhein-Westfalen 2017 - 2022)
# 185  41443  Angela Freimuth (Nordrhein-Westfalen 2017 - 2022)
# 186  41439     Angela Erwin (Nordrhein-Westfalen 2017 - 2022)
# 187  41437  Andreas Terhaag (Nordrhein-Westfalen 2017 - 2022)
# 188  41435  Andreas Kossiski (Nordrhein-Westfalen 2017 - 2...
# 189  41433   Andreas Bialas (Nordrhein-Westfalen 2017 - 2022)
# 190  41430   Andreas Becker (Nordrhein-Westfalen 2017 - 2022)
# 191  41426     André Stinka (Nordrhein-Westfalen 2017 - 2022)
# 192  41422      André Kuper (Nordrhein-Westfalen 2017 - 2022)
# 193  41419   Alexander Vogt (Nordrhein-Westfalen 2017 - 2022)
# 194  41416       Armin Jahl (Nordrhein-Westfalen 2017 - 2022)
# 195  41411  Alexander Langguth (Nordrhein-Westfalen 2017 -...
# 196  41375  Thomas Göddertz (Nordrhein-Westfalen 2017 - 2022)
# 197  39859       Jochen Ott (Nordrhein-Westfalen 2017 - 2022)
# 198  37951  Marcus Pretzell (Nordrhein-Westfalen 2017 - 2022)
#
#             pol_full_name                                            pol_url  \
# 179      Britta Altenkamp  https://www.abgeordnetenwatch.de/api/v2/politi...
# 180         Sonja Bongers  https://www.abgeordnetenwatch.de/api/v2/politi...
# 181         Björn Franken  https://www.abgeordnetenwatch.de/api/v2/politi...
# 182         Bernd Krückel  https://www.abgeordnetenwatch.de/api/v2/politi...
# 183  Anke Fuchs-Dreisbach  https://www.abgeordnetenwatch.de/api/v2/politi...
# 184           Angela Lück  https://www.abgeordnetenwatch.de/api/v2/politi...
# 185       Angela Freimuth  https://www.abgeordnetenwatch.de/api/v2/politi...
# 186          Angela Erwin  https://www.abgeordnetenwatch.de/api/v2/politi...
# 187       Andreas Terhaag  https://www.abgeordnetenwatch.de/api/v2/politi...
# 188      Andreas Kossiski  https://www.abgeordnetenwatch.de/api/v2/politi...
# 189        Andreas Bialas  https://www.abgeordnetenwatch.de/api/v2/politi...
# 190        Andreas Becker  https://www.abgeordnetenwatch.de/api/v2/politi...
# 191          André Stinka  https://www.abgeordnetenwatch.de/api/v2/politi...
# 192           André Kuper  https://www.abgeordnetenwatch.de/api/v2/politi...
# 193        Alexander Vogt  https://www.abgeordnetenwatch.de/api/v2/politi...
# 194            Armin Jahl  https://www.abgeordnetenwatch.de/api/v2/politi...
# 195    Alexander Langguth  https://www.abgeordnetenwatch.de/api/v2/politi...
# 196       Thomas Göddertz  https://www.abgeordnetenwatch.de/api/v2/politi...
# 197            Jochen Ott  https://www.abgeordnetenwatch.de/api/v2/politi...
# 198       Marcus Pretzell  https://www.abgeordnetenwatch.de/api/v2/politi...
#
#     start_date                                 constituency_label
# 179       None   67 - Essen III (Nordrhein-Westfalen 2017 - 2022)
# 180       None  55 - Oberhausen I (Nordrhein-Westfalen 2017 - ...
# 181       None  25 - Rhein-Sieg-Kreis I (Nordrhein-Westfalen 2...
# 182       None  9 - Heinsberg I (Nordrhein-Westfalen 2017 - 2022)
# 183       None  127 - Siegen-Wittgenstein II (Nordrhein-Westfa...
# 184       None  91 - Herford II - Minden-Lübbecke IV (Nordrhei...
# 185       None  123 - Märkischer Kreis III (Nordrhein-Westfale...
# 186       None  42 - Düsseldorf III (Nordrhein-Westfalen 2017 ...
# 187       None  50 - Mönchengladbach II (Nordrhein-Westfalen 2...
# 188       None     16 - Köln IV (Nordrhein-Westfalen 2017 - 2022)
# 189       None  32 - Wuppertal II (Nordrhein-Westfalen 2017 - ...
# 190       None  69 - Recklinghausen I (Nordrhein-Westfalen 201...
# 191       None  80 - Coesfeld II (Nordrhein-Westfalen 2017 - 2...
# 192       None  96 - Gütersloh III (Nordrhein-Westfalen 2017 -...
# 193       None    110 - Herne I (Nordrhein-Westfalen 2017 - 2022)
# 194       None  111 - Dortmund I (Nordrhein-Westfalen 2017 - 2...
# 195       None  121 - Märkischer Kreis I (Nordrhein-Westfalen ...
# 196       None     76 - Bottrop (Nordrhein-Westfalen 2017 - 2022)
# 197       None      17 - Köln V (Nordrhein-Westfalen 2017 - 2022)
# 198       None                                               None

# %%
nrw_df.constituency_label.value_counts()
# Out:
# constituency_label
# 68 - Essen IV (Nordrhein-Westfalen 2017 - 2022)                           3
# 88 - Minden-Lübbecke I (Nordrhein-Westfalen 2017 - 2022)                  3
# 42 - Düsseldorf III (Nordrhein-Westfalen 2017 - 2022)                     3
# 90 - Herford I - Minden-Lübbecke III (Nordrhein-Westfalen 2017 - 2022)    3
# 120 - Soest II (Nordrhein-Westfalen 2017 - 2022)                          3
#                                                                          ..
# 114 - Dortmund IV (Nordrhein-Westfalen 2017 - 2022)                       1
# 86 - Warendorf I (Nordrhein-Westfalen 2017 - 2022)                        1
# 103 - Hagen I (Nordrhein-Westfalen 2017 - 2022)                           1
# 53 - Kleve I (Nordrhein-Westfalen 2017 - 2022)                            1
# 76 - Bottrop (Nordrhein-Westfalen 2017 - 2022)                            1
# Name: count, Length: 119, dtype: int64

# %% [markdown]
# ## Let's say I want to...
#
# 1. Find and get the list of all candidates in the Election ('Wahl') for the parliament of Bremen in 2015.
# 2. Transform the result into a Data Frame, keeping only the 3 most useful variables as columns (as you seem fit), plus mandate_won.
# 3. From that DF, list only the candidates that won something, no matter what.

# %% [markdown]
# https://www.abgeordnetenwatch.de/api/v2/parliaments
#
# https://www.abgeordnetenwatch.de/api/v2/parliament-periods?parliament=10&range_end=500 --> get id for Bremen 2015 Wahl = 43
#
# https://www.abgeordnetenwatch.de/api/v2/candidacies-mandates?parliament_period=43&range_end=500

# %% [markdown]
# #### first
# Find and get the list of all candidates in the Election ('Wahl') for the parliament of Bremen in 2015.

# %%
bremen_cands = requests.get(url='https://www.abgeordnetenwatch.de/api/v2/candidacies-mandates?parliament_period=43&range_end=500').json()
bremen_cands['data'][0]
# Out:
# {'id': 36764,
#  'entity_type': 'candidacy_mandate',
#  'label': 'Eyfer Tunc (Bremen Wahl 2015)',
#  'api_url': 'https://www.abgeordnetenwatch.de/api/v2/candidacies-mandates/36764',
#  'id_external_administration': None,
#  'id_external_administration_description': None,
#  'type': 'candidacy',
#  'parliament_period': {'id': 43,
#   'entity_type': 'parliament_period',
#   'label': 'Bremen Wahl 2015',
#   'api_url': 'https://www.abgeordnetenwatch.de/api/v2/parliament-periods/43',
#   'abgeordnetenwatch_url': 'https://www.abgeordnetenwatch.de/bremen/wahl-2015'},
#  'politician': {'id': 73863,
#   'entity_type': 'politician',
#   'label': 'Eyfer Tunc',
#   'api_url': 'https://www.abgeordnetenwatch.de/api/v2/politicians/73863',
#   'abgeordnetenwatch_url': 'https://www.abgeordnetenwatch.de/profile/eyfer-tunc'},
#  'party': {'id': 1,
#   'entity_type': 'party',
#   'label': 'SPD',
#   'api_url': 'https://www.abgeordnetenwatch.de/api/v2/parties/1'},
#  'start_date': None,
#  'end_date': None,
#  'info': None,
#  'electoral_data': {'id': 36764,
#   'entity_type': 'electoral_data',
#   'label': 'Eyfer Tunc (Bremen Wahl 2015)',
#   'electoral_list': {'id': 182,
#    'entity_type': 'electoral_list',
#    'label': 'Wahlbereich Bremen (Bremen Wahl 2015)',
#    'api_url': 'https://www.abgeordnetenwatch.de/api/v2/electoral-lists/182'},
#   'list_position': 50,
#   'constituency': {'id': 6974,
#    'entity_type': 'constituency',
#    'label': '17 - Bremen-Vegesack (Bremen Wahl 2015)',
#    'api_url': 'https://www.abgeordnetenwatch.de/api/v2/constituencies/6974'},
#   'constituency_result': None,
#   'constituency_result_count': None,
#   'mandate_won': None}}

# %%
with open('21_bremen_cands.p', 'wb') as f:
    pickle.dump(bremen_cands, f)

# %%
with open('21_bremen_cands.p', 'rb') as f:
    bremen_cands = pickle.load(f)

# %%
bremen_for_df=[]
for i in bremen_cands['data']:
    cand_dict={}
    cand_dict['cand_id']=i['id']
    cand_dict['cand_label']=i['label']
    try:
        cand_dict['cand_party']=i['party']['label']
    except:
        cand_dict['cand_party']=None
    cand_dict['cand_list_pos']=i['electoral_data']['list_position']
    cand_dict['cand_won']=i['electoral_data']['mandate_won']
    bremen_for_df.append(cand_dict)

# %%
bremen_df = pd.DataFrame(bremen_for_df)
bremen_df
# Out:
#      cand_id                                         cand_label  \
# 0      36764                      Eyfer Tunc (Bremen Wahl 2015)
# 1      35731                  Nico Ingelbach (Bremen Wahl 2015)
# 2      35701                       Jan Timke (Bremen Wahl 2015)
# 3      35697                 Martin Günthner (Bremen Wahl 2015)
# 4      35693               Ute Reimers-Bruns (Bremen Wahl 2015)
# ..       ...                                                ...
# 361     1546         Fabian Tobias Siggelkow (Bremen Wahl 2015)
# 362     1088        Vanessa Kirsten Werschky (Bremen Wahl 2015)
# 363     1086  Marcel Käthner genannt Haberland (Bremen Wahl ...
# 364      780                 Sarah Ryglewski (Bremen Wahl 2015)
# 365      410                 Bernd Wundersee (Bremen Wahl 2015)
#
#         cand_party  cand_list_pos cand_won
# 0              SPD           50.0     None
# 1       Die PARTEI           16.0     None
# 2    Bürger in Wut            1.0     list
# 3              SPD            NaN     None
# 4              SPD           28.0     None
# ..             ...            ...      ...
# 361     Die PARTEI            5.0     None
# 362            CDU           22.0     None
# 363            CDU           44.0     None
# 364            SPD           10.0     None
# 365            CDU            NaN     None
#
# [366 rows x 5 columns]

# %% [markdown]
# first option

# %%
bremen_df.cand_won.unique() #or value_counts()
# Out:
# array([None, 'list'], dtype=object)

# %%
bremen_df[bremen_df.cand_won=='list']
# Out:
#      cand_id                                  cand_label  \
# 2      35701                Jan Timke (Bremen Wahl 2015)
# 8      35684        Lencke Wischhusen (Bremen Wahl 2015)
# 9      35682        Klaus-Rainer Rupp (Bremen Wahl 2015)
# 13     35668          Birgit Bergmann (Bremen Wahl 2015)
# 19     35530         Julie Kohlrausch (Bremen Wahl 2015)
# ..       ...                                         ...
# 259     4925             Turhal Özdal (Bremen Wahl 2015)
# 287     4883              Wilko Zicht (Bremen Wahl 2015)
# 294     4867  Kirsten Kappert-Gonther (Bremen Wahl 2015)
# 348     4786             Klaus Remkes (Bremen Wahl 2015)
# 360     4773          Piet Leidreiter (Bremen Wahl 2015)
#
#                 cand_party  cand_list_pos cand_won
# 2            Bürger in Wut            1.0     list
# 8                      FDP            1.0     list
# 9                DIE LINKE            2.0     list
# 13                     CDU           27.0     list
# 19                     FDP            5.0     list
# ..                     ...            ...      ...
# 259  Bündnis 90/Die Grünen            9.0     list
# 287  Bündnis 90/Die Grünen           16.0     list
# 294  Bündnis 90/Die Grünen            7.0     list
# 348                    AfD           16.0     list
# 360                    AfD            2.0     list
#
# [71 rows x 5 columns]

# %% [markdown]
# second (more generalizing) option

# %%
bremen_df[bremen_df.cand_won != 'None']
# Out:
#      cand_id                                         cand_label  \
# 0      36764                      Eyfer Tunc (Bremen Wahl 2015)
# 1      35731                  Nico Ingelbach (Bremen Wahl 2015)
# 2      35701                       Jan Timke (Bremen Wahl 2015)
# 3      35697                 Martin Günthner (Bremen Wahl 2015)
# 4      35693               Ute Reimers-Bruns (Bremen Wahl 2015)
# ..       ...                                                ...
# 361     1546         Fabian Tobias Siggelkow (Bremen Wahl 2015)
# 362     1088        Vanessa Kirsten Werschky (Bremen Wahl 2015)
# 363     1086  Marcel Käthner genannt Haberland (Bremen Wahl ...
# 364      780                 Sarah Ryglewski (Bremen Wahl 2015)
# 365      410                 Bernd Wundersee (Bremen Wahl 2015)
#
#         cand_party  cand_list_pos cand_won
# 0              SPD           50.0     None
# 1       Die PARTEI           16.0     None
# 2    Bürger in Wut            1.0     list
# 3              SPD            NaN     None
# 4              SPD           28.0     None
# ..             ...            ...      ...
# 361     Die PARTEI            5.0     None
# 362            CDU           22.0     None
# 363            CDU           44.0     None
# 364            SPD           10.0     None
# 365            CDU            NaN     None
#
# [366 rows x 5 columns]

# %%
bremen_df[bremen_df.cand_won.notnull()]
# Out:
#      cand_id                                  cand_label  \
# 2      35701                Jan Timke (Bremen Wahl 2015)
# 8      35684        Lencke Wischhusen (Bremen Wahl 2015)
# 9      35682        Klaus-Rainer Rupp (Bremen Wahl 2015)
# 13     35668          Birgit Bergmann (Bremen Wahl 2015)
# 19     35530         Julie Kohlrausch (Bremen Wahl 2015)
# ..       ...                                         ...
# 259     4925             Turhal Özdal (Bremen Wahl 2015)
# 287     4883              Wilko Zicht (Bremen Wahl 2015)
# 294     4867  Kirsten Kappert-Gonther (Bremen Wahl 2015)
# 348     4786             Klaus Remkes (Bremen Wahl 2015)
# 360     4773          Piet Leidreiter (Bremen Wahl 2015)
#
#                 cand_party  cand_list_pos cand_won
# 2            Bürger in Wut            1.0     list
# 8                      FDP            1.0     list
# 9                DIE LINKE            2.0     list
# 13                     CDU           27.0     list
# 19                     FDP            5.0     list
# ..                     ...            ...      ...
# 259  Bündnis 90/Die Grünen            9.0     list
# 287  Bündnis 90/Die Grünen           16.0     list
# 294  Bündnis 90/Die Grünen            7.0     list
# 348                    AfD           16.0     list
# 360                    AfD            2.0     list
#
# [71 rows x 5 columns]

# %%
bremen_df[bremen_df.cand_won.notnull()].groupby(bremen_df.cand_party).count()
# Out:
#                        cand_id  cand_label  cand_party  cand_list_pos  \
# cand_party
# AfD                          4           4           4              4
# Bündnis 90/Die Grünen       11          11          11             11
# Bürger in Wut                1           1           1              1
# CDU                         17          17          17             17
# DIE LINKE                    8           8           8              8
# FDP                          6           6           6              6
# SPD                         24          24          24             23
#
#                        cand_won
# cand_party
# AfD                           4
# Bündnis 90/Die Grünen        11
# Bürger in Wut                 1
# CDU                          17
# DIE LINKE                     8
# FDP                           6
# SPD                          24
